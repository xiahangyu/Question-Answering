# %%
import numpy as np
import json
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy

stop_words = set(stopwords.words('english'))
def removeStopw(tokenized_sent):
    return [word for word in tokenized_sent if word.lower() not in stop_words]

# %% [markdown]
# <b>Load data</b>

# %%
f = open("./data/training.json", encoding='utf-8')
js = json.load(f)
train_qs = [ [ word for word in word_tokenize(item['question'])] for item in js]
train_texts = [item['text'] for item in js]
train_aps = [item['answer_paragraph'] for item in js]
train_docids = [item['docid'] for item in js]
f.close()

# %%
f = open("./data/testing.json", encoding='utf-8')
js = json.load(f)
test_qs = [item['question'] for item in js]
test_docids = [item['docid'] for item in js]
f.close()
print(test_qs[0])
# Out:
# Modern browser support standards-based and defacto what?

# %%
f = open("./data/documents.json", encoding='utf-8')
js = json.load(f)
docs = [ item['text'] for item in js]
docids = [item['docid'] for item in js]
f.close()
print(docs[0][0])
# Out:
# First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave. In 1905 the value E, the minimal energy increment of a hypothetical oscillator, was theoretically associated by Einstein with a "quantum" or minimal element of the energy of the electromagnetic wave itself. The light quantum behaved in some respects as an electrically neutral particle, as opposed to an electromagnetic wave. It was eventually called the photon.

# %% [markdown]
# <b>Locate answer paragraph with TF-IDF</b>

# %%
TfidfVectorizers = []
tfidf_doc_mats = []
for doc in docs:
    tfidf = TfidfVectorizer(tokenizer=word_tokenize, lowercase=True)
    tfidf_doc_mats.append(tfidf.fit_transform(doc))
    TfidfVectorizers.append(tfidf)

test_context_sents = []
for i,query in enumerate(test_qs):
    docid = test_docids[i]
    tfidf_query = TfidfVectorizers[docid].transform([query])
    relativities = np.dot(tfidf_query, tfidf_doc_mats[docid].T)
    index = np.argmax(relativities)
    test_context_sents.append(docs[docid][index])
print(test_context_sents[0])
# Out:
# Early web browsers supported only a very simple version of HTML. The rapid development of proprietary web browsers led to the development of non-standard dialects of HTML, leading to problems with interoperability. Modern web browsers support a combination of standards-based and de facto HTML and XHTML, which should be rendered in the same way by all browsers.

# %%
#contexts = [word_tokenize(test_context) for test_context in test_contexts]
queries = [word_tokenize(query) for query in test_qs]
print(queries[0])
# Out:
# ['Modern', 'browser', 'support', 'standards-based', 'and', 'defacto', 'what', '?']

# %% [markdown]
# <b>Identify NER in test contexts</b>

# %%
answers = []
for context in test_context_sents:
    doc = nlp(context)
    
    answer = set()
    for ent in doc.ents:
        answer.add(ent.text)
    answers.append(answer)
answers
# Out:
# [{'HTML', 'XHTML'},
#  set(),
#  {'CSS', 'HTML', 'Java', 'XML'},
#  set(),
#  {'1998',
#   '28%',
#   '7%',
#   'August 2011',
#   'Firefox',
#   'Firefox 1.0',
#   'Netscape',
#   'late 2004',
#   'the Mozilla Foundation'},
#  {'1995', '2002', 'Microsoft', 'Mosaic', 'Windows', 'first', 'over 95%'},
#  {'1990',
#   'Berners-Lee',
#   'Nexus',
#   'Tim Berners-Lee',
#   'WorldWideWeb',
#   'first',
#   'the World Wide Web Consortium',
#   'the World Wide Web Foundation'},
#  {'HTTP Secure'},
#  {'1993',
#   '1993 –',
#   '1994',
#   '90%',
#   'Andreesen',
#   'Andreessen',
#   'Marc Andreessen',
#   'Mosaic',
#   'NCSA',
#   'National Center for Supercomputing Applications',
#   'Netscape',
#   'Netscape Navigator',
#   'first',
#   'the 1990s',
#   'the Mosaic-',
#   'the World Wide Web'},
#  {'1990',
#   'Berners-Lee',
#   'Nexus',
#   'Tim Berners-Lee',
#   'WorldWideWeb',
#   'first',
#   'the World Wide Web Consortium',
#   'the World Wide Web Foundation'},
#  {'January 2009',
#   'Microsoft',
#   'Microsoft Corp v Commission',
#   'Windows',
#   'the European Commission'},
#  {'1995', '2002', 'Microsoft', 'Mosaic', 'Windows', 'first', 'over 95%'},
#  {'HTML'},
#  {'January 2009',
#   'Microsoft',
#   'Microsoft Corp v Commission',
#   'Windows',
#   'the European Commission'},
#  {'1990',
#   'Berners-Lee',
#   'Nexus',
#   'Tim Berners-Lee',
#   'WorldWideWeb',
#   'first',
#   'the World Wide Web Consortium',
#   'the World Wide Web Foundation'},
#  {'Apple', 'April 2011', 'January 2003', 'Safari', 'first', 'just over 7%'},
#  {'January 2009',
#   'Microsoft',
#   'Microsoft Corp v Commission',
#   'Windows',
#   'the European Commission'},
#  {'HTTPS',
#   'URI',
#   'http://en.wikipedia.org/',
#   'the File Transfer Protocol',
#   'the Hypertext Transfer Protocol',
#   'the Uniform Resource Identifier'},
#  {'Firefox', 'Google', 'Google Chrome', 'Google Search', 'Mozilla', 'Today'},
#  {'HTTPS',
#   'URI',
#   'http://en.wikipedia.org/',
#   'the File Transfer Protocol',
#   'the Hypertext Transfer Protocol',
#   'the Uniform Resource Identifier'},
#  {'HTML'},
#  {'1995', '2002', 'Microsoft', 'Mosaic', 'Windows', 'first', 'over 95%'},
#  {'1998',
#   '28%',
#   '7%',
#   'August 2011',
#   'Firefox',
#   'Firefox 1.0',
#   'Netscape',
#   'late 2004',
#   'the Mozilla Foundation'},
#  {'URI', 'a Uniform Resource Identifier', 'the World Wide Web'},
#  {'45%',
#   '8% to 16%',
#   'April 2014',
#   'August 2011',
#   'Chrome',
#   'December 2011',
#   'May 2012',
#   'September 2008',
#   'first',
#   'from month to month'},
#  {'Bookmarks', 'Explorer', 'Firefox', 'Opera'},
#  {'45%',
#   '8% to 16%',
#   'April 2014',
#   'August 2011',
#   'Chrome',
#   'December 2011',
#   'May 2012',
#   'September 2008',
#   'first',
#   'from month to month'},
#  {'1993',
#   '1993 –',
#   '1994',
#   '90%',
#   'Andreesen',
#   'Andreessen',
#   'Marc Andreessen',
#   'Mosaic',
#   'NCSA',
#   'National Center for Supercomputing Applications',
#   'Netscape',
#   'Netscape Navigator',
#   'first',
#   'the 1990s',
#   'the Mosaic-',
#   'the World Wide Web'},
#  {'1998',
#   '28%',
#   '7%',
#   'August 2011',
#   'Firefox',
#   'Firefox 1.0',
#   'Netscape',
#   'late 2004',
#   'the Mozilla Foundation'},
#  {'1998',
#   '28%',
#   '7%',
#   'August 2011',
#   'Firefox',
#   'Firefox 1.0',
#   'Netscape',
#   'late 2004',
#   'the Mozilla Foundation'},
#  {'HTML', 'XHTML'},
#  {'HTTPS',
#   'URI',
#   'http://en.wikipedia.org/',
#   'the File Transfer Protocol',
#   'the Hypertext Transfer Protocol',
#   'the Uniform Resource Identifier'},
#  {'1998',
#   '28%',
#   '7%',
#   'August 2011',
#   'Firefox',
#   'Firefox 1.0',
#   'Netscape',
#   'late 2004',
#   'the Mozilla Foundation'},
#  {'the World Wide Web'},
#  {'1995', '2002', 'Microsoft', 'Mosaic', 'Windows', 'first', 'over 95%'},
#  {'HTTP Secure'},
#  {'1993',
#   '1993 –',
#   '1994',
#   '90%',
#   'Andreesen',
#   'Andreessen',
#   'Marc Andreessen',
#   'Mosaic',
#   'NCSA',
#   'National Center for Supercomputing Applications',
#   'Netscape',
#   'Netscape Navigator',
#   'first',
#   'the 1990s',
#   'the Mosaic-',
#   'the World Wide Web'},
#  {'JavaScript', 'UI'},
#  {'Firefox', 'Google', 'Google Chrome', 'Google Search', 'Mozilla', 'Today'},
#  set(),
#  {'URI', 'a Uniform Resource Identifier', 'the World Wide Web'},
#  {'1998',
#   '28%',
#   '7%',
#   'August 2011',
#   'Firefox',
#   'Firefox 1.0',
#   'Netscape',
#   'late 2004',
#   'the Mozilla Foundation'},
#  {'Bookmarks', 'Explorer', 'Firefox', 'Opera'},
#  {'Bookmarks', 'Explorer', 'Firefox', 'Opera'},
#  {'45%',
#   '8% to 16%',
#   'April 2014',
#   'August 2011',
#   'Chrome',
#   'December 2011',
#   'May 2012',
#   'September 2008',
#   'first',
#   'from month to month'},
#  {'HTTPS',
#   'URI',
#   'http://en.wikipedia.org/',
#   'the File Transfer Protocol',
#   'the Hypertext Transfer Protocol',
#   'the Uniform Resource Identifier'},
#  {'1993',
#   '1993 –',
#   '1994',
#   '90%',
#   'Andreesen',
#   'Andreessen',
#   'Marc Andreessen',
#   'Mosaic',
#   'NCSA',
#   'National Center for Supercomputing Applications',
#   'Netscape',
#   'Netscape Navigator',
#   'first',
#   'the 1990s',
#   'the Mosaic-',
#   'the World Wide Web'},
#  {'the World Wide Web'},
#  {'Apple', 'Mobile Safari', 'OS X', 'Safari', 'iOS'},
#  {'Apple', 'Mobile Safari', 'OS X', 'Safari', 'iOS'},
#  {'CSS', 'HTML', 'Java', 'XML'},
#  {'1995', '2002', 'Microsoft', 'Mosaic', 'Windows', 'first', 'over 95%'},
#  {'HTTPS',
#   'URI',
#   'http://en.wikipedia.org/',
#   'the File Transfer Protocol',
#   'the Hypertext Transfer Protocol',
#   'the Uniform Resource Identifier'},
#  set(),
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'April 12',
#   'April 15',
#   'BBC',
#   'Beijing',
#   'CPC',
#   'Carrefour',
#   'China',
#   'Chinese',
#   'French',
#   'Hefei',
#   'Hu Jintao',
#   'Kunming',
#   'Liu Yandong',
#   'May 1',
#   'Nazism',
#   'Politburo Standing Committee',
#   'Qingdao',
#   'Sohu.com',
#   'State',
#   'Swastika',
#   'Wuhan',
#   'Zhou Yongkang',
#   'first',
#   'hundreds',
#   'the LVMH Group',
#   'the Washington Times',
#   'the weekend'},
#  {'Chinese', 'Jin Jing', 'Western'},
#  {'2 am',
#   'Beijing',
#   'Chinese',
#   'Commerce',
#   'Delhi',
#   'India',
#   'Indian',
#   'Kamal Nath',
#   'Nath',
#   'New Delhi',
#   'Nirupama',
#   'Republic Day celebrations',
#   'the Foreign Ministry'},
#  {'15 minutes',
#   '37 mile per hour',
#   '5',
#   '65 kilometre per hour',
#   '72 centimetres',
#   '985 grams',
#   'Chinese',
#   'Lenovo Group',
#   'Lucky Cloud',
#   'The Olympic Torch',
#   'Torch',
#   'up to 50 millimetres (2 inches'},
#  {'April 15',
#   'April 16',
#   'Bollywood',
#   'Chinese',
#   'Delhi',
#   'Indian',
#   'Indian Police Service',
#   'Kiran Bedi',
#   'Soha Ali Khan',
#   'Tibet'},
#  {'1.9 mi',
#   '2 pm PDT',
#   '20:17 UTC',
#   '21:00',
#   'AT&T Park',
#   'American',
#   'Andrew Michael',
#   'China',
#   'Chinese',
#   'Darfur',
#   'International Olympic Committee',
#   'Jacques Rogge',
#   'Justin Herman Plaza',
#   'London',
#   'Majora Carter',
#   'Marina district',
#   'Mercury News',
#   'Paris',
#   'Partnerships For Change',
#   'San Francisco',
#   'San Francisco International Airport',
#   "San Francisco's",
#   'San Jose',
#   'Sustainable Development',
#   'Tibet',
#   'Tibetan',
#   'Two',
#   'Van Ness Avenue',
#   'Waldo',
#   'Where',
#   'about 1:17 pm PDT',
#   'about 3 km',
#   'between thousands',
#   'first',
#   'half-an-hour',
#   'the Bay Area Council',
#   'the Chinese Consulate',
#   'two'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'April 4', 'Beijing', 'CNN', 'Chinese'},
#  {'Australians',
#   'BBC',
#   'BBC CNN',
#   'Beijing',
#   'CNN',
#   'China',
#   'Chinese',
#   'Fu Ying',
#   'Libération',
#   'One',
#   'Sydney',
#   'Telegraph',
#   'The Daily Telegraph',
#   'Tibet',
#   'West',
#   'Western',
#   'the United Kingdom'},
#  {'20 km',
#   'April 5',
#   'MMA',
#   'Russia',
#   'Saint Petersburg',
#   'first',
#   'the Palace Square',
#   'the Victory Square'},
#  {'1989',
#   'April 26, 2008',
#   'Cheung Man Kwong',
#   'China',
#   'Color Orange',
#   'Danish',
#   'Darfur',
#   'Farrow',
#   'Galschiøt',
#   'Hollywood',
#   'Hong Kong',
#   "Hong Kong's",
#   'Jens Galschiøt',
#   'Lee Cheuk Yan',
#   'Mia Farrow',
#   'Patriotic Democratic Movements',
#   'Sudan',
#   'Tiananmen Square',
#   'one',
#   'the "Pillar of Shame"',
#   'the Hong Kong Alliance',
#   'two'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'20 km',
#   'April 5',
#   'MMA',
#   'Russia',
#   'Saint Petersburg',
#   'first',
#   'the Palace Square',
#   'the Victory Square'},
#  {'1000',
#   '16.5 km',
#   '1964',
#   'April 21',
#   'Independence Square',
#   'KL Tower',
#   'Kuala Lumpur',
#   'Malaysia',
#   'Malaysian',
#   'Merdeka Stadium',
#   'National Mosque',
#   'Petronas Twin Towers',
#   'Special Action Squad',
#   'Tokyo',
#   'the Parliament House'},
#  {'Aboriginal',
#   'Agnes Shea',
#   'April 24',
#   'Australia',
#   'Australian',
#   'Australian Capital Territory',
#   'Canberra',
#   'Chinese',
#   'Hundreds',
#   'Ngunnawal',
#   'Tibet',
#   'around 16 km',
#   'the Australian Federal Police',
#   'thousands'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'20 km',
#   'April 5',
#   'MMA',
#   'Russia',
#   'Saint Petersburg',
#   'first',
#   'the Palace Square',
#   'the Victory Square'},
#  {'China', 'Lin Hatfield Dodds', 'Stephen Smith'},
#  {'April 12',
#   'April 15',
#   'BBC',
#   'Beijing',
#   'CPC',
#   'Carrefour',
#   'China',
#   'Chinese',
#   'French',
#   'Hefei',
#   'Hu Jintao',
#   'Kunming',
#   'Liu Yandong',
#   'May 1',
#   'Nazism',
#   'Politburo Standing Committee',
#   'Qingdao',
#   'Sohu.com',
#   'State',
#   'Swastika',
#   'Wuhan',
#   'Zhou Yongkang',
#   'first',
#   'hundreds',
#   'the LVMH Group',
#   'the Washington Times',
#   'the weekend'},
#  {'Chinese',
#   'France',
#   'French',
#   'Libération',
#   'Michèle Alliot-Marie',
#   'Tibetan',
#   'Trocadéro'},
#  {'ACCO',
#   'Australian',
#   'Beijing',
#   'Canberra',
#   'China',
#   'Chinese',
#   'Chinese Australian',
#   'Olympia',
#   "People's Liberation Army",
#   'Stephen Smith',
#   'Tony Goh',
#   'Zhang Rongan',
#   'the Australian Council of Chinese Organisations',
#   'the Chinese Students and Scholars Association',
#   'thousands'},
#  {'20 km',
#   'April 5',
#   'MMA',
#   'Russia',
#   'Saint Petersburg',
#   'first',
#   'the Palace Square',
#   'the Victory Square'},
#  {'Notre Dame', 'the Eiffel Tower'},
#  {'April 1, 2008',
#   'April 8',
#   'April 9',
#   'Beijing Olympic',
#   'China',
#   'Desmond Tutu',
#   'Richard Gere',
#   'San Francisco',
#   'Tibet',
#   'United Nations Plaza',
#   'one',
#   'the San Francisco Board of Supervisors'},
#  {'April 18',
#   'Bangkok',
#   'Beijing',
#   'China',
#   'Chinese',
#   'Chitralada Palace',
#   'Democracy Monument',
#   'GWF',
#   'Green World Foundation',
#   'Narisa Chakrabongse',
#   'Olympic',
#   'Rajawongse Narissara Chakrabongse',
#   'Several hundred',
#   'Thai',
#   'Thailand',
#   'Tibet',
#   'first',
#   'just over 10 km',
#   'several hundred'},
#  {'Buddhist',
#   'Europe',
#   'Japan',
#   'Nagano',
#   'Nagano City',
#   'Shoichi Washizawa',
#   'Tibet',
#   'Washizawa',
#   'the Nagano City Office',
#   'the day'},
#  {'1989',
#   'April 26, 2008',
#   'Cheung Man Kwong',
#   'China',
#   'Color Orange',
#   'Danish',
#   'Darfur',
#   'Farrow',
#   'Galschiøt',
#   'Hollywood',
#   'Hong Kong',
#   "Hong Kong's",
#   'Jens Galschiøt',
#   'Lee Cheuk Yan',
#   'Mia Farrow',
#   'Patriotic Democratic Movements',
#   'Sudan',
#   'Tiananmen Square',
#   'one',
#   'the "Pillar of Shame"',
#   'the Hong Kong Alliance',
#   'two'},
#  {'April 16',
#   'China',
#   'Islamabad',
#   'Jinnah Stadium',
#   'Pakistan',
#   'Pervez Musharraf',
#   'Yousaf Raza Gillani',
#   'first',
#   'thousands'},
#  {'CCTV',
#   'Games',
#   'Marie-José Pérec',
#   'The Beijing Organising Committee',
#   'Western',
#   'Xinhua'},
#  {'10 Downing Street',
#   '80',
#   'BBC',
#   'Beijing Olympics',
#   'China',
#   'Chinese',
#   'Fleet Street',
#   'Francesca Martinez',
#   'Gordon Brown',
#   'Konnie Huq',
#   'Ladbroke Grove',
#   'London',
#   'Norman Baker',
#   'One',
#   'One World',
#   'Parliament',
#   'Redgrave',
#   'Richard Vaughan',
#   'Steve Redgrave',
#   'Tibet',
#   'Tibetan',
#   'Trafalgar Square',
#   'more than 2,000',
#   'the 2008',
#   'thirty-five'},
#  {'130 days',
#   '137,000 km',
#   '21',
#   '85,000 mi',
#   'A330',
#   'Air China',
#   'Airbus',
#   'B-6075',
#   'March 2008',
#   'the Beijing Committees of the Olympic Game',
#   'the Olympic Games'},
#  {'April 12',
#   'April 15',
#   'BBC',
#   'Beijing',
#   'CPC',
#   'Carrefour',
#   'China',
#   'Chinese',
#   'French',
#   'Hefei',
#   'Hu Jintao',
#   'Kunming',
#   'Liu Yandong',
#   'May 1',
#   'Nazism',
#   'Politburo Standing Committee',
#   'Qingdao',
#   'Sohu.com',
#   'State',
#   'Swastika',
#   'Wuhan',
#   'Zhou Yongkang',
#   'first',
#   'hundreds',
#   'the LVMH Group',
#   'the Washington Times',
#   'the weekend'},
#  {'2012',
#   '30 mi',
#   '48 km',
#   '750,000',
#   'April 6',
#   'Arena',
#   'Beijing Organising Committee',
#   'Chinese',
#   'Coe',
#   'Great Britain',
#   'Jacqui Smith',
#   'Ken Livingstone',
#   'London',
#   'Metropolitan',
#   'O2',
#   'Summer Olympics',
#   'Tibetan',
#   'Wembley Stadium',
#   'seven and a half hours',
#   'the City of London',
#   'the London Olympic Committee'},
#  {'North Korea', 'The United Nations Organization', 'UN', 'UNICEF'},
#  {'2012',
#   '30 mi',
#   '48 km',
#   '750,000',
#   'April 6',
#   'Arena',
#   'Beijing Organising Committee',
#   'Chinese',
#   'Coe',
#   'Great Britain',
#   'Jacqui Smith',
#   'Ken Livingstone',
#   'London',
#   'Metropolitan',
#   'O2',
#   'Summer Olympics',
#   'Tibetan',
#   'Wembley Stadium',
#   'seven and a half hours',
#   'the City of London',
#   'the London Olympic Committee'},
#  {'Beijing', 'Chinese', 'French', 'Libération', 'Western', 'Xinhua'},
#  {'Australians',
#   'BBC',
#   'BBC CNN',
#   'Beijing',
#   'CNN',
#   'China',
#   'Chinese',
#   'Fu Ying',
#   'Libération',
#   'One',
#   'Sydney',
#   'Telegraph',
#   'The Daily Telegraph',
#   'Tibet',
#   'West',
#   'Western',
#   'the United Kingdom'},
#  {'1200',
#   '3000',
#   'Buenos Aires',
#   'Chinese',
#   'Diego Maradona',
#   'France',
#   'Friends of Falun',
#   'HRTR',
#   'Mark Palmer',
#   'NED',
#   'Susan Prager',
#   'Tom Lanto',
#   'UK',
#   'US'},
#  {'19-kilometre',
#   '1966',
#   'April 28',
#   'Beijing',
#   'China',
#   'Chinese',
#   'Juche',
#   'Kim',
#   'Kim Il Sung',
#   'Kim Jong Il',
#   'Kim Yong Nam',
#   'North',
#   'North Korea',
#   "North Korea's",
#   'Pak Du Ik',
#   'Pyongyang',
#   'Tibet',
#   'World Cup',
#   'first',
#   'the Beijing Olympics',
#   'the Juche Tower',
#   'thousands'},
#  {'Australians',
#   'BBC',
#   'BBC CNN',
#   'Beijing',
#   'CNN',
#   'China',
#   'Chinese',
#   'Fu Ying',
#   'Libération',
#   'One',
#   'Sydney',
#   'Telegraph',
#   'The Daily Telegraph',
#   'Tibet',
#   'West',
#   'Western',
#   'the United Kingdom'},
#  {'Argentine',
#   'Buenos Aires',
#   'China',
#   'Jorge Carcavallo',
#   'London',
#   'Paris',
#   'Tibet',
#   'the Olympic Games'},
#  {'Athens',
#   'Beijing',
#   'China',
#   'Chinese',
#   'Greece',
#   'March 24',
#   'March 31',
#   'Mount Everest',
#   'Nepal',
#   'Olympia',
#   'Tibet',
#   'six',
#   'the Olympic Games',
#   'the Panathinaiko Stadium',
#   'the Silk Road'},
#  {'American',
#   'Beijing Olympic website',
#   'Canberra',
#   'China',
#   'Chinese',
#   'France',
#   'Hanoi',
#   'Lê Minh Phiếu',
#   'Nguyễn Văn Hải',
#   'Olympics',
#   'One day',
#   'Paris',
#   'San Francisco',
#   'Vietnam',
#   'Vietnamese',
#   'seven',
#   'the Beijing Olympics',
#   'the International Olympic Committee',
#   'the South China Sea',
#   'Điếu Cày'},
#  {'April 3',
#   'Chinese',
#   'Istanbul',
#   'Sultanahmet Square',
#   'Taksim Square',
#   'Turkey',
#   'Uyghurs',
#   'Xinjiang'},
#  {'Beijing', 'Chinese', 'French', 'Libération', 'Western', 'Xinhua'},
#  {'120',
#   'A-Ma Temple',
#   'Fisherman',
#   'Leong Heng Teng',
#   'Leong Hong Man',
#   'Macanese',
#   'Macao',
#   'Macao Daily News',
#   'Macau',
#   'Macau Cultural Centre',
#   "Macau Fisherman's",
#   'Macau Stadium',
#   'Macau Tower',
#   'May 3',
#   'Ponte Governador Nobre de Carvalho',
#   'Ponte de Sai Van',
#   "Ruins of St. Paul's",
#   'Stanley Ho',
#   'Taipa',
#   'first'},
#  {'American',
#   'Beijing Olympic website',
#   'Canberra',
#   'China',
#   'Chinese',
#   'France',
#   'Hanoi',
#   'Lê Minh Phiếu',
#   'Nguyễn Văn Hải',
#   'Olympics',
#   'One day',
#   'Paris',
#   'San Francisco',
#   'Vietnam',
#   'Vietnamese',
#   'seven',
#   'the Beijing Olympics',
#   'the International Olympic Committee',
#   'the South China Sea',
#   'Điếu Cày'},
#  {'2012',
#   '30 mi',
#   '48 km',
#   '750,000',
#   'April 6',
#   'Arena',
#   'Beijing Organising Committee',
#   'Chinese',
#   'Coe',
#   'Great Britain',
#   'Jacqui Smith',
#   'Ken Livingstone',
#   'London',
#   'Metropolitan',
#   'O2',
#   'Summer Olympics',
#   'Tibetan',
#   'Wembley Stadium',
#   'seven and a half hours',
#   'the City of London',
#   'the London Olympic Committee'},
#  {'-Kiran Bedi',
#   '70',
#   'Aamir Khan',
#   'April 17',
#   'Baichung Bhutia',
#   'Bhaichung Bhutia',
#   'Bhutia',
#   'China',
#   'Congress',
#   'Gandhi',
#   'India',
#   'Indian',
#   'Nehru',
#   'New Delhi',
#   'PRC',
#   'Rahul Gandhi',
#   'Sachin Tendulkar',
#   'Sikkimese',
#   'Soha Ali Khan',
#   'Sonia Gandhi',
#   'Sunil Gavaskar-',
#   'Tibet',
#   'first',
#   'five',
#   'just 2.3 km',
#   'less than 1.5 miles',
#   'the "Olympic Games',
#   'the India Gate'},
#  {'Chinese', 'Jin Jing', 'Western'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'150,000-strong Tibetan',
#   '3 km',
#   'China',
#   'Chinese',
#   'India',
#   'Indian',
#   'Tibetan',
#   'the "Olympic Holy Flame Protection Unit"'},
#  {'April 4', 'Beijing', 'CNN', 'Chinese'},
#  {'Australians',
#   'BBC',
#   'BBC CNN',
#   'Beijing',
#   'CNN',
#   'China',
#   'Chinese',
#   'Fu Ying',
#   'Libération',
#   'One',
#   'Sydney',
#   'Telegraph',
#   'The Daily Telegraph',
#   'Tibet',
#   'West',
#   'Western',
#   'the United Kingdom'},
#  {'2012',
#   '30 mi',
#   '48 km',
#   '750,000',
#   'April 6',
#   'Arena',
#   'Beijing Organising Committee',
#   'Chinese',
#   'Coe',
#   'Great Britain',
#   'Jacqui Smith',
#   'Ken Livingstone',
#   'London',
#   'Metropolitan',
#   'O2',
#   'Summer Olympics',
#   'Tibetan',
#   'Wembley Stadium',
#   'seven and a half hours',
#   'the City of London',
#   'the London Olympic Committee'},
#  {'13.8 km',
#   'April 11',
#   'Argentina',
#   'Argentines',
#   'Buenos',
#   'Carlos Espínola',
#   'Chinese',
#   'Costanera Sur',
#   'Gabriela Sabatini',
#   'Latin American',
#   'Lola Mora',
#   'Mauricio Macri',
#   'Olympic',
#   'Palermo',
#   'Plaza de Mayo',
#   'The day',
#   'Tibet',
#   'first',
#   'five',
#   'half-day',
#   'nearly a week',
#   'the Buenos Aires Riding Club',
#   'the Games',
#   'thousands'},
#  {'20 km',
#   'April 22',
#   'Chinese',
#   'Indonesia',
#   'Islamabad',
#   'Jakarta',
#   'Several dozen',
#   'Tibet'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'China', 'Lin Hatfield Dodds', 'Stephen Smith'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'ACCO',
#   'Australian',
#   'Beijing',
#   'Canberra',
#   'China',
#   'Chinese',
#   'Chinese Australian',
#   'Olympia',
#   "People's Liberation Army",
#   'Stephen Smith',
#   'Tony Goh',
#   'Zhang Rongan',
#   'the Australian Council of Chinese Organisations',
#   'the Chinese Students and Scholars Association',
#   'thousands'},
#  {'1200',
#   '3000',
#   'Buenos Aires',
#   'Chinese',
#   'Diego Maradona',
#   'France',
#   'Friends of Falun',
#   'HRTR',
#   'Mark Palmer',
#   'NED',
#   'Susan Prager',
#   'Tom Lanto',
#   'UK',
#   'US'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'1000',
#   '16.5 km',
#   '1964',
#   'April 21',
#   'Independence Square',
#   'KL Tower',
#   'Kuala Lumpur',
#   'Malaysia',
#   'Malaysian',
#   'Merdeka Stadium',
#   'National Mosque',
#   'Petronas Twin Towers',
#   'Special Action Squad',
#   'Tokyo',
#   'the Parliament House'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'1992',
#   'Aaron Peskin',
#   'April 9',
#   'Buenos Aires',
#   'CBS',
#   'California',
#   'China',
#   'Chinese',
#   'Gavin Newsom',
#   'Heather Fong',
#   'Justin Herman Plaza',
#   'Lin Li',
#   'NBC',
#   'Newsom',
#   'Norman Bellingham',
#   'North American',
#   'One',
#   'Peter Ueberroth',
#   'San Francisco',
#   'San Francisco Board of Supervisors',
#   'San Francisco International Airport',
#   'USD $726,400',
#   'United States of America',
#   'first',
#   'nearly half',
#   'the Bush State Department',
#   'the U.S. Olympic Committee',
#   'the day'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'Angel in Wheelchair',
#   'Chinese',
#   'France',
#   'Green Party',
#   'Jin Jing',
#   'Paris',
#   'Tibet',
#   'Tibetan',
#   'the City Hall',
#   'third'},
#  {'15 minutes',
#   '37 mile per hour',
#   '5',
#   '65 kilometre per hour',
#   '72 centimetres',
#   '985 grams',
#   'Chinese',
#   'Lenovo Group',
#   'Lucky Cloud',
#   'The Olympic Torch',
#   'Torch',
#   'up to 50 millimetres (2 inches'},
#  {'1989',
#   'April 26, 2008',
#   'Cheung Man Kwong',
#   'China',
#   'Color Orange',
#   'Danish',
#   'Darfur',
#   'Farrow',
#   'Galschiøt',
#   'Hollywood',
#   'Hong Kong',
#   "Hong Kong's",
#   'Jens Galschiøt',
#   'Lee Cheuk Yan',
#   'Mia Farrow',
#   'Patriotic Democratic Movements',
#   'Sudan',
#   'Tiananmen Square',
#   'one',
#   'the "Pillar of Shame"',
#   'the Hong Kong Alliance',
#   'two'},
#  {'130 days',
#   '137,000 km',
#   '21',
#   '85,000 mi',
#   'A330',
#   'Air China',
#   'Airbus',
#   'B-6075',
#   'March 2008',
#   'the Beijing Committees of the Olympic Game',
#   'the Olympic Games'},
#  {'China',
#   'French',
#   'Jane Birkin',
#   'Several hundred',
#   'Thupten Gyatso',
#   'Tibet',
#   'Tibetan',
#   'Trocadéro'},
#  {'20 km',
#   'April 14',
#   'Muscat',
#   'Oman',
#   'One',
#   'Sulaf Fawakherji',
#   'Syrian',
#   'the Middle East'},
#  {'ACT',
#   'April 24, 2008',
#   'At least five',
#   'Australia',
#   'Australian',
#   'Canberra',
#   'China',
#   'Chinese',
#   'Ian Thorpe',
#   'Jon Stanhope',
#   'Olympic',
#   'One',
#   'Ted Quinlan',
#   'Tibet',
#   'Tibetan',
#   'Up to 600',
#   'between 2,000 and 10,000',
#   'five',
#   'one',
#   'the day'},
#  {'CCTV',
#   'Games',
#   'Marie-José Pérec',
#   'The Beijing Organising Committee',
#   'Western',
#   'Xinhua'},
#  {'1989',
#   'April 26, 2008',
#   'Cheung Man Kwong',
#   'China',
#   'Color Orange',
#   'Danish',
#   'Darfur',
#   'Farrow',
#   'Galschiøt',
#   'Hollywood',
#   'Hong Kong',
#   "Hong Kong's",
#   'Jens Galschiøt',
#   'Lee Cheuk Yan',
#   'Mia Farrow',
#   'Patriotic Democratic Movements',
#   'Sudan',
#   'Tiananmen Square',
#   'one',
#   'the "Pillar of Shame"',
#   'the Hong Kong Alliance',
#   'two'},
#  {'1000',
#   '16.5 km',
#   '1964',
#   'April 21',
#   'Independence Square',
#   'KL Tower',
#   'Kuala Lumpur',
#   'Malaysia',
#   'Malaysian',
#   'Merdeka Stadium',
#   'National Mosque',
#   'Petronas Twin Towers',
#   'Special Action Squad',
#   'Tokyo',
#   'the Parliament House'},
#  {'1707',
#   '1998',
#   'April 26',
#   'Buddhist',
#   'China',
#   'Chinese',
#   'Five',
#   'Japan',
#   'Japanese',
#   'More than 100',
#   'Nagano',
#   'Only two',
#   'Thousands',
#   'Tibet',
#   'Tibetan',
#   'Winter Olympics',
#   'Zenkoji',
#   'Zenkō-ji',
#   'Zenkō-ji Hondō',
#   'four',
#   'the Minami Nagano Sports Park',
#   'the National Treasures of Japan',
#   'three'},
#  {'2005',
#   '5 km',
#   'About a thousand',
#   'Africa',
#   'Ali Mohamed Shein',
#   'April 13',
#   'China',
#   'Chinese',
#   'Dar es Salaam',
#   'Nobel Peace Prize',
#   'Tanzania',
#   'Temeke',
#   'Tibet',
#   "Wangari Maathai's",
#   'the 1970s',
#   'the Benjamin Mkapa National Stadium',
#   'the TAZARA Railway'},
#  {'120',
#   '3,000',
#   'Beijing',
#   'Chinese',
#   'Donald Tsang',
#   'Golden Bauhinia Square',
#   'Henry Tang',
#   'Hong Kong',
#   'Lantau',
#   'Lee Lai Shan',
#   'May 2',
#   'Nathan Road',
#   'One',
#   'Sha Tin',
#   'Shing Mun River',
#   'Tin Hau',
#   'Tsim Sha Tsui',
#   'Victoria Harbour',
#   'Wan Chai',
#   'first',
#   'more than 200,000',
#   'the Hong Kong Cultural Centre',
#   'the Marine Department'},
#  {'1707',
#   '1998',
#   'April 26',
#   'Buddhist',
#   'China',
#   'Chinese',
#   'Five',
#   'Japan',
#   'Japanese',
#   'More than 100',
#   'Nagano',
#   'Only two',
#   'Thousands',
#   'Tibet',
#   'Tibetan',
#   'Winter Olympics',
#   'Zenkoji',
#   'Zenkō-ji',
#   'Zenkō-ji Hondō',
#   'four',
#   'the Minami Nagano Sports Park',
#   'the National Treasures of Japan',
#   'three'},
#  {'1989',
#   'April 26, 2008',
#   'Cheung Man Kwong',
#   'China',
#   'Color Orange',
#   'Danish',
#   'Darfur',
#   'Farrow',
#   'Galschiøt',
#   'Hollywood',
#   'Hong Kong',
#   "Hong Kong's",
#   'Jens Galschiøt',
#   'Lee Cheuk Yan',
#   'Mia Farrow',
#   'Patriotic Democratic Movements',
#   'Sudan',
#   'Tiananmen Square',
#   'one',
#   'the "Pillar of Shame"',
#   'the Hong Kong Alliance',
#   'two'},
#  {'Beijing', 'Chinese', 'French', 'Libération', 'Western', 'Xinhua'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'5-year-old',
#   'As many as 1,000',
#   'China',
#   'Chinese',
#   'Falun Gong',
#   'Independence Square',
#   'Japanese',
#   'Just days',
#   'Malaysian',
#   'Malaysians',
#   'One',
#   'Taiwan',
#   'Tibet',
#   'Tibetan',
#   'the day',
#   'two'},
#  {'1988',
#   '2,500',
#   '24-kilometre',
#   '4.5 hour',
#   '500',
#   'Apr 29',
#   'April 27',
#   'China',
#   'Chinese',
#   'Choi Seung-kook',
#   'DPRK',
#   'Justice',
#   'Kim Kyung Han',
#   'Korean',
#   'Ministry of Foreign Affairs',
#   'More than 8,000',
#   'National Intelligence Service',
#   'National Police Agency',
#   'North Korean',
#   'Olympic Park',
#   'Olympics',
#   'One',
#   'Park Won-sun',
#   "Prosecutor's Office",
#   'Seoul',
#   'South Korea',
#   "South Korea's",
#   'Summer Games',
#   'Summer Olympics',
#   'Thousands',
#   'Tibet',
#   'Two',
#   'approximately 50',
#   'five',
#   'the day'},
#  {'120',
#   'A-Ma Temple',
#   'Fisherman',
#   'Leong Heng Teng',
#   'Leong Hong Man',
#   'Macanese',
#   'Macao',
#   'Macao Daily News',
#   'Macau',
#   'Macau Cultural Centre',
#   "Macau Fisherman's",
#   'Macau Stadium',
#   'Macau Tower',
#   'May 3',
#   'Ponte Governador Nobre de Carvalho',
#   'Ponte de Sai Van',
#   "Ruins of St. Paul's",
#   'Stanley Ho',
#   'Taipa',
#   'first'},
#  {'China',
#   'French',
#   'Jane Birkin',
#   'Several hundred',
#   'Thupten Gyatso',
#   'Tibet',
#   'Tibetan',
#   'Trocadéro'},
#  {'2 am',
#   'Beijing',
#   'Chinese',
#   'Commerce',
#   'Delhi',
#   'India',
#   'Indian',
#   'Kamal Nath',
#   'Nath',
#   'New Delhi',
#   'Nirupama',
#   'Republic Day celebrations',
#   'the Foreign Ministry'},
#  {'Chinese', "the People's Daily"},
#  {'129 days',
#   '137,000 km',
#   '1936',
#   '2008',
#   '85,000 mi',
#   'April 26, 2007',
#   'August 8, 2008',
#   'Beijing',
#   'China',
#   'Journey of Harmony',
#   'March 24',
#   'Summer Olympics',
#   'one'},
#  {'April 29',
#   'China',
#   'Chinese',
#   'Competition Hall',
#   'December 2007',
#   'Dũng',
#   'Hanoi',
#   'Ho Chi Minh City',
#   'Nguyễn Tấn',
#   'Opera House',
#   'Paracel Islands',
#   'Sansha',
#   'Some 60',
#   'Spratly',
#   'Tan Son Nhat International Airport',
#   'Vietnam',
#   'Vietnamese',
#   'the Military Zone'},
#  {'China',
#   'Chinese',
#   'European',
#   'North American',
#   'Paris',
#   'Pyongyang',
#   'San Francisco',
#   'Tibetan',
#   'hundreds'},
#  {'1707',
#   '1998',
#   'April 26',
#   'Buddhist',
#   'China',
#   'Chinese',
#   'Five',
#   'Japan',
#   'Japanese',
#   'More than 100',
#   'Nagano',
#   'Only two',
#   'Thousands',
#   'Tibet',
#   'Tibetan',
#   'Winter Olympics',
#   'Zenkoji',
#   'Zenkō-ji',
#   'Zenkō-ji Hondō',
#   'four',
#   'the Minami Nagano Sports Park',
#   'the National Treasures of Japan',
#   'three'},
#  {'April 29',
#   'China',
#   'Chinese',
#   'Competition Hall',
#   'December 2007',
#   'Dũng',
#   'Hanoi',
#   'Ho Chi Minh City',
#   'Nguyễn Tấn',
#   'Opera House',
#   'Paracel Islands',
#   'Sansha',
#   'Some 60',
#   'Spratly',
#   'Tan Son Nhat International Airport',
#   'Vietnam',
#   'Vietnamese',
#   'the Military Zone'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'-Kiran Bedi',
#   '70',
#   'Aamir Khan',
#   'April 17',
#   'Baichung Bhutia',
#   'Bhaichung Bhutia',
#   'Bhutia',
#   'China',
#   'Congress',
#   'Gandhi',
#   'India',
#   'Indian',
#   'Nehru',
#   'New Delhi',
#   'PRC',
#   'Rahul Gandhi',
#   'Sachin Tendulkar',
#   'Sikkimese',
#   'Soha Ali Khan',
#   'Sonia Gandhi',
#   'Sunil Gavaskar-',
#   'Tibet',
#   'first',
#   'five',
#   'just 2.3 km',
#   'less than 1.5 miles',
#   'the "Olympic Games',
#   'the India Gate'},
#  {'Chinese', "the People's Daily"},
#  {'Abhinav Bindra',
#   'Ayaan Ali Khan',
#   'Bhaichung Bhutia',
#   'Chinese',
#   'Delhi',
#   'Indian',
#   'Kiran Bedi',
#   'Manavjit Singh Sandhu',
#   'Olympics',
#   'Rajinder Singh Rahelu',
#   'Sachin Tendulkar',
#   'Soha Ali Khan'},
#  {'Beijing', 'Chinese', 'French', 'Libération', 'Western', 'Xinhua'},
#  {'American',
#   'Beijing Olympic website',
#   'Canberra',
#   'China',
#   'Chinese',
#   'France',
#   'Hanoi',
#   'Lê Minh Phiếu',
#   'Nguyễn Văn Hải',
#   'Olympics',
#   'One day',
#   'Paris',
#   'San Francisco',
#   'Vietnam',
#   'Vietnamese',
#   'seven',
#   'the Beijing Olympics',
#   'the International Olympic Committee',
#   'the South China Sea',
#   'Điếu Cày'},
#  {'129 days',
#   '137,000 km',
#   '1936',
#   '2008',
#   '85,000 mi',
#   'April 26, 2007',
#   'August 8, 2008',
#   'Beijing',
#   'China',
#   'Journey of Harmony',
#   'March 24',
#   'Summer Olympics',
#   'one'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'Chinese',
#   'France',
#   'French',
#   'Libération',
#   'Michèle Alliot-Marie',
#   'Tibetan',
#   'Trocadéro'},
#  {'24 km',
#   'August 2008',
#   'Beijing',
#   'China',
#   'Chinese',
#   'Ho Chi Minh City',
#   'Hong Kong',
#   'Macau',
#   'March 2008',
#   'May 2008',
#   'September 21, 2007',
#   'Taipei',
#   'Taiwan',
#   'The Beijing Organizing Committee',
#   'midnight',
#   'six',
#   'the Republic of China',
#   'the Taiwan Strait',
#   'the Torch Relay'},
#  {'1000',
#   '16.5 km',
#   '1964',
#   'April 21',
#   'Independence Square',
#   'KL Tower',
#   'Kuala Lumpur',
#   'Malaysia',
#   'Malaysian',
#   'Merdeka Stadium',
#   'National Mosque',
#   'Petronas Twin Towers',
#   'Special Action Squad',
#   'Tokyo',
#   'the Parliament House'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'20 km',
#   'April 5',
#   'MMA',
#   'Russia',
#   'Saint Petersburg',
#   'first',
#   'the Palace Square',
#   'the Victory Square'},
#  {'10 Downing Street',
#   '80',
#   'BBC',
#   'Beijing Olympics',
#   'China',
#   'Chinese',
#   'Fleet Street',
#   'Francesca Martinez',
#   'Gordon Brown',
#   'Konnie Huq',
#   'Ladbroke Grove',
#   'London',
#   'Norman Baker',
#   'One',
#   'One World',
#   'Parliament',
#   'Redgrave',
#   'Richard Vaughan',
#   'Steve Redgrave',
#   'Tibet',
#   'Tibetan',
#   'Trafalgar Square',
#   'more than 2,000',
#   'the 2008',
#   'thirty-five'},
#  {'1.9 mi',
#   '2 pm PDT',
#   '20:17 UTC',
#   '21:00',
#   'AT&T Park',
#   'American',
#   'Andrew Michael',
#   'China',
#   'Chinese',
#   'Darfur',
#   'International Olympic Committee',
#   'Jacques Rogge',
#   'Justin Herman Plaza',
#   'London',
#   'Majora Carter',
#   'Marina district',
#   'Mercury News',
#   'Paris',
#   'Partnerships For Change',
#   'San Francisco',
#   'San Francisco International Airport',
#   "San Francisco's",
#   'San Jose',
#   'Sustainable Development',
#   'Tibet',
#   'Tibetan',
#   'Two',
#   'Van Ness Avenue',
#   'Waldo',
#   'Where',
#   'about 1:17 pm PDT',
#   'about 3 km',
#   'between thousands',
#   'first',
#   'half-an-hour',
#   'the Bay Area Council',
#   'the Chinese Consulate',
#   'two'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'1.9 mi',
#   '2 pm PDT',
#   '20:17 UTC',
#   '21:00',
#   'AT&T Park',
#   'American',
#   'Andrew Michael',
#   'China',
#   'Chinese',
#   'Darfur',
#   'International Olympic Committee',
#   'Jacques Rogge',
#   'Justin Herman Plaza',
#   'London',
#   'Majora Carter',
#   'Marina district',
#   'Mercury News',
#   'Paris',
#   'Partnerships For Change',
#   'San Francisco',
#   'San Francisco International Airport',
#   "San Francisco's",
#   'San Jose',
#   'Sustainable Development',
#   'Tibet',
#   'Tibetan',
#   'Two',
#   'Van Ness Avenue',
#   'Waldo',
#   'Where',
#   'about 1:17 pm PDT',
#   'about 3 km',
#   'between thousands',
#   'first',
#   'half-an-hour',
#   'the Bay Area Council',
#   'the Chinese Consulate',
#   'two'},
#  {'Australians',
#   'BBC',
#   'BBC CNN',
#   'Beijing',
#   'CNN',
#   'China',
#   'Chinese',
#   'Fu Ying',
#   'Libération',
#   'One',
#   'Sydney',
#   'Telegraph',
#   'The Daily Telegraph',
#   'Tibet',
#   'West',
#   'Western',
#   'the United Kingdom'},
#  {'1200',
#   '3000',
#   'Buenos Aires',
#   'Chinese',
#   'Diego Maradona',
#   'France',
#   'Friends of Falun',
#   'HRTR',
#   'Mark Palmer',
#   'NED',
#   'Susan Prager',
#   'Tom Lanto',
#   'UK',
#   'US'},
#  {'2012',
#   '30 mi',
#   '48 km',
#   '750,000',
#   'April 6',
#   'Arena',
#   'Beijing Organising Committee',
#   'Chinese',
#   'Coe',
#   'Great Britain',
#   'Jacqui Smith',
#   'Ken Livingstone',
#   'London',
#   'Metropolitan',
#   'O2',
#   'Summer Olympics',
#   'Tibetan',
#   'Wembley Stadium',
#   'seven and a half hours',
#   'the City of London',
#   'the London Olympic Committee'},
#  {'North Korea', 'The United Nations Organization', 'UN', 'UNICEF'},
#  {'April',
#   'China',
#   'Chinese',
#   'Hainan',
#   'IOC',
#   'International Olympic Committee',
#   'Jackie Chan',
#   'Mainland China',
#   'May 4',
#   'Sanya',
#   'first'},
#  {'28 km',
#   'An estimated 3,000',
#   'April 7',
#   'Chinese',
#   'David Douillet',
#   'France',
#   'France 2',
#   'French',
#   'Paris',
#   'Paris City',
#   'Teddy Riner',
#   'Tibet',
#   'first',
#   'five',
#   'more than one',
#   'the Chinese Ministry of Foreign Affairs',
#   'the City Hall',
#   'the Eiffel Tower',
#   'the Stade Charléty'},
#  {'13.8 km',
#   'April 11',
#   'Argentina',
#   'Argentines',
#   'Buenos',
#   'Carlos Espínola',
#   'Chinese',
#   'Costanera Sur',
#   'Gabriela Sabatini',
#   'Latin American',
#   'Lola Mora',
#   'Mauricio Macri',
#   'Olympic',
#   'Palermo',
#   'Plaza de Mayo',
#   'The day',
#   'Tibet',
#   'first',
#   'five',
#   'half-day',
#   'nearly a week',
#   'the Buenos Aires Riding Club',
#   'the Games',
#   'thousands'},
#  {'20 km',
#   'Almaty',
#   'April 2',
#   'Astana Square',
#   'China',
#   'Kazakhstan',
#   'Medeo',
#   'Nursultan Nazarbaev',
#   'Uighur',
#   'first'},
#  {'129 days',
#   '137,000 km',
#   '1936',
#   '2008',
#   '85,000 mi',
#   'April 26, 2007',
#   'August 8, 2008',
#   'Beijing',
#   'China',
#   'Journey of Harmony',
#   'March 24',
#   'Summer Olympics',
#   'one'},
#  {'April 4', 'Beijing', 'CNN', 'Chinese'},
#  {'1000',
#   '16.5 km',
#   '1964',
#   'April 21',
#   'Independence Square',
#   'KL Tower',
#   'Kuala Lumpur',
#   'Malaysia',
#   'Malaysian',
#   'Merdeka Stadium',
#   'National Mosque',
#   'Petronas Twin Towers',
#   'Special Action Squad',
#   'Tokyo',
#   'the Parliament House'},
#  {'20 km',
#   'April 22',
#   'Chinese',
#   'Indonesia',
#   'Islamabad',
#   'Jakarta',
#   'Several dozen',
#   'Tibet'},
#  {'20 km',
#   'April 5',
#   'MMA',
#   'Russia',
#   'Saint Petersburg',
#   'first',
#   'the Palace Square',
#   'the Victory Square'},
#  {'April',
#   'China',
#   'Chinese',
#   'Hainan',
#   'IOC',
#   'International Olympic Committee',
#   'Jackie Chan',
#   'Mainland China',
#   'May 4',
#   'Sanya',
#   'first'},
#  {'30',
#   'Asian Times',
#   'August 2007',
#   'Beijing Olympic Games Sacred Flame Protection Unit',
#   'China',
#   'One',
#   'Second Right Brother',
#   'The Beijing Olympic Organizing Committee',
#   "the People's Armed Police"},
#  {'China',
#   'French',
#   'Jane Birkin',
#   'Several hundred',
#   'Thupten Gyatso',
#   'Tibet',
#   'Tibetan',
#   'Trocadéro'},
#  {'129 days',
#   '137,000 km',
#   '1936',
#   '2008',
#   '85,000 mi',
#   'April 26, 2007',
#   'August 8, 2008',
#   'Beijing',
#   'China',
#   'Journey of Harmony',
#   'March 24',
#   'Summer Olympics',
#   'one'},
#  {'1707',
#   '1998',
#   'April 26',
#   'Buddhist',
#   'China',
#   'Chinese',
#   'Five',
#   'Japan',
#   'Japanese',
#   'More than 100',
#   'Nagano',
#   'Only two',
#   'Thousands',
#   'Tibet',
#   'Tibetan',
#   'Winter Olympics',
#   'Zenkoji',
#   'Zenkō-ji',
#   'Zenkō-ji Hondō',
#   'four',
#   'the Minami Nagano Sports Park',
#   'the National Treasures of Japan',
#   'three'},
#  {'1989',
#   'April 26, 2008',
#   'Cheung Man Kwong',
#   'China',
#   'Color Orange',
#   'Danish',
#   'Darfur',
#   'Farrow',
#   'Galschiøt',
#   'Hollywood',
#   'Hong Kong',
#   "Hong Kong's",
#   'Jens Galschiøt',
#   'Lee Cheuk Yan',
#   'Mia Farrow',
#   'Patriotic Democratic Movements',
#   'Sudan',
#   'Tiananmen Square',
#   'one',
#   'the "Pillar of Shame"',
#   'the Hong Kong Alliance',
#   'two'},
#  {'April 15',
#   'April 16',
#   'Bollywood',
#   'Chinese',
#   'Delhi',
#   'Indian',
#   'Indian Police Service',
#   'Kiran Bedi',
#   'Soha Ali Khan',
#   'Tibet'},
#  {'Australians',
#   'BBC',
#   'BBC CNN',
#   'Beijing',
#   'CNN',
#   'China',
#   'Chinese',
#   'Fu Ying',
#   'Libération',
#   'One',
#   'Sydney',
#   'Telegraph',
#   'The Daily Telegraph',
#   'Tibet',
#   'West',
#   'Western',
#   'the United Kingdom'},
#  {'129 days',
#   '137,000 km',
#   '1936',
#   '2008',
#   '85,000 mi',
#   'April 26, 2007',
#   'August 8, 2008',
#   'Beijing',
#   'China',
#   'Journey of Harmony',
#   'March 24',
#   'Summer Olympics',
#   'one'},
#  {'1707',
#   '1998',
#   'April 26',
#   'Buddhist',
#   'China',
#   'Chinese',
#   'Five',
#   'Japan',
#   'Japanese',
#   'More than 100',
#   'Nagano',
#   'Only two',
#   'Thousands',
#   'Tibet',
#   'Tibetan',
#   'Winter Olympics',
#   'Zenkoji',
#   'Zenkō-ji',
#   'Zenkō-ji Hondō',
#   'four',
#   'the Minami Nagano Sports Park',
#   'the National Treasures of Japan',
#   'three'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'08',
#   'April 7, 2008',
#   'April 9',
#   'China',
#   'Chinese',
#   'Darfur',
#   'Falun Gong',
#   'KPIX-CBS5',
#   'Laurel Sutherlin',
#   'One',
#   'San Francisco',
#   'Sutherlin',
#   'Tibet',
#   'Tibetan',
#   'five',
#   'one',
#   'the Golden Gate Bridge',
#   'the International Olympic Committee',
#   'three',
#   'two',
#   'two days'},
#  {'2 am',
#   'Beijing',
#   'Chinese',
#   'Commerce',
#   'Delhi',
#   'India',
#   'Indian',
#   'Kamal Nath',
#   'Nath',
#   'New Delhi',
#   'Nirupama',
#   'Republic Day celebrations',
#   'the Foreign Ministry'},
#  {'120',
#   '3,000',
#   'Beijing',
#   'Chinese',
#   'Donald Tsang',
#   'Golden Bauhinia Square',
#   'Henry Tang',
#   'Hong Kong',
#   'Lantau',
#   'Lee Lai Shan',
#   'May 2',
#   'Nathan Road',
#   'One',
#   'Sha Tin',
#   'Shing Mun River',
#   'Tin Hau',
#   'Tsim Sha Tsui',
#   'Victoria Harbour',
#   'Wan Chai',
#   'first',
#   'more than 200,000',
#   'the Hong Kong Cultural Centre',
#   'the Marine Department'},
#  {'130 days',
#   '137,000 km',
#   '21',
#   '85,000 mi',
#   'A330',
#   'Air China',
#   'Airbus',
#   'B-6075',
#   'March 2008',
#   'the Beijing Committees of the Olympic Game',
#   'the Olympic Games'},
#  {'Buddhist',
#   'Europe',
#   'Japan',
#   'Nagano',
#   'Nagano City',
#   'Shoichi Washizawa',
#   'Tibet',
#   'Washizawa',
#   'the Nagano City Office',
#   'the day'},
#  {'150,000-strong Tibetan',
#   '3 km',
#   'China',
#   'Chinese',
#   'India',
#   'Indian',
#   'Tibetan',
#   'the "Olympic Holy Flame Protection Unit"'},
#  {'China',
#   'French',
#   'Jane Birkin',
#   'Several hundred',
#   'Thupten Gyatso',
#   'Tibet',
#   'Tibetan',
#   'Trocadéro'},
#  {'15 minutes',
#   '37 mile per hour',
#   '5',
#   '65 kilometre per hour',
#   '72 centimetres',
#   '985 grams',
#   'Chinese',
#   'Lenovo Group',
#   'Lucky Cloud',
#   'The Olympic Torch',
#   'Torch',
#   'up to 50 millimetres (2 inches'},
#  {'5-year-old',
#   'As many as 1,000',
#   'China',
#   'Chinese',
#   'Falun Gong',
#   'Independence Square',
#   'Japanese',
#   'Just days',
#   'Malaysian',
#   'Malaysians',
#   'One',
#   'Taiwan',
#   'Tibet',
#   'Tibetan',
#   'the day',
#   'two'},
#  {'1000',
#   '16.5 km',
#   '1964',
#   'April 21',
#   'Independence Square',
#   'KL Tower',
#   'Kuala Lumpur',
#   'Malaysia',
#   'Malaysian',
#   'Merdeka Stadium',
#   'National Mosque',
#   'Petronas Twin Towers',
#   'Special Action Squad',
#   'Tokyo',
#   'the Parliament House'},
#  {'Beijing', 'Chinese', 'French', 'Libération', 'Western', 'Xinhua'},
#  {'120',
#   '3,000',
#   'Beijing',
#   'Chinese',
#   'Donald Tsang',
#   'Golden Bauhinia Square',
#   'Henry Tang',
#   'Hong Kong',
#   'Lantau',
#   'Lee Lai Shan',
#   'May 2',
#   'Nathan Road',
#   'One',
#   'Sha Tin',
#   'Shing Mun River',
#   'Tin Hau',
#   'Tsim Sha Tsui',
#   'Victoria Harbour',
#   'Wan Chai',
#   'first',
#   'more than 200,000',
#   'the Hong Kong Cultural Centre',
#   'the Marine Department'},
#  {'2005',
#   'Beijing',
#   'Carrefour',
#   'Changsha',
#   'Chinese',
#   'French',
#   'Fuzhou',
#   'Japanese',
#   'May 1',
#   'Shenyang',
#   'Sohu.com',
#   'recent years',
#   "the People's Daily",
#   'the days'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'2005',
#   '5 km',
#   'About a thousand',
#   'Africa',
#   'Ali Mohamed Shein',
#   'April 13',
#   'China',
#   'Chinese',
#   'Dar es Salaam',
#   'Nobel Peace Prize',
#   'Tanzania',
#   'Temeke',
#   'Tibet',
#   "Wangari Maathai's",
#   'the 1970s',
#   'the Benjamin Mkapa National Stadium',
#   'the TAZARA Railway'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'April 3',
#   'Chinese',
#   'Istanbul',
#   'Sultanahmet Square',
#   'Taksim Square',
#   'Turkey',
#   'Uyghurs',
#   'Xinjiang'},
#  {'5-year-old',
#   'As many as 1,000',
#   'China',
#   'Chinese',
#   'Falun Gong',
#   'Independence Square',
#   'Japanese',
#   'Just days',
#   'Malaysian',
#   'Malaysians',
#   'One',
#   'Taiwan',
#   'Tibet',
#   'Tibetan',
#   'the day',
#   'two'},
#  {'24 km',
#   'August 2008',
#   'Beijing',
#   'China',
#   'Chinese',
#   'Ho Chi Minh City',
#   'Hong Kong',
#   'Macau',
#   'March 2008',
#   'May 2008',
#   'September 21, 2007',
#   'Taipei',
#   'Taiwan',
#   'The Beijing Organizing Committee',
#   'midnight',
#   'six',
#   'the Republic of China',
#   'the Taiwan Strait',
#   'the Torch Relay'},
#  {'-Kiran Bedi',
#   '70',
#   'Aamir Khan',
#   'April 17',
#   'Baichung Bhutia',
#   'Bhaichung Bhutia',
#   'Bhutia',
#   'China',
#   'Congress',
#   'Gandhi',
#   'India',
#   'Indian',
#   'Nehru',
#   'New Delhi',
#   'PRC',
#   'Rahul Gandhi',
#   'Sachin Tendulkar',
#   'Sikkimese',
#   'Soha Ali Khan',
#   'Sonia Gandhi',
#   'Sunil Gavaskar-',
#   'Tibet',
#   'first',
#   'five',
#   'just 2.3 km',
#   'less than 1.5 miles',
#   'the "Olympic Games',
#   'the India Gate'},
#  {'1707',
#   '1998',
#   'April 26',
#   'Buddhist',
#   'China',
#   'Chinese',
#   'Five',
#   'Japan',
#   'Japanese',
#   'More than 100',
#   'Nagano',
#   'Only two',
#   'Thousands',
#   'Tibet',
#   'Tibetan',
#   'Winter Olympics',
#   'Zenkoji',
#   'Zenkō-ji',
#   'Zenkō-ji Hondō',
#   'four',
#   'the Minami Nagano Sports Park',
#   'the National Treasures of Japan',
#   'three'},
#  {'Australians',
#   'BBC',
#   'BBC CNN',
#   'Beijing',
#   'CNN',
#   'China',
#   'Chinese',
#   'Fu Ying',
#   'Libération',
#   'One',
#   'Sydney',
#   'Telegraph',
#   'The Daily Telegraph',
#   'Tibet',
#   'West',
#   'Western',
#   'the United Kingdom'},
#  {'April 3',
#   'Chinese',
#   'Istanbul',
#   'Sultanahmet Square',
#   'Taksim Square',
#   'Turkey',
#   'Uyghurs',
#   'Xinjiang'},
#  {'2005',
#   '5 km',
#   'About a thousand',
#   'Africa',
#   'Ali Mohamed Shein',
#   'April 13',
#   'China',
#   'Chinese',
#   'Dar es Salaam',
#   'Nobel Peace Prize',
#   'Tanzania',
#   'Temeke',
#   'Tibet',
#   "Wangari Maathai's",
#   'the 1970s',
#   'the Benjamin Mkapa National Stadium',
#   'the TAZARA Railway'},
#  {'1989',
#   'Chan',
#   'China',
#   'Chinese',
#   'Christina Chan',
#   'Hong Kong',
#   'Legislative Council',
#   'Leung Kwok-hung',
#   'Mandarin',
#   'One',
#   'Patriotic Democratic Movements',
#   'RDHK',
#   'Szeto Wah',
#   'Tiananmen Square',
#   'Tibetan',
#   'about 10',
#   'currently[when',
#   'the Civil Human Rights Front',
#   'the Communist Party',
#   'the Hong Kong Alliance',
#   'two'},
#  {'150,000-strong Tibetan',
#   '3 km',
#   'China',
#   'Chinese',
#   'India',
#   'Indian',
#   'Tibetan',
#   'the "Olympic Holy Flame Protection Unit"'},
#  {'April 12',
#   'April 15',
#   'BBC',
#   'Beijing',
#   'CPC',
#   'Carrefour',
#   'China',
#   'Chinese',
#   'French',
#   'Hefei',
#   'Hu Jintao',
#   'Kunming',
#   'Liu Yandong',
#   'May 1',
#   'Nazism',
#   'Politburo Standing Committee',
#   'Qingdao',
#   'Sohu.com',
#   'State',
#   'Swastika',
#   'Wuhan',
#   'Zhou Yongkang',
#   'first',
#   'hundreds',
#   'the LVMH Group',
#   'the Washington Times',
#   'the weekend'},
#  {'2008',
#   'Anti-French',
#   'April 12',
#   'BOCOG',
#   'Beijing',
#   'Carrefour',
#   'China',
#   'Chinese',
#   'French',
#   'Harbin',
#   'Hefei',
# ...
#   'Challis',
#   'Galle',
#   "Heinrich d'Arrest",
#   'Johann Gottfried Galle',
#   'Le Verrier',
#   "Le Verrier's",
#   'Neptune',
#   'about 12',
#   'the evening of'},
#  {'27 January 1613',
#   '28 December 1612',
#   'David Jamieson',
#   'December 1612',
#   'Earth',
#   'Galileo',
#   'July 2009',
#   'Jupiter',
#   'Neptune',
#   'University of Melbourne',
#   'first'},
#  {'50–150 km', 'Neptune', 'Uranus', 'about 50–110 km'},
#  {'Neptune', 'several months'},
#  {'1',
#   '1.1',
#   '100 kPa',
#   '51.8 K',
#   '72.00',
#   'Neptune',
#   'Sun',
#   'Uranus',
#   'about 2.61',
#   'only 40%',
#   'over 50%',
#   'the Solar System',
#   'two',
#   '−201.15 °'},
#  {'15',
#   '17',
#   '30.1',
#   '4.50×109 km',
#   'Earth',
#   'Neptune',
#   'Roman',
#   'Sun',
#   'Uranus',
#   'eighth',
#   'every 164.8 years',
#   'fourth',
#   'the Solar System',
#   'third'},
#  {'15',
#   '17',
#   '30.1',
#   '4.50×109 km',
#   'Earth',
#   'Neptune',
#   'Roman',
#   'Sun',
#   'Uranus',
#   'eighth',
#   'every 164.8 years',
#   'fourth',
#   'the Solar System',
#   'third'},
#  {'15',
#   '17',
#   '30.1',
#   '4.50×109 km',
#   'Earth',
#   'Neptune',
#   'Roman',
#   'Sun',
#   'Uranus',
#   'eighth',
#   'every 164.8 years',
#   'fourth',
#   'the Solar System',
#   'third'},
#  {'Neptune', 'OB', 'One', 'Uranus', 'the Solar System'},
#  {'1997',
#   '2.2 to 2.4 arcseconds',
#   '2004',
#   '2005',
#   'AO',
#   'Earth',
#   'HST',
#   'Hawaii',
#   'Hubble Space Telescope',
#   'Neptune',
#   'between 38 and 61 kilometres',
#   'first',
#   'five',
#   'its spring',
#   'summer season',
#   'the Solar System',
#   'the mid-1990s',
#   'this Outer Planet'},
#  {'10 to 15',
#   '7000 km',
#   'Earth',
#   'the Lawrence Livermore National Laboratory',
#   '–'},
#  {'1,300',
#   '2,200 km',
#   '20 m/s',
#   '250 m/s',
#   '300 m/s',
#   '325 m/s',
#   '400 m/s',
#   '70° S',
#   'Neptune',
#   'almost 600 m/s'},
#  {'1981',
#   '1989',
#   '2004',
#   '2013',
#   'Despina',
#   'Five',
#   'From July to September 1989',
#   'Larissa',
#   'Neptune',
#   'Neptunian',
#   'Proteus',
#   'Roman',
#   'S/2004 N 1',
#   'Thalassa',
#   'Triton',
#   'Voyager 2',
#   'between 2002 and 2003',
#   'four',
#   'only 0.25%',
#   'second',
#   'six'},
#  {'1989',
#   '25 August 1989',
#   'Earth',
#   'Neptune',
#   'Neptune All Night',
#   'PBS',
#   'Saturn',
#   'Voyager',
#   "Voyager 1's",
#   'Voyager 2',
#   'all-night',
#   'moon Titan',
#   'the moon Triton'},
#  {'1:1',
#   '2007',
#   '2008',
#   '309239)',
#   'L5',
#   'Lagrangian',
#   'Neptune',
#   'about 12,500 years',
#   'another 12,500 years',
#   'first'},
#  {'K.', 'One', 'Sun', 'about 750'},
#  {'19%', '600', '80%', 'Neptune', 'Uranus'},
#  {'1744–1803',
#   'Bildung',
#   'German',
#   'Immanuel Kant',
#   'Johann Gottfried Herder',
#   'Kant'},
#  {'European',
#   'Europeans',
#   "Herbert Spencer's",
#   'Hobbes',
#   'Jean-Jacques Rousseau',
#   "Lewis Henry Morgan's",
#   'Matthew Arnold',
#   'Rousseau',
#   'Social Darwinism',
#   'Thomas Hobbes',
#   'the 16th centuries',
#   'the Native Americans'},
#  {'Ancient Roman', 'Cicero', 'Samuel Pufendorf', 'Tusculanae Disputationes'},
#  {'1858–1918', 'Georg Simmel', 'two'},
#  {'29', 'Raimon Panikkar'},
#  {'19th-century', 'Rousseau', 'West'},
#  {'Cambridge', 'Terror Management Theory'},
#  {'29', 'Raimon Panikkar'},
#  {'1964',
#   'CCCS',
#   'Cultural Studies',
#   'Hoggart',
#   'Richard Hoggart',
#   'Stuart Hall',
#   'Western Civilization',
#   'the Birmingham Centre for Contemporary Cultural Studies',
#   'the United States'},
#  {'Europe', 'European', 'the 18th and early 19th centuries'},
#  {'U.S.', 'the end of the last ice age'},
#  {'Europe', 'European', 'the 18th and early 19th centuries'},
#  {'European',
#   'Europeans',
#   "Herbert Spencer's",
#   'Hobbes',
#   'Jean-Jacques Rousseau',
#   "Lewis Henry Morgan's",
#   'Matthew Arnold',
#   'Rousseau',
#   'Social Darwinism',
#   'Thomas Hobbes',
#   'the 16th centuries',
#   'the Native Americans'},
#  {'Cambridge', 'Terror Management Theory'},
#  {'American', 'Tylor', 'four', 'the 20th century'},
#  {'Angela McRobbie',
#   'Dick Hebdige',
#   'Paul Willis',
#   "Stuart Hall's",
#   'Tony Jefferson',
#   'the 1970s onward'},
#  {'European',
#   'Europeans',
#   "Herbert Spencer's",
#   'Hobbes',
#   'Jean-Jacques Rousseau',
#   "Lewis Henry Morgan's",
#   'Matthew Arnold',
#   'Rousseau',
#   'Social Darwinism',
#   'Thomas Hobbes',
#   'the 16th centuries',
#   'the Native Americans'},
#  {'American',
#   'British',
#   'Doing Cultural Studies:',
#   'French',
#   'Griselda Pollock',
#   'Julia Kristeva',
#   'Lindlof',
#   'Louis Althusser',
#   'Marxist',
#   'Paul du Gay',
#   'Taylor',
#   'The Story of the Sony Walkman',
#   'culture.[citation',
#   'the Frankfurt School',
#   'the United States',
#   'the turn of the century'},
#  {'China', 'one', 'the United States'},
#  {'1767–1835',
#   '1795',
#   'Austro-Hungarian',
#   'Germany',
#   'Kant',
#   'Prussian',
#   'Weltanschauung',
#   'Wilhelm von Humboldt'},
#  {'British',
#   'E. P. Thompson',
#   'Paul Gilroy',
#   'Paul Willis',
#   'Raymond Williams',
#   'Richard Hoggart',
#   'Stuart Hall',
#   'first',
#   'the 1950s and 1960s',
#   'the Centre for Contemporary Cultural Studies',
#   'the Frankfurt School',
#   'the United Kingdom',
#   'the United States',
#   'the University of Birmingham',
#   'the late 1970s'},
#  {'1964',
#   'CCCS',
#   'Cultural Studies',
#   'Hoggart',
#   'Richard Hoggart',
#   'Stuart Hall',
#   'Western Civilization',
#   'the Birmingham Centre for Contemporary Cultural Studies',
#   'the United States'},
#  {'Europe', 'European', 'the 18th and early 19th centuries'},
#  {'Church',
#   'Constitution',
#   'Fourteenth',
#   'Justice',
#   'Justice Hugo Black',
#   'Justice Jackson',
#   'Robert H. Jackson',
#   'Rutledge',
#   'State',
#   'Virginia',
#   'Wiley Blount Rutledge',
#   'four',
#   'the First Amendment',
#   'today',
#   'yesterday'},
#  {'1879',
#   '1947',
#   'Court',
#   'Everson v. Board of Education',
#   'First] Amendment',
#   'Hugo Black',
#   'Jefferson',
#   'Reynolds',
#   'Thomas Jefferson',
#   'the U.S. Supreme Court',
#   'v. United States'},
#  {'1994',
#   'Board of Education',
#   'Everson v. Board of Education',
#   'First Amendment',
#   'Grumet',
#   'Kiryas Joel Village School District',
#   'the Supreme Court'},
#  {'America',
#   'Anglican',
#   'Christians',
#   'Church',
#   'Dutch',
#   'France',
#   'Germany',
#   'King of England',
#   'Massachusetts Bay Colony',
#   'New Netherland',
#   'Pennsylvania',
#   'Protestant',
#   'Puritans',
#   'Rhode Island',
#   'Roger Williams',
#   'William Penn',
#   'colonies',
#   'the Dutch Reformed Church',
#   'the English Civil War',
#   'the Plymouth Colony'},
#  {'America',
#   'Constitution',
#   'Court',
#   'England',
#   'Potter Stewart',
#   'colonists'},
#  {'1970',
#   '1980',
#   'American',
#   'Catholic',
#   'Jeffries',
#   'Jews',
#   'Protestant',
#   'Protestants',
#   'Roman',
#   'Ryan',
#   'today'},
#  {'Church',
#   'Constitution',
#   'Fourteenth',
#   'Justice',
#   'Justice Hugo Black',
#   'Justice Jackson',
#   'Robert H. Jackson',
#   'Rutledge',
#   'State',
#   'Virginia',
#   'Wiley Blount Rutledge',
#   'four',
#   'the First Amendment',
#   'today',
#   'yesterday'},
#  {'ACLU',
#   'American',
#   'December 20, 2005',
#   'Kentucky',
#   'May 3, 2006',
#   'Mercer County',
#   'Mount Soledad',
#   'Ten',
#   'the Sixth Circuit',
#   'the United States Court of Appeals'},
#  {'American',
#   'Christianity',
#   'Jefferson',
#   'Jeffersonian',
#   'Mark David Hall',
#   'State',
#   'Virginia Statute for Religious Freedom',
#   'each morning',
#   'one',
#   'the University of Virginia, Jefferson'},
#  {'Adam',
#   'America',
#   'Bowne',
#   'Christ',
#   'December 27, 1657',
#   'Dutch',
#   'Egyptians',
#   'English',
#   'Holland',
#   'Jesus',
#   'Jews',
#   'John Bowne',
#   'Netherlands',
#   'New Netherland',
#   'Peter Stuyvesant',
#   'Quakers',
#   'Stuyvesant',
#   'Turks',
#   'as early as the mid-17th century',
#   'the Dutch Reformed Church',
#   'the Dutch Republic'},
#  {'Frank Lambert',
#   'Isaac Bachus',
#   'James Madison',
#   'Jefferson',
#   'John Leland',
#   'Madison',
#   'New Light',
#   'Steven Waldman',
#   'The Founding Fathers and the Place of Religion in America',
#   'Thomas Jefferson'},
#  {'1962',
#   '370',
#   '421',
#   '6',
#   'Court',
#   'Engel',
#   'U.S.',
#   'Vitale',
#   'the New York State Board of Regents',
#   'the Supreme Court'},
#  {'Baker',
#   'British',
#   'Congress',
#   'Elbridge Gerry',
#   'Federalists',
#   'House',
#   'John Baker',
#   'LSU',
#   'Madison',
#   'Massachusetts'},
#  {'ACLU',
#   'American',
#   'December 20, 2005',
#   'Kentucky',
#   'May 3, 2006',
#   'Mercer County',
#   'Mount Soledad',
#   'Ten',
#   'the Sixth Circuit',
#   'the United States Court of Appeals'},
#  {'America',
#   'Anglican',
#   'Christians',
#   'Church',
#   'Dutch',
#   'France',
#   'Germany',
#   'King of England',
#   'Massachusetts Bay Colony',
#   'New Netherland',
#   'Pennsylvania',
#   'Protestant',
#   'Puritans',
#   'Rhode Island',
#   'Roger Williams',
#   'William Penn',
#   'colonies',
#   'the Dutch Reformed Church',
#   'the English Civil War',
#   'the Plymouth Colony'},
#  {'2001',
#   'Establishment Clause',
#   'Jeffries',
#   'Ryan',
#   'the Supreme Court',
#   'the mid-twentieth century',
#   'two'},
#  {'Baker',
#   'British',
#   'Congress',
#   'Elbridge Gerry',
#   'Federalists',
#   'House',
#   'John Baker',
#   'LSU',
#   'Madison',
#   'Massachusetts'},
#  {'1878',
#   'American',
#   'Baptists',
#   'Congress',
#   'Danbury',
#   'Jefferson',
#   'Madison',
#   'Mormon',
#   'Reynolds',
#   'Stephen Johnson Field',
#   'U.S.'},
#  {'145',
#   '1878',
#   '98',
#   'Danbury Baptists',
#   'Establishment Clause',
#   'James Madison',
#   'Jefferson',
#   'Reynolds',
#   'Thomas Jefferson',
#   'U.S.',
#   'US',
#   'first',
#   'the Constitution'},
#  {'1776',
#   '1835',
#   '1835-1876',
#   '1961',
#   '5',
#   'Anglican',
#   'Article VI, Section 8 of',
#   'Catholics',
#   'Christians',
#   'First',
#   'Fourteenth Amendment',
#   'NC Constitution',
#   'Protestants',
#   'The North Carolina Constitution',
#   'Torcaso',
#   'Watkins',
#   'the NC Constitution',
#   'the United States Supreme Court'},
#  {'Constitution',
#   'Nature',
#   'a "Creator',
#   'a "Creator"',
#   'the Supreme Court',
#   'the United States Declaration of Independence'},
#  {'1773',
#   '1786',
#   'Baptist',
#   'Christ',
#   'Isaac Backus',
#   'New England',
#   "Thomas Jefferson's",
#   'Virginia Statute',
#   'five years',
#   'the Bill of Rights'},
#  {'ACLU',
#   'American',
#   'December 20, 2005',
#   'Kentucky',
#   'May 3, 2006',
#   'Mercer County',
#   'Mount Soledad',
#   'Ten',
#   'the Sixth Circuit',
#   'the United States Court of Appeals'},
#  {'Center for New Religions',
#   'Robert S. Wood',
#   'Toronto',
#   'U.S.',
#   'Wood',
#   'the United States'},
#  {'Catholic',
#   'First',
#   'Kurtzman',
#   'Lemon',
#   'Second',
#   'Third',
#   'the "Lemon Test"',
#   "the Catholic Church's",
#   'the Establishment Clause',
#   'the Supreme Court',
#   'three'},
#  {'1962',
#   '370',
#   '421',
#   '6',
#   'Court',
#   'Engel',
#   'U.S.',
#   'Vitale',
#   'the New York State Board of Regents',
#   'the Supreme Court'},
#  {'1878',
#   'American',
#   'Baptists',
#   'Congress',
#   'Danbury',
#   'Jefferson',
#   'Madison',
#   'Mormon',
#   'Reynolds',
#   'Stephen Johnson Field',
#   'U.S.'},
#  {'1994',
#   'Board of Education',
#   'Everson v. Board of Education',
#   'First Amendment',
#   'Grumet',
#   'Kiryas Joel Village School District',
#   'the Supreme Court'},
#  {'Catholic',
#   'First',
#   'Kurtzman',
#   'Lemon',
#   'Second',
#   'Third',
#   'the "Lemon Test"',
#   "the Catholic Church's",
#   'the Establishment Clause',
#   'the Supreme Court',
#   'three'},
#  {'2001',
#   'Establishment Clause',
#   'Jeffries',
#   'Ryan',
#   'the Supreme Court',
#   'the mid-twentieth century',
#   'two'},
#  {'American',
#   'Christianity',
#   'Jefferson',
#   'Jeffersonian',
#   'Mark David Hall',
#   'State',
#   'Virginia Statute for Religious Freedom',
#   'each morning',
#   'one',
#   'the University of Virginia, Jefferson'},
#  {'"The First Amendment',
#   '1',
#   '1947',
#   '330',
#   'Catholic',
#   'Everson v. Board of Education',
#   'New Jersey',
#   'U.S.',
#   'first',
#   'the Bill of Rights',
#   'the Establishment Clause',
#   'the Fourteenth Amendment',
#   'the Religion Clauses of the Constitution'},
#  {'America',
#   'Constitution',
#   'Court',
#   'England',
#   'Potter Stewart',
#   'colonists'},
#  {'2001',
#   'Establishment Clause',
#   'Jeffries',
#   'Ryan',
#   'the Supreme Court',
#   'the mid-twentieth century',
#   'two'},
#  {'America',
#   'Anglican',
#   'Christians',
#   'Church',
#   'Dutch',
#   'France',
#   'Germany',
#   'King of England',
#   'Massachusetts Bay Colony',
#   'New Netherland',
#   'Pennsylvania',
#   'Protestant',
#   'Puritans',
#   'Rhode Island',
#   'Roger Williams',
#   'William Penn',
#   'colonies',
#   'the Dutch Reformed Church',
#   'the English Civil War',
#   'the Plymouth Colony'},
#  {'Catholic',
#   'First',
#   'Kurtzman',
#   'Lemon',
#   'Second',
#   'Third',
#   'the "Lemon Test"',
#   "the Catholic Church's",
#   'the Establishment Clause',
#   'the Supreme Court',
#   'three'},
#  {'12-696',
#   '5-4',
#   'Christian',
#   'Galloway',
#   'Greece',
#   'May 5, 2014',
#   'the Supreme Court',
#   'the Town of Greece',
#   'the U.S. Constitution',
#   'the U.S. Supreme Court'},
#  {'1644',
#   '1802',
#   'Baptist',
#   'Congregationalist',
#   'Connecticut',
#   'Rhode Island',
#   'Roger Williams',
#   'The Bloody Tenent of Persecution',
#   'Thomas Jefferson',
#   'first',
#   'the Danbury Baptists',
#   'the First Amendment'},
#  {'14th',
#   'First Amendment',
#   'IX, Section 2',
#   'Tennessee Constitution',
#   'one',
#   'today'},
#  {'1967',
#   'Civil Religion',
#   'John F. Kennedy',
#   'Robert N. Bellah',
#   'the United States'},
#  {'Catholic',
#   'J. Brent Walker',
#   'the Baptist Joint Committee',
#   'the Catholic Church'},
#  {'1789', '2', 'Article IV', 'Section 10', 'the Georgia Constitution'},
#  {'1773',
#   '1786',
#   'Baptist',
#   'Christ',
#   'Isaac Backus',
#   'New England',
#   "Thomas Jefferson's",
#   'Virginia Statute',
#   'five years',
#   'the Bill of Rights'},
#  {'Bill of Rights, Declaration of Rights',
#   'Constitution',
#   'Maryland',
#   'Massachusetts',
#   'North Carolina',
#   'Pennsylvania',
#   'Seven',
#   'South Carolina',
#   'Tennessee',
#   'Texas'},
#  {'Bible', 'Christmas', 'Ohio', 'the Supreme Court'},
#  {'American',
#   'Blaine Amendments',
#   'Catholicism',
#   'Columbia Law',
#   'Nativism.[citation',
#   'Philip Hamburger',
#   'U.S.',
#   'the Supreme Court'},
#  {'Bible', 'Christmas', 'Ohio', 'the Supreme Court'},
#  {'2002',
#   'California',
#   'Congress',
#   'Elk Grove Unified School District',
#   'God',
#   'June 2004',
#   'Newdow',
#   'five',
#   'the Ninth Circuit Court of Appeals',
#   'the Pledge of Allegiance',
#   'the Supreme Court',
#   'three'},
#  {'1773',
#   '1786',
#   'Baptist',
#   'Christ',
#   'Isaac Backus',
#   'New England',
#   "Thomas Jefferson's",
#   'Virginia Statute',
#   'five years',
#   'the Bill of Rights'},
#  {'1644',
#   '1802',
#   'Baptist',
#   'Congregationalist',
#   'Connecticut',
#   'Rhode Island',
#   'Roger Williams',
#   'The Bloody Tenent of Persecution',
#   'Thomas Jefferson',
#   'first',
#   'the Danbury Baptists',
#   'the First Amendment'},
#  {'Catholic',
#   'First',
#   'Kurtzman',
#   'Lemon',
#   'Second',
#   'Third',
#   'the "Lemon Test"',
#   "the Catholic Church's",
#   'the Establishment Clause',
#   'the Supreme Court',
#   'three'},
#  {'1967',
#   'Civil Religion',
#   'John F. Kennedy',
#   'Robert N. Bellah',
#   'the United States'},
#  {'2002',
#   'California',
#   'Congress',
#   'Elk Grove Unified School District',
#   'God',
#   'June 2004',
#   'Newdow',
#   'five',
#   'the Ninth Circuit Court of Appeals',
#   'the Pledge of Allegiance',
#   'the Supreme Court',
#   'three'},
#  {'Catholic',
#   'First',
#   'Kurtzman',
#   'Lemon',
#   'Second',
#   'Third',
#   'the "Lemon Test"',
#   "the Catholic Church's",
#   'the Establishment Clause',
#   'the Supreme Court',
#   'three'},
#  {'Bill of Rights, Declaration of Rights',
#   'Constitution',
#   'Maryland',
#   'Massachusetts',
#   'North Carolina',
#   'Pennsylvania',
#   'Seven',
#   'South Carolina',
#   'Tennessee',
#   'Texas'},
#  {'1967',
#   'Civil Religion',
#   'John F. Kennedy',
#   'Robert N. Bellah',
#   'the United States'},
#  {'Congress',
#   'Connecticut',
#   'Constitution',
#   'Roger Sherman',
#   'South Carolina',
#   'Thomas Tucker',
#   'first',
#   'the House of Representatives'},
#  {'America',
#   'Anglican',
#   'Christians',
#   'Church',
#   'Dutch',
#   'France',
#   'Germany',
#   'King of England',
#   'Massachusetts Bay Colony',
#   'New Netherland',
#   'Pennsylvania',
#   'Protestant',
#   'Puritans',
#   'Rhode Island',
#   'Roger Williams',
#   'William Penn',
#   'colonies',
#   'the Dutch Reformed Church',
#   'the English Civil War',
#   'the Plymouth Colony'},
#  {'ACLU',
#   'American',
#   'December 20, 2005',
#   'Kentucky',
#   'May 3, 2006',
#   'Mercer County',
#   'Mount Soledad',
#   'Ten',
#   'the Sixth Circuit',
#   'the United States Court of Appeals'},
#  ...]

# %%
def in_query(tips, i):
    for tip in tips:
        if test_qs[i].find(tip) != -1:
            return True
    return False

answers = []
for i, context in enumerate(test_contexts):
    doc = nlp(context)
    
    answer = {}
    answer['text'] = set()
    
    if in_query(["who", "organization"], i):
        for ent in doc.ents:
            if ent.label_ in {"ORG", "PERSON", "NORP"}:
                answer['text'].add(ent.text)
    elif in_query(["when", "time", "month", "day", "year", "was", "did", "how"], i):
        for ent in doc.ents:
            if ent.label_ in {"DATE", "TIME", "CARDINAL"}:
                answer['text'].add(ent.text)
    elif in_query(["where", "place", "city", "country"], i):
        for ent in doc.ents:
            if ent.label_ in {"GPE", "LOC", "FACILITY", "ORG"}:
                answer['text'].add(ent.text)
    elif in_query(["much", "many"], i):
        for ent in doc.ents:
            if ent.label_ in {"PERCENT", "QUANTITY", "CARDINAL", "MONEY"}:
                answer['text'].add(ent.text)
    else:
        for ent in doc.ents:
            if not ent.label_:
                answer['text'].add(ent.text)

    if not answer['text']:
        for chunk in doc.noun_chunks:
            answer['text'].add(ent.text)
    
    answer["text"] = answer
    # delete the entities which already appear in query
    answer["text"] = " ".join(list(answer["text"] - set(queries[i])))
        
    answers.append(answer)
answers
# Out:
# -------------------------------------------------------------------
# TypeError                         Traceback (most recent call last)
# <ipython-input-168-9a529af83034> in <module>()
#      37             answer['text'].add(ent.text)
#      38
# ---> 39     answer["text"] = answer["text"][:3]
#      40     # delete the entities which already appear in query
#      41     answer["text"] = " ".join(list(answer["text"] - set(queries[i])))
#
# TypeError: 'set' object is not subscriptable

# %%
import csv
import re
i=0
with open('result.csv', 'w') as f:
    f.write("id,answer\n")
    for t in answers:
        ans = re.sub(r'[^\w\s]', '', t["text"])
        f.write(str(i) + ', ' + ans + '\n')
        i+=1
