# %%
import numpy as np
import json
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# <b>Word embedding</b>

# %%
embedding_size = 50
gloveFilePath = "data/glove.6B.50d.txt"
def loadGlove(filePath):
    file = open(filePath, 'r')
    
    vocab = {}
    embedding = []
    for i, line in enumerate(file.readlines()):
        line = line.strip().split(' ')
        word = line[0]
        vocab[word] = i
        embedding.append(line[1:])
    file.close()
    return vocab,embedding
vocab, embedding = loadGlove(gloveFilePath)
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 400000

# %% [markdown]
# <b>Load data</b>

# %%
f = open("./data/training.json", encoding='utf-8')
js = json.load(f)
#discard the token '?' at the end of each query
train_qs = [item['question'][:-1] for item in js]
tokenized_train_qs_all = [word_tokenize(item['question'][:-1]) for item in js]
train_texts = [item['text'] for item in js]
tokenized_train_texts_all = [word_tokenize(item['text']) for item in js]
train_aps = [item['answer_paragraph'] for item in js]
train_docids = [item['docid'] for item in js]
f.close()
print(train_qs[0])
print(tokenized_train_qs_all[0])
print(train_texts[0])
print(tokenized_train_texts_all[0])
# Out:
# A kilogram could be definined as having a Planck constant of what value
# ['A', 'kilogram', 'could', 'be', 'definined', 'as', 'having', 'a', 'Planck', 'constant', 'of', 'what', 'value']
# 6966662606895999999♠6.62606896×10−34 j⋅s
# ['6966662606895999999♠6.62606896×10−34', 'j⋅s']

# %%
f = open("./data/testing.json", encoding='utf-8')
js = json.load(f)
#discard the token '?' at the end of each query
test_qs = [item['question'][:-1] for item in js]
tokenized_test_qs_all = [word_tokenize(item['question'][:-1]) for item in js]
test_docids = [item['docid'] for item in js]
f.close()
print(test_qs[0])
print(tokenized_test_qs_all[0])
# Out:
# Modern browser support standards-based and defacto what
# ['Modern', 'browser', 'support', 'standards-based', 'and', 'defacto', 'what']

# %%
f = open("./data/documents.json", encoding='utf-8')
js = json.load(f)
docs = [ [ sent for para in item['text'] for sent in sent_tokenize(para)] for item in js]
tokenized_docs = [[word_tokenize(sent) for sent in doc] for doc in docs]
docids = [item['docid'] for item in js]
f.close()
print(docs[0])
print(tokenized_docs[0])
# Out:
# ['First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.', 'In 1905 the value E, the minimal energy increment of a hypothetical oscillator, was theoretically associated by Einstein with a "quantum" or minimal element of the energy of the electromagnetic wave itself.', 'The light quantum behaved in some respects as an electrically neutral particle, as opposed to an electromagnetic wave.', 'It was eventually called the photon.', 'Classical statistical mechanics requires the existence of h (but does not define its value).', "Eventually, following upon Planck's discovery, it was recognized that physical action cannot take on an arbitrary value.", 'Instead, it must be some multiple of a very small quantity, the "quantum of action", now called the Planck constant.', 'Classical physics cannot explain this fact.', 'In many cases, such as for monochromatic light or for atoms, this quantum of action also implies that only certain energy levels are allowed, and values in between are forbidden.', 'Equivalently, the smallness of the Planck constant reflects the fact that everyday objects and systems are made of a large number of particles.', 'For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).', 'Each photon has an energy E = hf = 6981358000000000000♠3.58×10−19 J.', 'That is a very small amount of energy in terms of everyday experience, but everyday experience is not concerned with individual photons any more than with individual atoms or molecules.', 'An amount of light compatible with everyday experience is the energy of one mole of photons; its energy can be computed by multiplying the photon energy by the Avogadro constant, NA ≈ 7023602200000000000♠6.022×1023 mol−1.', 'The result is that green light of wavelength 555 nm has an energy of 7005216000000000000♠216 kJ/mol, a typical energy of everyday life.', 'In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.', 'It is well known that hot objects glow, and that hotter objects glow brighter than cooler ones.', 'The electromagnetic field obeys laws of motion similarly to a mass on a spring, and can come to thermal equilibrium with hot atoms.', 'The hot object in equilibrium with light absorbs just as much light as it emits.', 'If the object is black, meaning it absorbs all the light that hits it, then its thermal light emission is maximized.', 'The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).', 'But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".', 'Nevertheless, Wilhelm Wien discovered the mathematical relationship between the peaks of the curves at different temperatures, by using the principle of adiabatic invariance.', "At each different temperature, the curve is moved over by Wien's displacement law (1893).", 'Wien also proposed an approximation for the spectrum of the object, which was correct at high frequencies (short wavelength) but not at low frequencies (long wavelength).', 'It still was not clear why the spectrum of a hot object had the form that it has (see diagram).', "Prior to Planck's work, it had been assumed that the energy of a body could take on any value whatsoever – that it was a continuous variable.", 'The Rayleigh–Jeans law makes close predictions for a narrow range of values at one limit of temperatures, but the r ...
# [['First', 'recognized', 'in', '1900', 'by', 'Max', 'Planck', ',', 'it', 'was', 'originally', 'the', 'proportionality', 'constant', 'between', 'the', 'minimal', 'increment', 'of', 'energy', ',', 'E', ',', 'of', 'a', 'hypothetical', 'electrically', 'charged', 'oscillator', 'in', 'a', 'cavity', 'that', 'contained', 'black', 'body', 'radiation', ',', 'and', 'the', 'frequency', ',', 'f', ',', 'of', 'its', 'associated', 'electromagnetic', 'wave', '.'], ['In', '1905', 'the', 'value', 'E', ',', 'the', 'minimal', 'energy', 'increment', 'of', 'a', 'hypothetical', 'oscillator', ',', 'was', 'theoretically', 'associated', 'by', 'Einstein', 'with', 'a', '``', 'quantum', "''", 'or', 'minimal', 'element', 'of', 'the', 'energy', 'of', 'the', 'electromagnetic', 'wave', 'itself', '.'], ['The', 'light', 'quantum', 'behaved', 'in', 'some', 'respects', 'as', 'an', 'electrically', 'neutral', 'particle', ',', 'as', 'opposed', 'to', 'an', 'electromagnetic', 'wave', '.'], ['It', 'was', 'eventually', 'called', 'the', 'photon', '.'], ['Classical', 'statistical', 'mechanics', 'requires', 'the', 'existence', 'of', 'h', '(', 'but', 'does', 'not', 'define', 'its', 'value', ')', '.'], ['Eventually', ',', 'following', 'upon', 'Planck', "'s", 'discovery', ',', 'it', 'was', 'recognized', 'that', 'physical', 'action', 'can', 'not', 'take', 'on', 'an', 'arbitrary', 'value', '.'], ['Instead', ',', 'it', 'must', 'be', 'some', 'multiple', 'of', 'a', 'very', 'small', 'quantity', ',', 'the', '``', 'quantum', 'of', 'action', "''", ',', 'now', 'called', 'the', 'Planck', 'constant', '.'], ['Classical', 'physics', 'can', 'not', 'explain', 'this', 'fact', '.'], ['In', 'many', 'cases', ',', 'such', 'as', 'for', 'monochromatic', 'light', 'or', 'for', 'atoms', ',', 'this', 'quantum', 'of', 'action', 'also', 'implies', 'that', 'only', 'certain', 'energy', 'levels', 'are', 'allowed', ',', 'and', 'values', 'in', 'between', 'are', 'forbidden', '.'], ['Equivalently', ',', 'the', 'smallness', 'of', 'the', 'Planck', 'constant', 'reflects', 'the', 'fact', 'that', 'everyday', 'objects', 'and', 'systems', 'are', 'made', 'of', 'a', 'large', 'number', 'of', 'particles', '.'], ['For', 'example', ',', 'green', 'light', 'with', 'a', 'wavelength', 'of', '555', 'nanometres', '(', 'the', 'approximate', 'wavelength', 'to', 'which', 'human', 'eyes', 'are', 'most', 'sensitive', ')', 'has', 'a', 'frequency', 'of', '7014540000000000000♠540', 'THz', '(', '7014540000000000000♠540×1012', 'Hz', ')', '.'], ['Each', 'photon', 'has', 'an', 'energy', 'E', '=', 'hf', '=', '6981358000000000000♠3.58×10−19', 'J', '.'], ['That', 'is', 'a', 'very', 'small', 'amount', 'of', 'energy', 'in', 'terms', 'of', 'everyday', 'experience', ',', 'but', 'everyday', 'experience', 'is', 'not', 'concerned', 'with', 'individual', 'photons', 'any', 'more', 'than', 'with', 'individual', 'atoms', 'or', 'molecules', '.'], ['An', 'amount', 'of', 'light', 'compatible', 'with', 'everyday', 'experience', 'is', 'the', 'energy', 'of', 'one', 'mole', 'of', 'photons', ';', 'its', 'energy', 'can', 'be', 'computed', 'by', 'multiplying', 'the', 'photon', 'energy', 'by', 'the', 'Avogadro', 'constant', ',', 'NA', '≈', '7023602200000000000♠6.022×1023', 'mol−1', '.'], ['The', 'result', 'is', 'that', 'green', 'light', 'of', 'wavelength', '555', 'nm', 'has', 'an', 'energy', 'of', '7005216000000000000♠216', 'kJ/mol', ',', 'a', 'typical', 'energy', 'of', 'everyday', 'life', '.'], ['In', 'the', 'last', 'years', 'of', 'the', 'nineteenth', 'century', ',', 'Planck', 'was', 'investigating', 'the', 'problem', 'of', 'black-body', 'radiation', 'first', 'posed', 'by', 'Kirchhoff', 'some', 'forty', 'years', 'earlier', '.'], ['It', 'is', 'well', 'known', 'that', 'hot', 'objects', 'glow', ',', 'and', 'that', 'hotter', 'objects', 'glow', 'brighter', 'than', 'cooler', 'ones', '.'], ['The', 'electromagnetic', 'field', 'obeys', 'laws', 'of', 'motion', 'similarly', 'to', 'a', 'mass', 'on', 'a', 'spring', ',', 'and', 'can', 'come', 'to', 'thermal', 'equilibrium', 'with ...

# %% [markdown]
# <b>Locate answer sentence with TF-IDF</b>

# %%
TfidfVectorizers = []
tfidf_paras_mats = []
for paras in docs:
    tfidf = TfidfVectorizer(tokenizer=word_tokenize, lowercase=True)
    tfidf_paras_mats.append(tfidf.fit_transform(paras))
    TfidfVectorizers.append(tfidf)

train_context_sents = []
train_queries = []
train_answers = []
for i,query in enumerate(train_qs):
    docid = train_docids[i]
    tfidf_query = TfidfVectorizers[docid].transform([query])
    relativities = np.dot(tfidf_query, tfidf_paras_mats[docid].T).toarray()
    indices = (-relativities).argsort()[0]
    
    answer = train_texts[i]
    tokenized_answer = word_tokenize(answer)
    for index in indices:
        tokenized_context = tokenized_docs[docid][index]
        #if answer is not in context, which means we failed to find the right context. We discard this train item
        if tokenized_answer[0] in tokenized_context and tokenized_answer[-1] in tokenized_context:
            train_context_sents.append(docs[docid][index])
            train_queries.append(query)
            train_answers.append(answer)
            break
print(train_context_sents[6])
print(train_queries[6])
print(train_answers[6])
            
test_context_sents = []
for i,query in enumerate(test_qs):
    docid = test_docids[i]
    tfidf_query = TfidfVectorizers[docid].transform([query])
    relativities = np.dot(tfidf_query, tfidf_paras_mats[docid].T)
    index = np.argmax(relativities)
    test_context_sents.append(docs[docid][index])
print(test_context_sents[0])
# Out:
# First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.
# What is frequency also known as in science
# f
# Modern web browsers support a combination of standards-based and de facto HTML and XHTML, which should be rendered in the same way by all browsers.

# %% [markdown]
# <b>Get answer indices in context</b>

# %%
tokenized_train_context = [word_tokenize(context) for context in train_context_sents]
tokenized_train_qs = [word_tokenize(query) for query in train_queries]
tokenized_train_answers = [word_tokenize(answer) for answer in train_answers]

# %%
#indices of answer words in context 
train_answers_indices = []
for i,answer in enumerate(tokenized_train_answers):
    start_w = answer[0]
    start_i = -1
    end_w = answer[-1]
    end_i = -1
    
    has_answer = False
    for j,word in enumerate(tokenized_train_context[i]):
        if start_w == word:
            start_i = j
        if end_w == word:
            end_i = j
        
        answer_indices = []
        #answer should be less than 5 words, and start index should smaller than end_i
        if start_i!=-1 and end_i - start_i <= 5 and end_i >= start_i :
            for index in range(start_i, end_i+1):
                answer_indices.append(index)
            train_answers_indices.append(answer_indices)
            has_answer = True
            break
    if not has_answer:
        train_answers_indices.append([])
        
print(tokenized_train_context[0])
print(tokenized_train_answers[0])
print(train_answers_indices[0])
    
tokenized_test_context = [word_tokenize(context) for context in test_context_sents]
tokenized_test_qs = [word_tokenize(query) for query in test_qs]
# Out:
# ['The', 'most', 'urgent', 'unit', 'on', 'the', 'list', 'for', 'redefinition', 'is', 'the', 'kilogram', ',', 'whose', 'value', 'has', 'been', 'fixed', 'for', 'all', 'science', '(', 'since', '1889', ')', 'by', 'the', 'mass', 'of', 'a', 'small', 'cylinder', 'of', 'platinum–iridium', 'alloy', 'kept', 'in', 'a', 'vault', 'just', 'outside', 'Paris', '.']
# ['cylinder']
# [31]

# %%
embed_train_context = [[embedding[vocab[word]] for word in context if word in vocab] for context in tokenized_train_context]
embed_train_qs = [[embedding[vocab[word]] for word in q if word in vocab] for q in tokenized_train_qs]
embed_train_answers = [[embedding[vocab[word]] for word in answer if word in vocab] for answer in tokenized_train_answers]
embed_test_context = [[embedding[vocab[word]] for word in context if word in vocab] for context in tokenized_test_context]
embed_test_qs = [[embedding[vocab[word]] for word in q if word in vocab] for q in tokenized_test_qs]
print(embed_train_answers[0])
# Out:
# [['0.53501', '0.51619', '1.2869', '-0.44228', '-0.6153', '1.5837', '0.77163', '-0.74072', '-0.59075', '0.44771', '0.35128', '0.16073', '-0.43567', '1.5196', '-0.32378', '0.0080341', '-0.37728', '1.537', '-0.44858', '-2.0515', '0.050697', '-1.3163', '-0.074289', '-0.13453', '0.1929', '-0.46173', '0.51555', '1.3476', '-0.38719', '0.38547', '1.7052', '-0.84175', '0.16006', '1.0468', '1.2382', '0.33616', '0.95423', '0.14869', '0.48572', '0.44431', '0.54502', '-0.20186', '-0.43291', '0.1342', '-0.58757', '0.40151', '0.93869', '0.16292', '-0.1962', '-0.99166']]

# %% [markdown]
# <b>Deep learning model</b>

# %%
max_context_size = 0
for tokenized_doc in tokenized_docs:
    for tokenized_sent in tokenized_doc:
        len_sent = len(tokenized_sent)
        if max_context_size < len_sent:
            max_context_size = len_sent

max_query_size = 0
for query in tokenized_train_qs_all:
    len_query = len(query)
    if max_query_size < len_query:
        max_query_size = len_query
for query in tokenized_test_qs_all:
    len_query = len(query)
    if max_query_size < len_query:
        max_query_size = len_query
        
max_answer_size = 0
for answer in tokenized_train_answers:
    len_answer = len(answer)
    if max_answer_size < len_answer:
        max_answer_size = len_answer

print(max_context_size)
print(max_query_size)
print(max_answer_size)
# Out:
# 382
# 59
# 8

# %% [markdown]
# training data

# %%
trainig_size = len(embed_train_qs)

training_contexts = np.zeros(
    (trainig_size, max_context_size, embedding_size),
    dtype='float32')
training_queries = np.zeros(
    (trainig_size, max_query_size, embedding_size),
    dtype='float32')
#answers are indices in context
# training_answers = np.zeros(
#     (trainig_size, max_answer_size, max_context_size),
#     dtype='float32')

#answers are start and end indices in context
training_answers = np.zeros(
    ( 2, trainig_size, max_context_size),
    dtype='float32')

#similarity matrix of context words to context words
training_cc = np.zeros(
    (trainig_size, max_context_size, max_context_size),
    dtype='float32')
#similarity matrix of query words to query words
training_qq = np.zeros(
    (trainig_size, max_query_size, max_query_size),
    dtype='float32')
#similarity matrix of context words to query words
training_qc = np.zeros(
    (trainig_size, max_query_size, max_context_size),
    dtype='float32')
training_input = np.zeros(
    (trainig_size, max_query_size, max_context_size),
    dtype='float32')

for i, embed_context in enumerate(embed_train_context):
    for j, embed_word in enumerate(embed_context):
        training_contexts[i,j] = embed_word
        
for i, embed_query in enumerate(embed_train_qs):
    for j, embed_word in enumerate(embed_query):
        training_queries[i,j] = embed_word

for i, answer_indices in enumerate(train_answers_indices):
    if len(answer_indices) > 1:
        training_answers[0, i, answer_indices[0]] = 1.
        training_answers[1, i, answer_indices[-1]] = 1.
        
for i in range(trainig_size):
    training_cc[i] = np.dot(training_contexts[i], training_contexts[i].T)
    training_qq[i] = np.dot(training_queries[i], training_queries[i].T)
    training_qc[i] = np.dot(training_queries[i], training_contexts[i].T)
    training_input[i] = np.dot( np.dot(training_qq[i], training_qc[i]), training_cc[i])

# %% [markdown]
# testing data

# %%
testing_size = len(embed_test_qs)

testing_contexts = np.zeros(
    (testing_size, max_context_size, embedding_size),
    dtype='float32')
testing_size_queries = np.zeros(
    (testing_size, max_query_size, embedding_size),
    dtype='float32')

#similarity matrix of context words to context words
testing_cc = np.zeros(
    (testing_size, max_context_size, max_context_size),
    dtype='float32')
#similarity matrix of query words to query words
testing_qq = np.zeros(
    (testing_size, max_query_size, max_query_size),
    dtype='float32')
#similarity matrix of context words to query words
testing_qc = np.zeros(
    (testing_size, max_query_size, max_context_size),
    dtype='float32')
testing_input = np.zeros(
    (testing_size, max_query_size, max_context_size),
    dtype='float32')

for i, embed_context in enumerate(embed_test_context):
    for j, embed_word in enumerate(embed_context):
        testing_contexts[i,j] = embed_word
        
for i, embed_query in enumerate(embed_test_qs):
    for j, embed_word in enumerate(embed_query):
        testing_queries[i,j] = embed_word
        
for i in range(testing_size):
    testing_cc[i] = np.dot(testing_contexts[i], testing_contexts[i].T)
    testing_qq[i] = np.dot(testing_queries[i], testing_queries[i].T)
    testing_qc[i] = np.dot(testing_queries[i], testing_contexts[i].T)
    testing_input[i] = np.dot( np.dot(testing_qq[i], testing_qc[i]), testing_cc[i])
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-99-775ec175cdc9> in <module>()
#      30 for i, embed_query in enumerate(embed_test_qs):
#      31     for j, embed_word in enumerate(embed_query):
# ---> 32         testing_queries[i,j] = embed_word
#      33
#      34 for i in range(testing_size):
#
# NameError: name 'testing_queries' is not defined

# %% [markdown]
# '''
# testing_size = len(embed_test_qs)
#
# input_contexts = np.zeros(
#     (testing_size, max_context_size, embedding_size),
#     dtype='float32')
#
# input_queries = np.zeros(
#     (testing_size, max_query_size, embedding_size),
#     dtype='float32')
# '''

# %%
import keras.backend as K
from keras.models import Model
from keras import layers
from keras.layers import Input, GRU, Dense, Reshape, Flatten

batch_size = 128  
epochs = 12
qc_relations_size = max_context_size*max_query_size

# %% [markdown]
# <b>model 1 pure GRU</b>

# %%
qc_relations = Input(shape=(None, max_context_size))
qc_relations_dense = Dense(max_query_size, activation='relu')(qc_relations)
encoder_outputs = GRU(output_dim = max_context_size, activation = 'tanh')(qc_relations_dense) #output_dim #activation

start = Dense(max_context_size, activation='softmax')(encoder_outputs)
end = Dense(max_context_size, activation='softmax')(encoder_outputs)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(activation="tanh", units=50)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model = Model(qc_relations, [start, end])
model.compile(optimizer='adam', loss='categorical_crossentropy') 
model.fit(training_input, [training_answers[0], training_answers[1]] ,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)

# %%
my_answers = []
for i,embed_query in enumerate(embed_train_qs):
    start_idx, end_idx = model.predict(training_input[i:i+1])
    start_idx = np.argmax(start_idx)
    end_idx = np.argmax(eand_idx)
    print(train_answers_indices[i], "\t", start_idx, end_idx)
    print("Answer:", train_answers[i], "My answer:", tokenized_train_context[i][start_idx:end_idx+1])
# Out:
# -------------------------------------------------------------------
# ValueError                        Traceback (most recent call last)
# <ipython-input-117-1c8961907053> in <module>()
#       1 my_answers = []
#       2 for i,embed_query in enumerate(embed_train_qs):
# ----> 3     start_idx, end_idx = model.predict(training_input[i:i+1])
#       4     start_idx = np.argmax(start_idx)
#       5     end_idx = np.argmax(end_idx)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1815         x = _standardize_input_data(x, self._feed_input_names,
#    1816                                     self._feed_input_shapes,
# -> 1817                                     check_batch_axis=False)
#    1818         if self.stateful:
#    1819             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#      84                 'Expected to see ' + str(len(names)) + ' array(s), '
#      85                 'but instead got the following list of ' +
# ---> 86                 str(len(data)) + ' arrays: ' + str(data)[:200] + '...')
#      87         elif len(names) > 1:
#      88             raise ValueError(
#
# ValueError: Error when checking model : the list of Numpy arrays that you are passing to your model is not the size the model expected. Expected to see 2 array(s), but instead got the following list of 1 arrays: [array([[[2629954.5, 1538674.2, 2095450. , ...,       0. ,       0. ,
#                0. ],
#         [2796211. , 1635883.6, 2227734. , ...,       0. ,       0. ,
#                0. ],
#         [2092697.8,...

# %% [markdown]
# <b>model 2 GRU seq2seq</b>

# %%
decoder_input_data = np.zeros(
    (trainig_size, 2, max_context_size),
    dtype='float32')

decoder_target_data = np.zeros(
    (trainig_size, 2, max_context_size),
    dtype='float32')

for i, answer_indices in enumerate(train_answers_indices):
    if len(answer_indices) > 1:
        decoder_input_data[i, 1, answer_indices[0]] = 1.
        decoder_target_data[i, 0, answer_indices[0]] = 1.
        decoder_target_data[i, 1, answer_indices[-1]] = 1.

# %%
qc_relations = Input(shape=(None, max_context_size))
encoder_outputs, encoder_state= GRU(output_dim = max_context_size,
                                    return_state = True,
                                    activation = 'tanh')(qc_relations)

decoder_inputs = Input(shape=(None, max_context_size))
decoder_gru = GRU(output_dim = max_context_size,
                  return_sequences = True,
                  return_state = True,
                  activation = 'tanh')
decoder_outputs, _ = decoder_gru(decoder_inputs,
                                 initial_state = encoder_state)
decoder_dense = Dense(max_context_size,
                      activation='softmax')

start_end = decoder_dense(decoder_outputs)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(return_state=True, activation="tanh", units=382)`
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(return_sequences=True, return_state=True, activation="tanh", units=382)`
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([qc_relations, decoder_inputs], start_end)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy') #optimizer
model.fit([training_input, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)

#define inference model
encoder_model = Model(qc_relations, encoder_state)

decoder_state_inputs = Input(shape=(max_context_size,))
decoder_outputs, decoder_state = decoder_gru(decoder_inputs,
                                             initial_state = decoder_state_inputs)
start_end = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs, decoder_state_inputs],
    [start_end, decoder_state])
# Out:
# Train on 19400 samples, validate on 4850 samples
# Epoch 1/12
# 19400/19400 [==============================] - 120s 6ms/step - loss: 1.5670 - val_loss: 1.2180
# Epoch 2/12
# 19400/19400 [==============================] - 115s 6ms/step - loss: 1.1916 - val_loss: 1.0111
# Epoch 3/12
# 19400/19400 [==============================] - 123s 6ms/step - loss: 1.0821 - val_loss: 0.9756
# Epoch 4/12
# 19400/19400 [==============================] - 119s 6ms/step - loss: 1.0583 - val_loss: 0.9611
# Epoch 5/12
# 19400/19400 [==============================] - 123s 6ms/step - loss: 1.0480 - val_loss: 0.9621
# Epoch 6/12
# 19400/19400 [==============================] - 128s 7ms/step - loss: 1.0471 - val_loss: 0.9653
# Epoch 7/12
# 19400/19400 [==============================] - 117s 6ms/step - loss: 1.0465 - val_loss: 0.9608
# Epoch 8/12
# 19400/19400 [==============================] - 118s 6ms/step - loss: 1.0455 - val_loss: 0.9607
# Epoch 9/12
# 19400/19400 [==============================] - 122s 6ms/step - loss: 1.0448 - val_loss: 0.9613
# Epoch 10/12
# 19400/19400 [==============================] - 114s 6ms/step - loss: 1.0442 - val_loss: 0.9607
# Epoch 11/12
# 19400/19400 [==============================] - 117s 6ms/step - loss: 1.0431 - val_loss: 0.9643
# Epoch 12/12
# 19400/19400 [==============================] - 121s 6ms/step - loss: 1.0414 - val_loss: 0.9640

# %%
def get_start_end(question):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(question)

    # Generate empty target sequence of length 1.
    Go_index = np.zeros((1, 1, max_context_size))
    
    start_index , states_value = decoder_model.predict( [Go_index, states_value])
    end_index, _ = decoder_model.predict( [start_index, states_value])

    return start_index, end_index

# %%
my_answers = []
for i,embed_query in enumerate(embed_train_qs):
    start_idx, end_idx = get_start_end(training_input[i:i+1])
    start_idx = np.argmax(start_idx)
    end_idx = np.argmax(end_idx)
    print(train_answers_indices[i], "\t", start_idx, end_idx)
    print("Answer:", train_answers[i], "My answer:", tokenized_train_context[i][start_idx:end_idx+1])
# Out:
# [31] 	 1 10
# Answer: cylinder My answer: ['most', 'urgent', 'unit', 'on', 'the', 'list', 'for', 'redefinition', 'is', 'the']
# [3, 4, 5] 	 3 5
# Answer: time vs. energy My answer: ['time', 'vs.', 'energy']
# [15, 16, 17] 	 15 17
# Answer: quantum of action My answer: ['quantum', 'of', 'action']
# [11] 	 16 17
# Answer: 1913 My answer: ['to', 'overcome']
# [7] 	 5 9
# Answer: h My answer: ['existence', 'of', 'h', '(', 'but']
# [7] 	 5 9
# Answer: h My answer: ['existence', 'of', 'h', '(', 'but']
# [42] 	 34 24
# Answer: f My answer: []
# [9] 	 13 15
# Answer: 1839 My answer: ['is', 'usually', 'reserved']
# [19] 	 6 10
# Answer: 1911 My answer: ['the', '``', 'ultraviolet', 'catastrophe', "''"]
# [78, 79] 	 78 79
# Answer: multiphoton effect My answer: ['multiphoton', 'effect']
# [5, 6] 	 5 6
# Answer: nuclear magneton My answer: ['nuclear', 'magneton']
# [9, 10] 	 9 10
# Answer: 555 nanometres My answer: ['555', 'nanometres']
# [6] 	 16 18
# Answer: 1911 My answer: ['quanta', "''", '.']
# [22, 23] 	 22 23
# Answer: hot atoms My answer: ['hot', 'atoms']
# [6] 	 21 23
# Answer: thermal My answer: ['with', 'the', 'temperature']
# [23] 	 10 11
# Answer: quantum My answer: ['of', 'a']
# [32] 	 17 19
# Answer: forbidden My answer: ['also', 'implies', 'that']
# [23] 	 5 7
# Answer: particles My answer: ['the', 'Planck', 'constant']
# [17, 18] 	 17 18
# Answer: a wave My answer: ['a', 'wave']
# [3] 	 9 10
# Answer: green My answer: ['555', 'nanometres']
# [7] 	 26 27
# Answer: colour My answer: ['hot', "''"]
# [6, 7, 8, 9, 10] 	 6 10
# Answer: the `` ultraviolet catastrophe '' My answer: ['the', '``', 'ultraviolet', 'catastrophe', "''"]
# [] 	 13 14
# Answer: the kilogram My answer: ['the', 'current']
# [13] 	 2 3
# Answer: intensity My answer: ['transferred', 'by']
# [31, 32] 	 31 32
# Answer: watt-balance measurement My answer: ['watt-balance', 'measurement']
# [25, 26, 27] 	 25 27
# Answer: a circular argument My answer: ['a', 'circular', 'argument']
# [21, 22] 	 21 22
# Answer: the frequency My answer: ['the', 'frequency']
# [] 	 7 11
# Answer: the light quantum My answer: ['minimal', 'energy', 'increment', 'of', 'a']
# [] 	 18 20
# Answer: time vs. energy My answer: ['is', 'to', 'say']
# [5] 	 17 19
# Answer: sound My answer: ['own', 'intensity', '.']
# [18] 	 18 19
# Answer: thermal My answer: ['thermal', 'light']
# [12, 13] 	 12 14
# Answer: physical action My answer: ['physical', 'action', 'can']
# [4, 5, 6] 	 4 6
# Answer: laws of motion My answer: ['laws', 'of', 'motion']
# [9, 10] 	 9 10
# Answer: 555 nanometres My answer: ['555', 'nanometres']
# [16] 	 29 32
# Answer: relativity My answer: ['in', 'discovery', 'or', 'experiment']
# [3, 4] 	 3 4
# Answer: the quantity My answer: ['the', 'quantity']
# [4] 	 13 15
# Answer: 1918 My answer: ['the', 'services', 'he']
# [15] 	 15 16
# Answer: black-body My answer: ['black-body', 'radiation']
# [26] 	 6 8
# Answer: h My answer: ['which', 'correctly', 'predicts']
# [15, 16, 17] 	 15 17
# Answer: quantum of action My answer: ['quantum', 'of', 'action']
# [33] 	 11 12
# Answer: platinum–iridium My answer: ['kilogram', ',']
# [9, 10] 	 9 10
# Answer: blackbody emissions My answer: ['blackbody', 'emissions']
# [30] 	 31 32
# Answer: 2007 My answer: ['watt-balance', 'measurement']
# [18, 19, 20] 	 18 20
# Answer: thermal light emission My answer: ['thermal', 'light', 'emission']
# [25, 26] 	 25 26
# Answer: white hot My answer: ['white', 'hot']
# [15, 16] 	 15 16
# Answer: black-body radiation My answer: ['black-body', 'radiation']
# [13] 	 10 14
# Answer: intensity My answer: ['is', 'called', 'its', 'intensity', '.']
# [19] 	 26 28
# Answer: 1921 My answer: ['confirmed', 'by', 'the']
# [2, 3, 4] 	 2 4
# Answer: the energy account My answer: ['the', 'energy', 'account']
# [1] 	 10 11
# Answer: 1905 My answer: ['of', 'a']
# [17, 18] 	 17 18
# Answer: a wave My answer: ['a', 'wave']
# [22] 	 15 16
# Answer: forty My answer: ['black-body', 'radiation']
# [6] 	 16 18
# Answer: 1911 My answer: ['quanta', "''", '.']
# [6] 	 6 7
# Answer: light My answer: ['light', 'absorbs']
# [11] 	 13 15
# Answer: hotter My answer: ['glow', 'brighter', 'than']
# [10] 	 30 32
# Answer: accurate My answer: ['the', 'Stefan–Boltzmann', 'law']
# [22] 	 16 17
# Answer: silicon My answer: ['and', 'the']
# [30, 31, 32] 	 30 32
# Answer: the stefan–boltzmann law My answer: ['the', 'Stefan–Boltzmann', 'law']
# [20, 21, 22] 	 20 22
# Answer: renewable energy technologies My answer: ['renewable', 'energy', 'technologies']
# [5] 	 11 12
# Answer: 2006 My answer: ['political', 'agenda']
# [8, 9, 10] 	 8 10
# Answer: $ 140.4 billion My answer: ['$', '140.4', 'billion']
# [26, 27] 	 26 27
# Answer: global warming My answer: ['global', 'warming']
# [3] 	 7 8
# Answer: three My answer: ['than', '10']
# [24] 	 1 12
# Answer: half My answer: ['IEA', 'has', 'said', ':', '``', 'Photovoltaic', 'and', 'solar-thermal', 'plants', 'may', 'meet', 'most']
# [12, 13, 14] 	 12 14
# Answer: renewable energy policy My answer: ['renewable', 'energy', 'policy']
# [5, 6] 	 5 6
# Answer: 58 percent My answer: ['58', 'percent']
# [8, 9] 	 8 9
# Answer: 18.1 percent My answer: ['18.1', 'percent']
# [16, 17] 	 16 17
# Answer: 22 percent My answer: ['22', 'percent']
# [5] 	 5 6
# Answer: renewables My answer: ['renewables', 'exceeded']
# [] 	 12 13
# Answer: tax shifting My answer: ['there', 'as']
# [5, 6] 	 3 16
# Answer: 19 % My answer: ['for', 'approximately', '19', '%', 'of', 'electricity', 'generated', 'in', 'Denmark', ',', '9', '%', 'in', 'Spain']
# [13, 14, 15] 	 13 15
# Answer: social and political My answer: ['social', 'and', 'political']
# [21] 	 15 17
# Answer: 2060 My answer: ['world', "'s", 'demand']
# [13, 14] 	 13 14
# Answer: 10 percent My answer: ['10', 'percent']
# [3] 	 10 12
# Answer: hydroelectricity My answer: ['competitive', 'source', 'of']
# [] 	 4 6
# Answer: renewable energy commercialization My answer: ['the', 'deployment', 'of']
# [3] 	 6 7
# Answer: 144 My answer: ['renewable', 'energy']
# [9, 10] 	 9 10
# Answer: 19 percent My answer: ['19', 'percent']
# [22] 	 7 8
# Answer: coal My answer: ['disrupting', 'subsidies']
# [2] 	 19 20
# Answer: 2011 My answer: ['technologies', ':']
# [10] 	 8 9
# Answer: 2008 My answer: ['prices', 'since']
# [4, 5] 	 4 5
# Answer: renewable energy My answer: ['renewable', 'energy']
# [3] 	 10 12
# Answer: hydroelectricity My answer: ['competitive', 'source', 'of']
# [13, 14] 	 3 16
# Answer: 9 % My answer: ['for', 'approximately', '19', '%', 'of', 'electricity', 'generated', 'in', 'Denmark', ',', '9', '%', 'in', 'Spain']
# [10, 11] 	 10 11
# Answer: renewable energy My answer: ['renewable', 'energy']
# [26, 27] 	 26 27
# Answer: 17 percent My answer: ['17', 'percent']
# [8, 9, 10] 	 8 10
# Answer: $ 244 billion My answer: ['$', '140.4', 'billion']
# [13, 14] 	 13 14
# Answer: market expansion My answer: ['market', 'expansion']
# [7] 	 7 8
# Answer: 2030 My answer: ['2030', '.']
# [4] 	 2 6
# Answer: 150 My answer: ['produced', 'in', '150', 'countries', ',']
# [4, 5, 6, 7] 	 4 7
# Answer: renewable technologies My answer: ['renewable', 'power', 'generation', 'technologies']
# [1, 2, 3, 4] 	 1 4
# Answer: $ 1.00/w installed cost My answer: ['$', '1.00/W', 'installed', 'cost']
# [36] 	 36 20
# Answer: 2030 My answer: []
# [] 	 22 23
# Answer: energy regulators My answer: ['projects', '.']
# [4, 5] 	 4 5
# Answer: renewable energy My answer: ['renewable', 'energy']
# [4, 5] 	 4 5
# Answer: renewable energy My answer: ['renewable', 'energy']
# [1] 	 17 18
# Answer: 1958 My answer: ['by', 'making']
# [8] 	 15 16
# Answer: 1997 My answer: ['its', 'sequels']
# [9] 	 9 10
# Answer: 1995 My answer: ['1995', 'when']
# [1, 2] 	 1 2
# Answer: vice president My answer: ['vice', 'president']
# [1] 	 18 19
# Answer: 1997 My answer: ['#', '9']
# [27] 	 16 18
# Answer: 1,100 My answer: ['Oskar', 'Schindler', ',']
# [9] 	 6 7
# Answer: 2005 My answer: ['inducted', 'Spielberg']
# [14] 	 15 18
# Answer: intrusive My answer: [',', 'and', 'feels', 'making']
# [10] 	 10 12
# Answer: 1993 My answer: ['1993', ')', '—achieved']
# [2] 	 10 12
# Answer: 1984 My answer: ['November', '1985', ',']
# [11, 12, 13] 	 11 13
# Answer: $ 200 million My answer: ['$', '481', 'million']
# [18, 19] 	 18 19
# Answer: # 9 My answer: ['#', '9']
# [6] 	 27 28
# Answer: 1989 My answer: ['.']
# [8] 	 1 2
# Answer: 1979 My answer: ['a', 'result']
# [21, 22] 	 21 22
# Answer: the 1930s My answer: ['the', '1930s']
# [13, 14] 	 13 8
# Answer: his father My answer: []
# [31, 32] 	 31 32
# Answer: his father My answer: ['his', 'father']
# [2] 	 4 6
# Answer: 1984 My answer: ['renewed', 'their', 'romance']
# [13, 14] 	 13 14
# Answer: 15–20 years My answer: ['15–20', 'years']
# [17] 	 20 22
# Answer: two My answer: [',', 'including', 'one']
# [4] 	 6 8
# Answer: co-producer My answer: ['the', '1987', 'film']
# [2] 	 5 6
# Answer: five My answer: ['nominations', ',']
# [16] 	 12 13
# Answer: 26-minute My answer: ['theatrical', 'release']
# [13] 	 7 8
# Answer: actress My answer: ['also', 'met']
# [13] 	 6 9
# Answer: four My answer: ['work', ',', 'Universal', 'signed']
# [23] 	 1 2
# Answer: seven-year My answer: ['vice', 'president']
# [18] 	 1 3
# Answer: 1989 My answer: ['two', 'forays', 'into']
# [20] 	 13 14
# Answer: cinematography My answer: ['of', 'America']
# [13] 	 6 9
# Answer: four My answer: ['work', ',', 'Universal', 'signed']
# [7] 	 15 17
# Answer: poorly My answer: ['limited', 'release', '.']
# [23] 	 16 18
# Answer: 1996 My answer: ["'s", 'Chair', ',']
# [24] 	 8 10
# Answer: 1980 My answer: [',', 'with', 'financial']
# [13] 	 3 4
# Answer: six My answer: ['received', 'positive']
# [18] 	 49 50
# Answer: 1982 My answer: ['London', 'which']
# [15, 16, 17] 	 15 17
# Answer: reportedly close friends My answer: ['reportedly', 'close', 'friends']
# [50] 	 35 36
# Answer: terrorism My answer: ['the', 'Sun']
# [10] 	 9 10
# Answer: 1981 My answer: ['in', '1981']
# [18] 	 9 10
# Answer: editing My answer: ['small', 'unpaid']
# [6] 	 5 2
# Answer: impressed My answer: []
# [9] 	 20 22
# Answer: 2005 My answer: [',', 'including', 'one']
# [7, 8, 9, 10] 	 7 10
# Answer: exceeds $ 9 billion My answer: ['exceeds', '$', '9', 'billion']
# [1] 	 1 3
# Answer: two My answer: ['two', 'forays', 'into']
# [25] 	 6 7
# Answer: 1989 My answer: ['of', 'marriage']
# [7] 	 10 12
# Answer: 1974 My answer: ['has', 'been', 'an']
# [26] 	 12 14
# Answer: three My answer: ['Academy', 'Award', 'for']
# [3] 	 2 4
# Answer: eleven My answer: ['received', 'eleven', 'Academy']
# [2, 3] 	 2 3
# Answer: science fiction My answer: ['science', 'fiction']
# [3] 	 19 22
# Answer: actress My answer: ['he', 'was', 'looking', 'for']
# [4] 	 3 4
# Answer: two My answer: ['in', 'two']
# [6] 	 5 6
# Answer: 1975 My answer: ['(', '1975']
# [] 	 24 25
# Answer: `` bachelor funky '' My answer: ['greatly', 'influenced']
# [1] 	 1 3
# Answer: two My answer: ['two', 'forays', 'into']
# [24] 	 5 7
# Answer: 1994 My answer: ['own', 'directorial', 'copy']
# [18] 	 1 28
# Answer: 1969 My answer: ['first', 'professional', 'TV', 'job', 'came', 'when', 'he', 'was', 'hired', 'to', 'direct', 'one', 'of', 'the', 'segments', 'for', 'the', '1969', 'pilot', 'episode', 'of', 'Night', 'Gallery', '.']
# [47] 	 19 20
# Answer: 1953 My answer: ['and', 'DreamWorks']
# [38] 	 38 39
# Answer: 2054 My answer: ['2054', 'who']
# [21] 	 5 7
# Answer: 1938 My answer: ['own', 'directorial', 'copy']
# [7, 8, 9] 	 7 9
# Answer: $ 250 million My answer: ['$', '250', 'million']
# [7] 	 10 11
# Answer: 2014 My answer: ['Spielberg', 'was']
# [6] 	 30 32
# Answer: 2149 My answer: ['85', 'million', 'years']
# [5, 6] 	 13 8
# Answer: $ 500 My answer: []
# [8, 9] 	 8 9
# Answer: during childhood My answer: ['during', 'childhood']
# [36] 	 7 9
# Answer: six My answer: ['and', 'directed', 'by']
# [64] 	 63 64
# Answer: 1999 My answer: ['(', '1999']
# [25] 	 5 6
# Answer: 2018 My answer: ['early', '2017']
# [26] 	 12 14
# Answer: three My answer: ['Academy', 'Award', 'for']
# [8, 9, 10, 11] 	 8 11
# Answer: $ 470 million worldwide My answer: ['$', '9', 'billion', 'worldwide']
# [15, 16] 	 15 16
# Answer: 92 % My answer: ['92', '%']
# [30, 31, 32] 	 30 32
# Answer: 85 million years My answer: ['85', 'million', 'years']
# [33] 	 31 33
# Answer: embarrassed My answer: ['I', 'was', 'embarrassed']
# [2] 	 10 15
# Answer: 2010 My answer: ['again', 'with', 'co-producer', 'Tom', 'Hanks', ',']
# [45] 	 13 14
# Answer: 2009 My answer: ['the', 'January']
# [13] 	 10 12
# Answer: three My answer: ["'s", 'first', 'of']
# [2] 	 2 3
# Answer: thirteen My answer: ['thirteen', ',']
# [15] 	 2 3
# Answer: 40-minute My answer: ['thirteen', ',']
# [12] 	 42 40
# Answer: 1858 My answer: []
# [11] 	 21 22
# Answer: 2001 My answer: ['.']
# [1] 	 15 16
# Answer: 2002 My answer: ['Rice-Eccles', 'Stadium']
# [8, 9] 	 8 9
# Answer: 47 % My answer: ['47', '%']
# [33, 34] 	 33 34
# Answer: electrical engineer My answer: ['electrical', 'engineer']
# [14, 15] 	 14 15
# Answer: a headteacher My answer: ['a', 'headteacher']
# [23, 24, 25] 	 23 24
# Answer: as a child My answer: ['as', 'a']
# [16] 	 11 12
# Answer: 1941 My answer: ['sled', 'from']
# [21] 	 17 18
# Answer: guns My answer: ['roles', 'formerly']
# [23] 	 23 24
# Answer: 1950s My answer: ['1950s', ',']
# [35, 36] 	 35 36
# Answer: anti-aircraft artillery My answer: ['anti-aircraft', 'artillery']
# [10, 11] 	 10 11
# Answer: the railgun My answer: ['the', 'railgun']
# [17, 18] 	 17 18
# Answer: machine guns My answer: ['machine', 'guns']
# [36, 37, 38] 	 36 38
# Answer: the late 1960s My answer: ['the', 'late', '1960s']
# [13] 	 11 13
# Answer: mechanical My answer: [')', 'or', 'mechanical']
# [18, 19, 20] 	 18 20
# Answer: self-propelled anti-aircraft guns My answer: ['self-propelled', 'anti-aircraft', 'guns']
# [12] 	 9 10
# Answer: 1918 My answer: ['3.6-inch', ',']
# [43, 44, 45] 	 43 45
# Answer: 90 km away My answer: ['90', 'km', 'away']
# [3, 4] 	 21 23
# Answer: air defence My answer: ['smaller', 'force', 'levels']
# [4, 5] 	 31 32
# Answer: air defence My answer: ['guided', 'missiles']
# [11, 12] 	 11 12
# Answer: non-ballistic factors My answer: ['non-ballistic', 'factors']
# [5, 6, 7] 	 5 7
# Answer: for anti-aircraft fire My answer: ['for', 'anti-aircraft', 'fire']
# [1] 	 3 4
# Answer: 3-inch My answer: ['in', 'development']
# [12, 13] 	 12 13
# Answer: aimed fire My answer: ['aimed', 'fire']
# [14, 15] 	 14 15
# Answer: the backblast My answer: ['the', 'backblast']
# [10] 	 7 8
# Answer: 1925 My answer: ['Corps', 'formed']
# [5] 	 10 11
# Answer: 183 My answer: ['(', 'most']
# [26] 	 51 53
# Answer: four My answer: ['(', 'as', 'a']
# [3, 4, 5] 	 3 5
# Answer: solid fuel rockets My answer: ['solid', 'fuel', 'rockets']
# [9, 10] 	 9 10
# Answer: homeland defence My answer: ['homeland', 'defence']
# [8, 9] 	 8 9
# Answer: 24,000 feet My answer: ['24,000', 'feet']
# [1] 	 10 11
# Answer: radar My answer: ['hostile', 'aircraft']
# [12, 13] 	 12 13
# Answer: guided missiles My answer: ['guided', 'missiles']
# [23] 	 15 16
# Answer: 125 My answer: ['it', 'had']
# [41] 	 29 30
# Answer: permanently My answer: ['in', 'friendly']
# [21] 	 31 32
# Answer: aircraft My answer: ['guided', 'missiles']
# [10, 11] 	 10 11
# Answer: the kerrison predictor My answer: ['the', 'predictor']
# [28] 	 17 18
# Answer: 1925 My answer: ['ADGB', ')']
# [24] 	 32 34
# Answer: bombers My answer: ['altitude', 'capabilities', '.']
# [10, 11, 12] 	 10 12
# Answer: 2 to 12 My answer: ['2', 'to', '12']
# [9, 10] 	 9 10
# Answer: elevation angle My answer: ['elevation', 'angle']
# [6] 	 5 6
# Answer: 1940 My answer: ['in', '1940']
# [2] 	 10 4
# Answer: altitude My answer: []
# [32] 	 2 13
# Answer: 1954 My answer: ['divided', 'into', 'two', 'arms', ',', 'PVO', 'Strany', ',', 'the', 'Strategic', 'Air', 'defence']
# [3, 4, 5, 6] 	 3 6
# Answer: `` effective ceiling '' My answer: ['``', 'effective', 'ceiling', "''"]
# [19, 20, 21] 	 19 21
# Answer: 8 july 1914 My answer: ['8', 'July', '1914']
# [33, 34] 	 33 34
# Answer: its height My answer: ['its', 'height']
# [27, 28] 	 27 28
# Answer: experimental usefulness My answer: ['experimental', 'usefulness']
# [8, 9] 	 8 9
# Answer: 18-pdr guns My answer: ['18-pdr', 'guns']
# [4, 5] 	 4 5
# Answer: into battalions My answer: ['into', 'battalions']
# [27, 28, 29] 	 27 29
# Answer: for 20 seconds My answer: ['for', '20', 'seconds']
# [22, 23, 24, 25] 	 22 25
# Answer: the carrier 's escorts My answer: ['the', 'carrier', "'s", 'escorts']
# [5] 	 17 18
# Answer: missiles My answer: ['.']
# [2, 3] 	 2 3
# Answer: the maximum distance My answer: ['the', 'distance']
# [] 	 14 15
# Answer: the gun My answer: ['a', 'movie']
# [7, 8, 9] 	 7 9
# Answer: three aa corps My answer: ['three', 'AA', 'corps']
# [21] 	 1 3
# Answer: 1943 My answer: ['firing', 'of', 'one']
# [7, 8, 9] 	 7 9
# Answer: a steel plate My answer: ['a', 'steel', 'plate']
# [25, 26] 	 25 26
# Answer: slide rules My answer: ['slide', 'rules']
# [7] 	 5 6
# Answer: shrapnel My answer: [')', 'and']
# [18, 19] 	 18 19
# Answer: smallest mounts My answer: ['smallest', 'mounts']
# [3] 	 51 52
# Answer: 1924 My answer: ['and', 'ground']
# [7] 	 15 16
# Answer: searchlights My answer: ['of', 'detection']
# [9, 10] 	 9 10
# Answer: barrage balloons My answer: ['barrage', 'balloons']
# [1] 	 16 17
# Answer: 2-inch My answer: ['or', 'dive']
# [17, 18, 19] 	 17 19
# Answer: `` archibald , certainly not ! '' My answer: ['``', 'ack-ack', "''"]
# [30, 31] 	 30 31
# Answer: fighter jets My answer: ['fighter', 'jets']
# [7, 8, 9] 	 7 9
# Answer: detect hostile aircraft My answer: ['detect', 'hostile', 'aircraft']
# [9] 	 1 2
# Answer: minimal My answer: ['balloons', 'were']
# [4, 5] 	 4 5
# Answer: guided missile My answer: ['guided', 'missile']
# [31, 32] 	 31 32
# Answer: guided missiles My answer: ['guided', 'missiles']
# [4, 5] 	 4 5
# Answer: important buildings My answer: ['important', 'buildings']
# [14] 	 1 2
# Answer: 1950s My answer: ['90', 'mm']
# [23, 24] 	 23 24
# Answer: the u.s. army My answer: ['the', 'army']
# [6, 7] 	 6 7
# Answer: maximum ceiling My answer: ['maximum', 'ceiling']
# [9] 	 6 8
# Answer: .50-inch My answer: ['anything', 'larger', 'than']
# [25, 26, 27, 28, 29] 	 25 29
# Answer: `` flaktürme '' flak towers My answer: ['``', 'Flaktürme', "''", 'flak', 'towers']
# [9, 10] 	 9 10
# Answer: homeland air defence My answer: ['homeland', 'defence']
# [1] 	 3 4
# Answer: 1925 My answer: ['British', 'adopted']
# [8, 9] 	 8 9
# Answer: the laser My answer: ['the', 'laser']
# [38] 	 14 15
# Answer: 1990 My answer: ['artillery', 'arm']
# [6, 7, 8] 	 6 8
# Answer: machine-gun based weapons My answer: ['machine-gun', 'based', 'weapons']
# [4] 	 13 31
# Answer: eight My answer: ['advanced', 'by', 'the', 'late', '1930s', 'for', 'development', 'work', 'on', 'sound', 'locating', 'acoustic', 'devices', 'to', 'be', 'generally', 'halted', ',', 'although']
# [1] 	 18 20
# Answer: 1928 My answer: []
# [11, 12] 	 7 9
# Answer: destroy them My answer: ['detect', 'hostile', 'aircraft']
# [30, 31] 	 30 31
# Answer: 60,000 ft My answer: ['60,000', 'ft']
# [21, 22, 23] 	 21 23
# Answer: 30-second running time My answer: ['30-second', 'running', 'time']
# [11, 12, 13] 	 11 13
# Answer: speed and height My answer: ['speed', 'and', 'height']
# [17] 	 2 11
# Answer: 74 My answer: ['1916', 'there', 'were', '183', 'AA', 'Sections', 'defending', 'Britain', '(', 'most']
# [20, 21] 	 20 21
# Answer: lighter weapons My answer: ['lighter', 'weapons']
# [25, 26] 	 25 26
# Answer: predicted trajectory My answer: ['predicted', 'trajectory']
# [9, 10] 	 9 10
# Answer: anti-stealth technology My answer: ['anti-stealth', 'technology']
# [14, 15] 	 14 15
# Answer: a movie My answer: ['a', 'movie']
# [1, 2, 3] 	 1 3
# Answer: 30 september 1915 My answer: ['30', 'September', '1915']
# [15] 	 30 31
# Answer: aéronef My answer: ['airship', ',']
# [17] 	 12 14
# Answer: 2004 My answer: ['(', 'RAF', ')']
# [18, 19, 20] 	 10 12
# Answer: fire control elements My answer: ['2', 'to', '12']
# [7] 	 2 4
# Answer: mobile My answer: ['air', 'defence', 'systems']
# [7, 8, 9] 	 7 9
# Answer: 2020 to 2025 My answer: ['2020', 'to', '2025']
# [7] 	 6 7
# Answer: zenitnye My answer: ['called', 'zenitnye']
# [3, 4, 5] 	 3 5
# Answer: a 3.7 cm My answer: ['a', '3.7', 'cm']
# [9, 10] 	 9 10
# Answer: air-search radar My answer: ['air-search', 'radar']
# [14] 	 7 9
# Answer: autocannons My answer: ['cheap', 'short-range', 'missiles']
# [13, 14] 	 13 14
# Answer: the 1960s My answer: ['the', '1960s']
# [5] 	 5 6
# Answer: 1943 My answer: ['1943', 'an']
# [5, 6] 	 5 6
# Answer: steel cable My answer: ['steel', 'cable']
# [] 	 1 2
# Answer: the interceptor aircraft My answer: ['and', 'altitude']
# [34, 35, 36] 	 34 36
# Answer: speed and direction My answer: ['speed', 'and', 'direction']
# [43] 	 12 13
# Answer: 100 My answer: ['next', 'layers']
# [1, 2] 	 1 2
# Answer: short range My answer: ['short', 'range']
# [38, 39] 	 38 39
# Answer: infantry positions My answer: ['infantry', 'positions']
# [14, 15] 	 14 15
# Answer: artillery arm My answer: ['artillery', 'arm']
# [4, 5] 	 4 5
# Answer: range measurement My answer: ['range', 'measurement']
# [16, 17] 	 16 17
# Answer: passive measures My answer: ['passive', 'measures']
# [12] 	 11 12
# Answer: concealment My answer: ['and', 'concealment']
# [39] 	 37 39
# Answer: hydraulics My answer: ['which', 'used', 'hydraulics']
# [4] 	 9 10
# Answer: 1935 My answer: ['following', 'year']
# [1] 	 6 7
# Answer: 1938 My answer: ['12.8', 'cm']
# [13, 14] 	 13 14
# Answer: anti-aircraft warfare My answer: ['anti-aircraft', 'warfare']
# [10, 11] 	 14 15
# Answer: the user My answer: ['the', 'backblast']
# [20, 21, 22] 	 20 22
# Answer: most anti-aircraft gunnery My answer: ['most', 'anti-aircraft', 'gunnery']
# [11, 12, 13] 	 11 13
# Answer: in the air My answer: ['in', 'the', 'air']
# [15] 	 15 16
# Answer: 45 My answer: ['45', 'bombs']
# [26, 27] 	 26 27
# Answer: many kilometers My answer: ['many', 'kilometers']
# [21, 22, 23] 	 21 23
# Answer: smaller force levels My answer: ['smaller', 'force', 'levels']
# [32] 	 23 25
# Answer: optronics My answer: ['by', 'radar', ',']
# [17] 	 6 7
# Answer: vertically My answer: ['maximum', 'ceiling']
# [] 	 9 10
# Answer: air forces My answer: ['homeland', 'defence']
# [9, 10] 	 9 10
# Answer: ground forces My answer: ['ground', 'forces']
# [21] 	 17 18
# Answer: guns My answer: ['roles', 'formerly']
# [24, 25] 	 24 25
# Answer: 75 mm My answer: ['75', 'mm']
# [9] 	 8 11
# Answer: trailers My answer: ['on', 'trailers', 'and', 'are']
# [7, 8, 9, 10, 11] 	 7 11
# Answer: counter-air defence My answer: ['counter-air', 'and', 'naval', 'air', 'defence']
# [13, 14, 15] 	 13 15
# Answer: in the 1960s My answer: ['in', 'the', '1960s']
# [23] 	 6 7
# Answer: 3 My answer: ['which', 'was']
# [] 	 28 29
# Answer: area air defence My answer: ['armies', '(']
# [8, 9] 	 8 9
# Answer: the cold war My answer: ['the', 'war']
# [17, 18, 19] 	 17 19
# Answer: 90-day screening period My answer: ['90-day', 'screening', 'period']
# [5, 6] 	 5 6
# Answer: $ 500,000 My answer: ['$', '500,000']
# [4, 5] 	 4 5
# Answer: eight years My answer: ['eight', 'years']
# [21] 	 38 9
# Answer: seven My answer: []
# [30] 	 10 12
# Answer: butterflies My answer: ['on', '``', 'an']
# [6, 7] 	 6 7
# Answer: two ways My answer: ['two', 'ways']
# [28, 29] 	 28 29
# Answer: the clinton administration My answer: ['the', 'administration']
# [11, 12] 	 11 12
# Answer: 16 birds My answer: ['16', 'birds']
# [] 	 11 12
# Answer: habitat conservation plan My answer: ['``', 'an']
# [12, 13] 	 12 13
# Answer: 45 days My answer: ['45', 'days']
# [18, 19] 	 18 19
# Answer: cotton-top tamarin My answer: ['cotton-top', 'tamarin']
# [11] 	 30 9
# Answer: twenty-eight My answer: []
# [29, 30, 31] 	 29 31
# Answer: candidate assessment program My answer: ['candidate', 'assessment', 'program']
# [8, 9, 10, 11, 12] 	 8 12
# Answer: `` class of '67 '' My answer: ['``', 'Class', 'of', "'67", "''"]
# [9, 10] 	 9 10
# Answer: over 2,000 My answer: ['over', '2,000']
# [24, 25] 	 24 25
# Answer: the northwest My answer: ['the', 'northwest']
# [29, 30, 31] 	 29 31
# Answer: about 75 % My answer: ['about', '70', '%']
# [7, 8] 	 17 21
# Answer: 2.8 % My answer: ['in', 'other', 'Southern', 'African', 'Customs']
# [1, 2, 3] 	 1 3
# Answer: the early seventies My answer: ['the', 'early', 'seventies']
# [13] 	 11 15
# Answer: one My answer: ['each', 'elects', 'one', 'representative', 'to']
# [] 	 12 13
# Answer: the king My answer: ['a', 'minority']
# [5] 	 3 5
# Answer: five My answer: ['held', 'every', 'five']
# [19, 20, 21] 	 19 21
# Answer: a five-year term My answer: ['a', 'five-year', 'term']
# [18, 19, 20] 	 18 20
# Answer: neighbourhood care points My answer: ['neighbourhood', 'care', 'points']
# [2] 	 4 5
# Answer: four My answer: ['geographical', 'regions']
# [6] 	 10 12
# Answer: four My answer: ['is', 'ten', '.']
# [16, 17, 18, 19] 	 16 19
# Answer: more than 50 % My answer: ['more', 'than', '50', '%']
# [12, 13] 	 12 13
# Answer: textile manufacturing My answer: ['textile', 'manufacturing']
# [17, 18, 19] 	 17 19
# Answer: 9 september 1964 My answer: ['9', 'September', '1964']
# [10] 	 8 10
# Answer: liqoqo My answer: ['Council', '(', 'liqoqo']
# [28, 29] 	 28 29
# Answer: 20 % My answer: ['20', '%']
# [6, 7] 	 6 7
# Answer: 17,364 km2 My answer: ['17,364', 'km2']
# [19, 20] 	 19 20
# Answer: 38.8 % My answer: ['38.8', '%']
# [6, 7] 	 6 7
# Answer: mid-18th century My answer: ['mid-18th', 'century']
# [4] 	 1 3
# Answer: king My answer: ['literally', 'means', '``']
# [7, 8, 9] 	 7 9
# Answer: at the inkhundla My answer: ['at', 'the', 'inkhundla']
# [2] 	 1 4
# Answer: 14 My answer: ['are', '14', 'Jewish', 'families']
# [6] 	 2 4
# Answer: kubhula My answer: ['is', 'based', 'on']
# [9, 10] 	 9 10
# Answer: 18 % My answer: ['18', '%']
# [18, 19] 	 18 19
# Answer: the majority My answer: ['the', 'majority']
# [20, 21] 	 20 21
# Answer: the chiefdoms My answer: ['the', 'chiefdoms']
# [5, 6] 	 2 3
# Answer: $ 9,714 My answer: ['per', 'capita']
# [6, 7, 8] 	 6 8
# Answer: 5-year or younger My answer: ['5-year', 'or', 'younger']
# [15] 	 12 13
# Answer: three My answer: ['programme', 'divided']
# [14] 	 11 12
# Answer: 10 My answer: ['30', 'seats']
# [18, 19, 20] 	 18 20
# Answer: over 90 % My answer: ['over', '90', '%']
# [13, 14, 15] 	 13 15
# Answer: indvuna ye nkhundla My answer: ['indvuna', 'ye', 'nkhundla']
# [19] 	 22 23
# Answer: 1906 My answer: ['Transvaal', 'colony']
# [14, 15, 16] 	 14 16
# Answer: at least ten My answer: ['at', 'least', 'ten']
# [] 	 16 21
# Answer: constituency executive committee My answer: ['its', 'area', 'for', 'a', 'five-year', 'term']
# [11, 12] 	 11 12
# Answer: 30 seats My answer: ['30', 'seats']
# [3, 4] 	 3 4
# Answer: 21.6 % My answer: ['21.6', '%']
# [27] 	 30 32
# Answer: 1982 My answer: []
# [1] 	 12 13
# Answer: 1903 My answer: ['became', 'a']
# [12, 13, 14] 	 12 14
# Answer: 19 august 2005 My answer: ['19', 'August', '2005']
# [33, 34, 35, 36] 	 33 36
# Answer: less than 20 % My answer: ['less', 'than', '20', '%']
# [0, 1] 	 0 1
# Answer: 83 % My answer: ['83', '%']
# [1, 2, 3, 4] 	 1 4
# Answer: childless , unmarried girls My answer: ['childless', ',', 'unmarried', 'girls']
# [17, 18] 	 17 18
# Answer: 81 mi My answer: ['81', 'mi']
# [10, 11] 	 10 11
# Answer: declined markedly My answer: ['declined', 'markedly']
# [5, 6, 7] 	 5 7
# Answer: all young girls My answer: ['all', 'young', 'girls']
# [12] 	 14 15
# Answer: 1972 My answer: ['an', 'International']
# [11, 12] 	 11 12
# Answer: 55 % My answer: ['55', '%']
# [3, 4, 5] 	 3 5
# Answer: a traditional diviner My answer: ['a', 'traditional', 'diviner']
# [12, 13] 	 12 13
# Answer: a minority My answer: ['a', 'minority']
# [27] 	 17 18
# Answer: 2013 My answer: ['would', 'not']
# [16, 17] 	 16 17
# Answer: home appliances My answer: ['home', 'appliances']
# [3, 4, 5] 	 5 6
# Answer: about 45 % My answer: ['%', 'of']
# [4, 5] 	 4 5
# Answer: twelve jurists My answer: ['twelve', 'jurists']
# [15, 16, 17] 	 15 17
# Answer: rugged mountain ranges My answer: ['rugged', 'mountain', 'ranges']
# [7, 8, 9] 	 7 9
# Answer: $ 15 billion My answer: ['$', '15', 'billion']
# [13, 14] 	 13 14
# Answer: 70,000 citizens My answer: ['70,000', 'citizens']
# [8, 9, 10] 	 8 10
# Answer: 636,372 sq mi My answer: ['636,372', 'sq', 'mi']
# [16, 17] 	 16 17
# Answer: below zero My answer: ['below', 'zero']
# [8, 9, 10] 	 8 10
# Answer: one week annually My answer: ['one', 'week', 'annually']
# [1] 	 3 4
# Answer: 2006 My answer: ['six', 'Iranian']
# [7, 8] 	 7 8
# Answer: foreign embargoes My answer: ['foreign', 'embargoes']
# [1] 	 11 13
# Answer: 1960s My answer: ['25', 'commercial', 'films']
# [19, 20] 	 19 20
# Answer: 33,000 megawatts My answer: ['33,000', 'megawatts']
# [41, 42, 43] 	 41 43
# Answer: proven oil reserves My answer: ['proven', 'oil', 'reserves']
# [9, 10] 	 9 10
# Answer: four-year terms My answer: ['four-year', 'terms']
# [19] 	 12 14
# Answer: 90,000 My answer: ['called', 'the', 'Basij']
# [25] 	 11 13
# Answer: 65 My answer: ['25', 'commercial', 'films']
# [23, 24, 25, 26] 	 23 26
# Answer: the sassanid empire My answer: ['the', 'most', 'powerful', 'empire']
# [23, 24] 	 23 24
# Answer: 156 years My answer: ['156', 'years']
# [11, 12] 	 11 12
# Answer: 22 % My answer: ['22', '%']
# [8] 	 15 17
# Answer: embargo My answer: ['affected', 'the', 'economy']
# [10, 11] 	 10 11
# Answer: 153,600,000,000 barrels My answer: ['153,600,000,000', 'barrels']
# [7] 	 4 5
# Answer: six My answer: ['twelve', 'jurists']
# [1] 	 19 20
# Answer: 2010 My answer: ['targeted', 'social']
# [11, 12, 13] 	 11 13
# Answer: 25 commercial films My answer: ['25', 'commercial', 'films']
# [13, 14] 	 13 14
# Answer: in 1906 My answer: ['in', '1906']
# [13, 14] 	 13 14
# Answer: construction materials My answer: ['construction', 'materials']
# [11] 	 5 7
# Answer: 19 My answer: ['is', 'reflected', 'in']
# [62, 63, 64] 	 62 64
# Answer: the achaemenid empire My answer: ['the', 'largest', 'empire']
# [10, 11, 12, 13] 	 10 13
# Answer: mamluks ( slave-warriors ) My answer: ['mamluks', '(', 'slave-warriors', ')']
# [46] 	 13 17
# Answer: watermelons My answer: ['following', 'agricultural', 'products', 'in', 'the']
# [7, 8] 	 7 8
# Answer: the 1979 constitution My answer: ['the', 'constitution']
# [18, 19] 	 18 19
# Answer: were executed My answer: ['were', 'executed']
# [33] 	 13 14
# Answer: petrochemicals My answer: ['construction', 'materials']
# [13, 14] 	 5 6
# Answer: 18 % My answer: ['75', '%']
# [1] 	 5 8
# Answer: 2004 My answer: ['its', 'first', 'wind-powered', 'and']
# [32, 33] 	 41 43
# Answer: natural gas My answer: ['proven', 'oil', 'reserves']
# [48] 	 5 7
# Answer: *ar-yo- My answer: ['aryān', 'are', 'oblique']
# [52, 53] 	 52 53
# Answer: scientific writing My answer: ['scientific', 'writing']
# [12, 13, 14] 	 12 14
# Answer: large-scale state subsidies My answer: ['large-scale', 'state', 'subsidies']
# [62, 63, 64] 	 62 64
# Answer: the achaemenid empire My answer: ['the', 'largest', 'empire']
# [18] 	 12 16
# Answer: 11,000–16,000 My answer: ['KIA', ',', '60,711', 'MIA', ',']
# [4, 5] 	 4 5
# Answer: the gentilic My answer: ['the', 'gentilic']
# [6] 	 6 8
# Answer: 2015 My answer: ['2015', 'nuclear', 'and']
# [1] 	 23 24
# Answer: 1370 My answer: ['156', 'years']
# [] 	 21 23
# Answer: the fajr-3 ( mirv ) My answer: ['the', 'last', 'contains']
# [14] 	 6 9
# Answer: 3rd-century My answer: ['Middle', 'Persian', 'Ērān', ',']
# [4, 5] 	 4 5
# Answer: restoring order My answer: ['restoring', 'order']
# [5, 6, 7] 	 5 7
# Answer: around 40 % My answer: ['around', '40', '%']
# [7, 8] 	 7 8
# Answer: 1.4 million My answer: ['1.4', 'million']
# [5, 6] 	 5 6
# Answer: military spending My answer: ['military', 'spending']
# [11] 	 9 11
# Answer: 1979 My answer: ['by', 'the', '1979']
# [13] 	 8 10
# Answer: 86 My answer: ['one', 'week', 'annually']
# [5, 6, 7] 	 5 7
# Answer: an economic recession My answer: ['an', 'economic', 'recession']
# [5, 6] 	 5 6
# Answer: ranked 69 My answer: ['ranked', '69']
# [13, 14] 	 13 14
# Answer: in 1906 My answer: ['in', '1906']
# [1] 	 5 9
# Answer: 1960 My answer: ['co-invented', 'the', 'first', 'gas', 'laser']
# [7] 	 7 6
# Answer: 1993 My answer: []
# [14, 15, 16] 	 14 16
# Answer: between 21.6–30 % My answer: ['between', '21.6–30', '%']
# [4] 	 13 14
# Answer: 1988 My answer: ['forces', 'inside']
# [1] 	 7 8
# Answer: summer My answer: ['(', '100.4']
# [1, 2] 	 1 2
# Answer: 78.4 million My answer: ['78.4', 'million']
# [21, 22] 	 21 22
# Answer: rated 4th My answer: ['rated', '4th']
# [17] 	 13 14
# Answer: 1921 My answer: ['and', 'fully']
# [8, 9] 	 8 9
# Answer: until 1911 My answer: ['until', '1911']
# [28, 29] 	 28 29
# Answer: 25 % My answer: ['25', '%']
# [10, 11, 12] 	 10 12
# Answer: $ 70 billion My answer: ['$', '70', 'billion']
# [24] 	 24 26
# Answer: 36,000 My answer: ['36,000', 'rial', ',']
# [] 	 17 24
# Answer: the assyrian empire My answer: ['large', 'empire', 'under', 'the', 'reign', 'of', 'the', 'Achaemenid']
# [1, 2, 3] 	 1 3
# Answer: the 19th century My answer: ['the', '19th', 'century']
# [6, 7, 8] 	 6 8
# Answer: over 80 % My answer: ['over', '44', '%']
# [13] 	 33 35
# Answer: twenty-two My answer: []
# [] 	 5 6
# Answer: the golrizan festival My answer: ['festival', 'that']
# [6, 7] 	 6 7
# Answer: the bonyads My answer: ['the', 'bonyads']
# [44, 45, 46] 	 44 46
# Answer: to the south My answer: ['to', 'the', 'south']
# [26, 27, 28, 29] 	 26 29
# Answer: the sassanid era My answer: ['the', 'Lower', 'Paleolithic', 'era']
# [5, 6] 	 5 6
# Answer: 75 % My answer: ['75', '%']
# [6, 7, 8] 	 6 8
# Answer: the iraqi army My answer: ['the', 'Iraqi', 'army']
# [3] 	 9 11
# Answer: 1973 My answer: ['the', 'economy', 'of']
# [5, 6] 	 5 6
# Answer: a third My answer: ['a', 'third']
# [9, 10] 	 9 10
# Answer: class rank My answer: ['class', 'rank']
# [1] 	 4 5
# Answer: 2006 My answer: ['60', '%']
# [24, 25, 26] 	 24 26
# Answer: whites and males My answer: ['whites', 'and', 'males']
# [26] 	 17 20
# Answer: two My answer: [',', 'reaffirming', 'FDR', "'s"]
# [21, 22, 23] 	 5 23
# Answer: enforcing equal opportunity My answer: ['against', 'affirmative', 'action', ',', 'wanted', 'to', 'see', 'affirmative', 'action', 'go', 'back', 'to', 'its', 'original', 'meaning', 'of', 'enforcing', 'equal', 'opportunity']
# [25, 26] 	 25 26
# Answer: 12 % My answer: ['12', '%']
# [5, 6, 7] 	 5 7
# Answer: integrate public facilities My answer: ['integrate', 'public', 'facilities']
# [6] 	 12 13
# Answer: reservations My answer: ['less', 'productive']
# [21, 22] 	 21 22
# Answer: legacy admissions My answer: ['legacy', 'admissions']
# [13, 14] 	 13 14
# Answer: class inequality My answer: ['class', 'inequality']
# [3] 	 11 13
# Answer: 17 My answer: ['immediate', 'promotion', '.']
# [4, 5] 	 4 5
# Answer: 60 % My answer: ['60', '%']
# [6] 	 19 20
# Answer: 1952 My answer: ['the', 'states']
# [] 	 1 2
# Answer: executive order 10925 My answer: ['Shortly', 'after']
# [12, 13, 14] 	 12 14
# Answer: mediocrity and incompetence My answer: ['mediocrity', 'and', 'incompetence']
# [7, 8] 	 23 24
# Answer: positive action My answer: ['alliterative', 'quality']
# [3] 	 9 10
# Answer: 5-4 My answer: ['ruled', 'that']
# [46, 47] 	 46 47
# Answer: the descendants My answer: ['the', 'descendants']
# [30, 31, 32] 	 30 32
# Answer: remedying past discrimination My answer: ['remedying', 'past', 'discrimination']
# [8, 9] 	 8 9
# Answer: compensation argument My answer: ['compensation', 'argument']
# [23] 	 44 45
# Answer: 14 My answer: ['review', 'is']
# [18, 19, 20] 	 18 20
# Answer: 52 million acres My answer: ['52', 'million', 'acres']
# [3] 	 16 18
# Answer: 10,000 My answer: ['he', 'stood', 'on']
# [23, 24, 25] 	 23 25
# Answer: just outlawing discrimination My answer: ['just', 'outlawing', 'discrimination']
# [14, 15] 	 14 15
# Answer: 80 % My answer: ['80', '%']
# [4] 	 10 11
# Answer: racial My answer: ['inherently', 'suspect']
# [1] 	 6 7
# Answer: 1976 My answer: ['Italian', 'American']
# [30, 31] 	 30 31
# Answer: reverse discrimination My answer: ['reverse', 'discrimination']
# [35, 36] 	 35 36
# Answer: white students My answer: ['white', 'students']
# [4, 5] 	 4 5
# Answer: higher educational My answer: ['higher', 'educational']
# [44, 45] 	 44 45
# Answer: race-conscious policy My answer: ['race-conscious', 'policy']
# [5] 	 11 13
# Answer: white My answer: ['not', 'be', 'covered']
# [16] 	 15 16
# Answer: federal My answer: ['of', 'federal']
# [10, 11, 12] 	 10 12
# Answer: more than triple My answer: ['more', 'than', 'triple']
# [1] 	 7 8
# Answer: 1947 My answer: [',', 'To']
# [29, 30, 31] 	 29 31
# Answer: high dropout rates My answer: ['high', 'dropout', 'rates']
# [7, 8, 9] 	 7 9
# Answer: more than 60 My answer: ['more', 'than', '60']
# [7] 	 1 3
# Answer: white My answer: ['UNC-Chapel', 'Hill', 'lawsuit']
# [34, 35, 36] 	 34 36
# Answer: equality of opportunity My answer: ['equality', 'of', 'opportunity']
# [5, 6, 7] 	 5 7
# Answer: against affirmative action My answer: ['against', 'affirmative', 'action']
# [24, 25] 	 24 25
# Answer: four times My answer: ['four', 'times']
# [20, 21] 	 24 25
# Answer: eight percent My answer: ['action', 'programs']
# [14, 15] 	 14 15
# Answer: 3.1 % My answer: ['3.1', '%']
# [25] 	 12 13
# Answer: reverse My answer: ['gender', 'quotas']
# [8, 9] 	 8 9
# Answer: school segregation My answer: ['school', 'segregation']
# [12, 13] 	 12 13
# Answer: gender quotas My answer: ['gender', 'quotas']
# [6] 	 13 15
# Answer: merit My answer: ['in', 'applying', 'for']
# [12] 	 7 8
# Answer: minorities My answer: ['unions', 'it']
# [8] 	 15 16
# Answer: 11114 My answer: ['of', 'federal']
# [9, 10] 	 9 10
# Answer: inherently unequal My answer: ['inherently', 'unequal']
# [3] 	 11 12
# Answer: 2007 My answer: ['at', 'the']
# [9] 	 11 12
# Answer: economics My answer: ['at', 'the']
# [11, 12] 	 11 12
# Answer: possible remedies My answer: ['possible', 'remedies']
# [3, 4, 5] 	 3 5
# Answer: least well educated My answer: ['least', 'well', 'educated']
# [20, 21] 	 20 21
# Answer: craft unions My answer: ['craft', 'unions']
# [19, 20] 	 19 20
# Answer: the states My answer: ['the', 'states']
# [] 	 20 86
# Answer: executive order 10925 My answer: ['origin', 'is', 'contrary', 'to', 'the', 'Constitutional', 'principles', 'and', 'policies', 'of', 'the', 'United', 'States', "''", ';', 'that', '``', 'it', 'is', 'the', 'plain', 'and', 'positive', 'obligation', 'of', 'the', 'United', 'States', 'Government', 'to', 'promote', 'and', 'ensure', 'equal', 'opportunity', 'for', 'all', 'qualified', 'persons', ',', 'without', 'regard', 'to', 'race', ',', 'creed', ',', 'color', ',', 'or', 'national', 'origin', ',', 'employed', 'or', 'seeking', 'employment', 'with', 'the', 'Federal', 'Government', 'and', 'on', 'government', 'contracts', "''", ';']
# [1, 2, 3] 	 1 3
# Answer: a panel discussion My answer: ['a', 'panel', 'discussion']
# [1] 	 14 15
# Answer: 23 My answer: ['high', 'enough']
# [13, 14, 15] 	 13 15
# Answer: class-based affirmative action My answer: ['class-based', 'affirmative', 'action']
# [9, 10, 11] 	 9 11
# Answer: became less prevalent My answer: ['became', 'less', 'prevalent']
# [13] 	 32 35
# Answer: education My answer: ['been', 'historically', 'excluded', 'groups']
# [12, 13, 14] 	 12 14
# Answer: bottom 20 percent My answer: ['bottom', '20', 'percent']
# [23, 24] 	 23 24
# Answer: alliterative quality My answer: ['alliterative', 'quality']
# [26] 	 7 9
# Answer: achievement My answer: ['the', 'bar', 'and']
# [8, 9] 	 8 9
# Answer: undesirable side-effects My answer: ['undesirable', 'side-effects']
# [] 	 13 14
# Answer: executive order 10925 My answer: ['1961', ',']
# [1, 2, 3] 	 1 3
# Answer: 1 september 1870 My answer: ['1', 'September', '1870']
# [5, 6, 7] 	 5 7
# Answer: the main power My answer: ['the', 'main', 'power']
# [5, 6, 7, 8] 	 5 8
# Answer: bronze , rifled muzzle-loading My answer: ['bronze', ',', 'rifled', 'muzzle-loading']
# [3, 4, 5] 	 3 5
# Answer: over 17,000 men My answer: ['over', '17,000', 'men']
# [8] 	 21 23
# Answer: 400,000 My answer: ['served', 'the', 'comparatively']
# [11] 	 9 11
# Answer: 35,000 My answer: ['numbered', 'only', '35,000']
# [30] 	 12 13
# Answer: uniforms My answer: ['working-class', 'neighbourhoods']
# [11, 12] 	 11 12
# Answer: longer range My answer: ['longer', 'range']
# [6, 7, 8] 	 6 8
# Answer: multiple competing companies My answer: ['multiple', 'competing', 'companies']
# [16, 17, 18] 	 16 18
# Answer: steel breech-loading guns My answer: ['steel', 'breech-loading', 'guns']
# [5, 6, 7] 	 5 7
# Answer: declaration of war My answer: ['declaration', 'of', 'war']
# [23, 24, 25] 	 23 25
# Answer: belt of fortresses My answer: ['belt', 'of', 'fortresses']
# [18] 	 12 13
# Answer: 270,000 My answer: ['on', 'the']
# [10, 11, 12] 	 7 9
# Answer: 4 august 1870 My answer: ['took', 'place', 'on']
# [13, 14] 	 13 14
# Answer: 20 miles My answer: ['20', 'miles']
# [8] 	 8 9
# Answer: war My answer: ['war', ',']
# [24, 25] 	 24 25
# Answer: independent thinking My answer: ['independent', 'thinking']
# [5, 6, 7] 	 5 7
# Answer: 10 may 1871 My answer: ['10', 'May', '1871']
# [12, 13] 	 12 13
# Answer: 1,000 dead My answer: ['1,000', 'dead']
# [5, 6] 	 5 6
# Answer: heavy guns My answer: ['heavy', 'guns']
# [12] 	 13 14
# Answer: nobody My answer: ['responsible', 'for']
# [8, 9] 	 8 9
# Answer: 5,000 men My answer: ['5,000', 'men']
# [26] 	 24 26
# Answer: 1,000,000 My answer: ['field', 'some', '1,000,000']
# [18, 19] 	 18 19
# Answer: 1,000 prisoners My answer: ['1,000', 'prisoners']
# [1, 2, 3] 	 1 3
# Answer: 28 january 1871 My answer: ['28', 'January', '1871']
# [12, 13, 14] 	 12 14
# Answer: 16 august 1870 My answer: ['16', 'August', '1870']
# [16, 17] 	 16 17
# Answer: the franco-austrian war My answer: ['the', 'war']
# [28, 29] 	 28 29
# Answer: over 150,000 My answer: ['over', '150,000']
# [1, 2, 3] 	 1 3
# Answer: 16 july 1870 My answer: ['16', 'July', '1870']
# [8] 	 18 19
# Answer: westward My answer: ['1,000', 'prisoners']
# [11, 12, 13] 	 11 13
# Answer: incessant cavalry charges My answer: ['incessant', 'cavalry', 'charges']
# [9, 10] 	 9 10
# Answer: pre-war preparations My answer: ['pre-war', 'preparations']
# [2] 	 9 10
# Answer: starving My answer: ['reeling', 'from']
# [20] 	 10 12
# Answer: reforms My answer: ['1859', 'to', '1873']
# [8] 	 12 13
# Answer: 462,000 My answer: ['on', 'the']
# [] 	 8 11
# Answer: the north sea My answer: ['to', 'sea', 'on', '24']
# [3, 4, 5] 	 3 5
# Answer: four to one My answer: ['four', 'to', 'one']
# [12, 13] 	 12 13
# Answer: working-class neighbourhoods My answer: ['working-class', 'neighbourhoods']
# [1, 2, 3] 	 1 3
# Answer: a contact-detonated shell My answer: ['a', 'contact-detonated', 'shell']
# [21, 22] 	 21 22
# Answer: government buildings My answer: ['government', 'buildings']
# [3, 4] 	 3 4
# Answer: encirclement battles My answer: ['encirclement', 'battles']
# [8, 9] 	 21 22
# Answer: 500 people My answer: ['government', 'buildings']
# [31, 32] 	 31 32
# Answer: 140,000 troops My answer: ['140,000', 'troops']
# [10] 	 15 17
# Answer: food My answer: ['Prussian', 'forces', 'to']
# [] 	 9 11
# Answer: the second empire My answer: ['France', 'both', 'inevitable']
# [10, 11] 	 10 11
# Answer: military thinking My answer: ['military', 'thinking']
# [28, 29] 	 28 29
# Answer: only five My answer: ['only', 'five']
# [19, 20] 	 19 20
# Answer: coal reserves My answer: ['coal', 'reserves']
# [9] 	 4 5
# Answer: conscripts My answer: ['composed', 'not']
# [1, 2, 3] 	 1 3
# Answer: 19 july 1870 My answer: ['19', 'July', '1870']
# [10] 	 8 10
# Answer: 4,420 My answer: ['along', 'with', '4,420']
# [10, 11] 	 10 11
# Answer: 2–3 kilometres My answer: ['2–3', 'kilometres']
# [14, 15] 	 14 15
# Answer: intellectual development My answer: ['intellectual', 'development']
# [11, 12] 	 11 12
# Answer: breaking up My answer: ['breaking', 'up']
# [27, 28, 29] 	 27 29
# Answer: inflamed public opinion My answer: ['inflamed', 'public', 'opinion']
# [15, 16] 	 15 16
# Answer: significant distances My answer: ['significant', 'distances']
# [11, 12, 13] 	 11 13
# Answer: their military system My answer: ['their', 'military', 'system']
# [4] 	 8 10
# Answer: 7,855 My answer: ['along', 'with', '4,420']
# [7, 8] 	 7 8
# Answer: war reparations My answer: ['war', 'reparations']
# [11] 	 12 14
# Answer: trench-warfare My answer: ['style', 'fighting—the', 'so-called']
# [24, 25] 	 24 25
# Answer: very limited My answer: ['very', 'limited']
# [7, 8, 9] 	 7 9
# Answer: the chassepot rifle My answer: ['the', 'Dreyse', 'rifle']
# [10, 11, 12] 	 10 12
# Answer: 1859 to 1873 My answer: ['1859', 'to', '1873']
# [4] 	 5 7
# Answer: 20,163 My answer: ['German', 'troops', 'were']
# [9, 10, 11, 12] 	 9 12
# Answer: literally `` circle '' My answer: ['literally', '``', 'circle', "''"]
# [15] 	 13 47
# Answer: eidos My answer: [')', 'and', 'eidos', '(', 'εἶδος', ',', '``', 'species', "''", ')', 'have', 'the', 'same', 'root', 'as', 'the', 'word', 'idea', '(', 'ἰδέα', ')', ',', 'indicating', 'how', 'the', 'Greek', 'mind', 'moved', 'from', 'the', 'gift', 'of', 'the', 'senses', ',']
# [3] 	 10 11
# Answer: labrys My answer: ['the', 'Cretan']
# [10] 	 10 11
# Answer: paion My answer: ['paion', "''"]
# [4] 	 43 49
# Answer: kouros My answer: []
# [4] 	 4 5
# Answer: kouros My answer: ['kouros', '(']
# [6] 	 0 1
# Answer: paeans My answer: ['Hymns', 'sung']
# [7, 8, 9] 	 7 9
# Answer: early archaic period My answer: ['early', 'archaic', 'period']
# [13] 	 0 1
# Answer: dolphins My answer: ['An', 'etiology']
# [24] 	 23 24
# Answer: amber My answer: ['of', 'amber']
# [7] 	 13 14
# Answer: pella My answer: ["''", 'and']
# [12] 	 34 35
# Answer: apella My answer: ['the', 'limits']
# [4, 5] 	 4 5
# Answer: the bow My answer: ['the', 'bow']
# [12] 	 14 15
# Answer: apella My answer: ['ἀπέλλα', ')']
# [5, 6] 	 5 6
# Answer: peripteral temples My answer: ['peripteral', 'temples']
# [18] 	 23 24
# Answer: physician My answer: ['the', 'Iliad']
# [7] 	 19 20
# Answer: paean My answer: ['to', 'implore']
# [] 	 14 15
# Answer: a crow My answer: ['they', 'were']
# [] 	 14 15
# Answer: keep away evil , My answer: ['in', 'popular']
# [17, 18] 	 17 18
# Answer: theological oracles My answer: ['theological', 'oracles']
# [1] 	 9 13
# Answer: stones My answer: ['Homeric', 'Troy', 'were', 'the', 'symbols']
# [5] 	 2 4
# Answer: marble My answer: ['statues', 'were', 'usually']
# [12] 	 7 9
# Answer: paean My answer: ['of', 'the', 'relevant']
# [10] 	 22 23
# Answer: apella My answer: ['would', 'be']
# [15, 16] 	 7 9
# Answer: the artists My answer: ['early', 'archaic', 'period']
# [13, 14] 	 13 14
# Answer: these representations My answer: ['these', 'representations']
# [17] 	 6 3
# Answer: apellaia My answer: []
# [] 	 9 10
# Answer: the seventh My answer: ['new', 'and']
# [6] 	 14 15
# Answer: seer-doctors My answer: ['used', 'an']
# [14] 	 18 19
# Answer: flute My answer: ['sing', 'at']
# [3] 	 3 4
# Answer: lyre My answer: ['lyre', 'for']
# [16] 	 5 6
# Answer: apollymi My answer: ['often', 'associated']
# [18] 	 21 15
# Answer: flower My answer: []
# [40] 	 27 3
# Answer: alexikakos My answer: []
# [51] 	 5 7
# Answer: stone My answer: ['their', 'initiation', 'festival']
# [12] 	 7 9
# Answer: paean My answer: ['of', 'the', 'relevant']
# [8] 	 16 17
# Answer: agyieus My answer: ['and', 'houses']
# [10] 	 16 17
# Answer: kouros My answer: ['fully', 'preserved']
# [6] 	 8 28
# Answer: discus My answer: ['a', 'discus', 'thrown', 'by', 'Apollo', 'was', 'blown', 'off', 'course', 'by', 'the', 'jealous', 'Zephyrus', 'and', 'struck', 'Hyacinthus', 'in', 'the', 'head', ',', 'killing']
# [13] 	 24 25
# Answer: one My answer: ['.']
# [14] 	 15 16
# Answer: earlywood My answer: [',', 'this']
# [7] 	 2 3
# Answer: cells My answer: ['or', 'softwood']
# [19] 	 2 3
# Answer: circular My answer: ['(', 'when']
# [12, 13] 	 12 13
# Answer: more rapid My answer: ['more', 'rapid']
# [9] 	 9 10
# Answer: rot My answer: ['rot', 'and']
# [7] 	 5 6
# Answer: defects My answer: ['susceptible', 'to']
# [3] 	 28 29
# Answer: bamboo My answer: ['material', 'in']
# [16] 	 14 16
# Answer: narrower My answer: ['they', 'become', 'narrower']
# [29] 	 19 20
# Answer: maple My answer: ['hickory', ',']
# [1] 	 1 2
# Answer: knot My answer: ['knot', 'is']
# [30, 31, 32] 	 30 32
# Answer: composite structural unit My answer: ['composite', 'structural', 'unit']
# [28] 	 28 29
# Answer: youth My answer: ['youth', ',']
# [10] 	 30 31
# Answer: grass My answer: ['their', 'own']
# [37] 	 31 33
# Answer: position My answer: ['of', 'sapwood', ',']
# [4] 	 19 5
# Answer: hemicellulose My answer: []
# [7] 	 25 27
# Answer: glulam My answer: ['laminated', 'veneer', 'lumber']
# [35] 	 24 23
# Answer: heartwood My answer: []
# [8] 	 8 11
# Answer: carvings My answer: ['carvings', 'for', 'millennia', '.']
# [31] 	 18 19
# Answer: thin My answer: ['very', 'small']
# [21, 22] 	 21 22
# Answer: around it My answer: ['around', 'it']
# [26, 27] 	 26 27
# Answer: 1 % My answer: ['1', '%']
# [6] 	 6 7
# Answer: coniferous My answer: ['coniferous', 'woods']
# [14, 15] 	 14 15
# Answer: specific gravity My answer: ['specific', 'gravity']
# [4, 5, 6, 7] 	 4 7
# Answer: annual rings My answer: ['annual', 'these', 'growth', 'rings']
# [43] 	 14 15
# Answer: magnesium My answer: ['50', '%']
# [24] 	 42 43
# Answer: persimmon My answer: ['synthetic', 'materials']
# [9] 	 5 6
# Answer: trees My answer: ['inner', 'heartwood']
# [10] 	 17 19
# Answer: latewood My answer: ['fibers', 'are', 'most']
# [11] 	 5 7
# Answer: handles My answer: ['in', 'the', 'choice']
# [25, 26] 	 25 26
# Answer: a rule My answer: ['a', 'rule']
# [21] 	 30 32
# Answer: seed My answer: ['density', '.']
# [1] 	 1 2
# Answer: oven-dried My answer: ['oven-dried', 'wood']
# [13] 	 18 22
# Answer: beds My answer: []
# [14, 15] 	 14 15
# Answer: supporting material My answer: ['supporting', 'material']
# [14, 15, 16] 	 14 16
# Answer: a dormant bud My answer: ['a', 'dormant', 'bud']
# [14, 15] 	 14 15
# Answer: 50 % My answer: ['50', '%']
# [10] 	 25 16
# Answer: cellulose My answer: []
# [8] 	 6 8
# Answer: commercial My answer: ['residential', 'and', 'commercial']
# [1] 	 9 11
# Answer: firmness My answer: [',', 'the', 'length']
# [17] 	 6 7
# Answer: diffuse-porous My answer: ['customary', 'to']
# [1] 	 15 17
# Answer: larvae My answer: ['sources', 'of', 'weakness']
# [8] 	 32 33
# Answer: walls My answer: ['with', 'lignin']
# [5] 	 6 7
# ...
# [2] 	 23 24
# Answer: 2005 My answer: ['a', 'special']
# [] 	 16 17
# Answer: the one My answer: ['financial', 'reasons']
# [1] 	 4 6
# Answer: 1998 My answer: ['network', 'carried', 'a']
# [9] 	 1 3
# Answer: both My answer: ['the', 'transition', 'deadline']
# [21, 22] 	 21 22
# Answer: 113,930 people My answer: ['113,930', 'people']
# [21] 	 5 7
# Answer: last My answer: ['at', '6:00', 'a.m.']
# [44, 45] 	 44 45
# Answer: 62.5 % My answer: ['62.5', '%']
# [21, 22, 23] 	 21 23
# Answer: on cbc-owned stations My answer: ['on', 'CBC-owned', 'stations']
# [23] 	 40 42
# Answer: more My answer: ['delaying', 'events', 'to']
# [53] 	 4 6
# Answer: 27 My answer: ['4', ',', '2012']
# [53] 	 56 58
# Answer: 27 My answer: []
# [24] 	 21 22
# Answer: 303,465 My answer: ['113,930', 'people']
# [21] 	 20 6
# Answer: cambium My answer: []
# [16, 17] 	 16 17
# Answer: flowering plants My answer: ['flowering', 'plants']
# [4] 	 13 14
# Answer: magnoliids My answer: ['.']
# [5] 	 4 5
# Answer: biochemical My answer: ['a', 'biochemical']
# [26, 27, 28] 	 26 28
# Answer: increase in thickness My answer: ['increase', 'in', 'thickness']
# [16] 	 49 50
# Answer: flowering My answer: []
# [10, 11, 12] 	 10 12
# Answer: green and leaf-like My answer: ['green', 'and', 'leaf-like']
# [7] 	 7 10
# Answer: flower My answer: ['flower', '.']
# [39, 40] 	 39 40
# Answer: annual rings My answer: ['annual', 'rings']
# [26, 27, 28] 	 26 28
# Answer: inferior transitional forms My answer: ['inferior', 'transitional', 'forms']
# [2, 3, 4] 	 2 4
# Answer: whole genome duplication My answer: ['whole', 'genome', 'duplication']
# [10] 	 26 28
# Answer: speciation My answer: ['inferior', 'transitional', 'forms']
# [38] 	 28 30
# Answer: 402 My answer: ['that', 'the', 'minimum']
# [15] 	 28 29
# Answer: seed-dispersal My answer: ['scattering', 'the']
# [23, 24] 	 23 24
# Answer: naked ovules My answer: ['naked', 'ovules']
# [6, 7, 8] 	 6 8
# Answer: formerly simple weeds My answer: ['formerly', 'simple', 'weeds']
# [4] 	 31 13
# Answer: 12,000 My answer: []
# [29] 	 11 32
# Answer: inflorescence My answer: ['distinguished', 'from', 'the', 'foliage-bearing', 'or', 'vegetative', 'portion', ',', 'and', 'forms', 'a', 'more', 'or', 'less', 'elaborate', 'branch-system', 'called', 'an', 'inflorescence', '.']
# [24] 	 16 19
# Answer: gigantopterids My answer: ['deposits', 'of', 'that', 'age']
# [14, 15, 16] 	 14 16
# Answer: an open ring My answer: ['an', 'open', 'ring']
# [22] 	 19 23
# Answer: prettiest My answer: [',', 'and', 'the', 'prettiest', 'did']
# [15, 16] 	 15 16
# Answer: different flowers My answer: ['different', 'flowers']
# [14] 	 12 13
# Answer: two My answer: ['result', 'of']
# [10, 11] 	 10 11
# Answer: an enclosure My answer: ['an', 'enclosure']
# [3] 	 13 14
# Answer: embryo My answer: ['promote', 'germination']
# [2] 	 30 32
# Answer: basal My answer: []
# [13] 	 15 17
# Answer: spores My answer: ['new', 'habitats', '.']
# [8] 	 8 10
# Answer: hermaphrodite My answer: ['hermaphrodite', '(', 'having']
# [10, 11, 12] 	 10 12
# Answer: sepals and petals My answer: ['sepals', 'and', 'petals']
# [10, 11] 	 10 11
# Answer: the sporophylls My answer: ['the', 'sporophylls']
# [1, 2, 3, 4] 	 1 4
# Answer: great angiosperm radiation , My answer: ['great', 'angiosperm', 'radiation', ',']
# [34, 35, 36, 37, 38, 39] 	 34 39
# Answer: xylem and phloem My answer: ['xylem', 'on', 'the', 'inside', 'and', 'phloem']
# [8, 9] 	 8 9
# Answer: haploid generative My answer: ['haploid', 'generative']
# [20, 21] 	 20 21
# Answer: the spike-moss My answer: ['the', 'spike-moss']
# [4] 	 11 13
# Answer: angiosperms My answer: ['or', 'Magnoliophyta', ',']
# [16] 	 15 16
# Answer: magnoliids My answer: ['the', 'magnoliids']
# [28] 	 37 35
# Answer: wasps My answer: []
# [10, 11] 	 10 11
# Answer: the ovule My answer: ['the', 'ovule']
# [5, 6, 7] 	 5 7
# Answer: form and elaboration My answer: ['form', 'and', 'elaboration']
# [28, 29] 	 28 29
# Answer: abominable mystery My answer: ['abominable', 'mystery']
# [44, 45, 46] 	 44 46
# Answer: other dicotyledonous plants My answer: ['other', 'dicotyledonous', 'plants']
# [15] 	 10 11
# Answer: fruit My answer: ['the', 'ovule']
# [2] 	 8 10
# Answer: classification My answer: ['considerable', 'revision', '.']
# [8, 9] 	 8 9
# Answer: fused together My answer: ['fused', 'together']
# [6] 	 11 12
# Answer: angiosperms My answer: ['all', 'plant-based']
# [] 	 19 22
# Answer: the cronquist system My answer: ['Magnoliophyta', '(', 'from', 'the']
# [5, 6] 	 5 6
# Answer: seed-producing plants My answer: ['seed-producing', 'plants']
# [11] 	 1 3
# Answer: coherent My answer: ['most', 'taxonomies', ',']
# [13, 14] 	 13 14
# Answer: the fruit My answer: ['the', 'fruit']
# [45] 	 30 25
# Answer: primary My answer: []
# [32, 33, 34] 	 8 9
# Answer: `` ovary-inferior '' My answer: ['fused', 'together']
# [3] 	 31 32
# Answer: angiosperm My answer: ['enclosed', 'seeds']
# [5] 	 8 8
# Answer: dicot My answer: ['form']
# [9, 10] 	 9 10
# Answer: dominated environments My answer: ['dominated', 'environments']
# [22] 	 31 13
# Answer: diverse My answer: []
# [18] 	 10 11
# Answer: dissemination My answer: ['fruit', 'provides']
# [7] 	 19 21
# Answer: fragile My answer: ['be', 'an', 'unusually']
# [9] 	 15 7
# Answer: slightly My answer: []
# [19, 20] 	 19 20
# Answer: about 9,000 My answer: ['about', '9,000']
# [27] 	 4 22
# Answer: chancellor My answer: ['years', 'at', 'the', 'University', 'of', 'Chicago', ',', 'Arthur', 'Holly', 'Compton', 'returned', 'to', 'St.', 'Louis', 'in', '1946', 'to', 'serve', 'as']
# [9] 	 7 8
# Answer: 1891 My answer: ['University', 'in']
# [35] 	 15 17
# Answer: 1925 My answer: ['the', 'George', 'Warren']
# [25, 26, 27] 	 25 27
# Answer: currently ranked first My answer: ['currently', 'ranked', 'first']
# [11] 	 7 8
# Answer: 1853 My answer: ['Missouri', 'General']
# [10, 11, 12] 	 10 12
# Answer: the south 40 My answer: ['the', 'South', '40']
# [9] 	 14 15
# Answer: 1881 My answer: ['the', 'oldest']
# [] 	 18 20
# Answer: a night school My answer: ['education', ',', 'and']
# [4, 5] 	 4 5
# Answer: 40–60 % My answer: ['40–60', '%']
# [9] 	 11 12
# Answer: 1986 My answer: ['a', 'donation']
# [31, 32] 	 31 32
# Answer: 25 % My answer: ['25', '%']
# [21, 22] 	 21 22
# Answer: 85 hours My answer: ['85', 'hours']
# [1] 	 27 28
# Answer: 2010 My answer: [',', 'opened']
# [28] 	 9 10
# Answer: seven My answer: ['academic', 'research']
# [20, 21] 	 20 21
# Answer: 25 % My answer: ['25', '%']
# [6, 7] 	 6 7
# Answer: 60 % My answer: ['60', '%']
# [18, 19] 	 18 19
# Answer: 14 % My answer: ['14', '%']
# [1, 2] 	 1 2
# Answer: 80 % My answer: ['80', '%']
# [5, 6, 7] 	 5 7
# Answer: $ 537.5 million My answer: ['$', '537.5', 'million']
# [24] 	 13 14
# Answer: 120 My answer: ['students', 'and']
# [10, 11, 12, 13] 	 10 13
# Answer: the south 40 , My answer: ['the', 'South', '40', ',']
# [16, 17, 18, 19] 	 16 19
# Answer: `` hilltop '' campus My answer: ['``', 'Hilltop', "''", 'campus']
# [1] 	 18 20
# Answer: 2008 My answer: ['about', 'Joe', 'Biden']
# [14] 	 7 8
# Answer: 12 My answer: ['student-run', 'musical']
# [4] 	 4 5
# Answer: 32nd My answer: ['32nd', 'in']
# [8] 	 11 12
# Answer: 30,117 My answer: ['a', 'freshman']
# [20, 21, 22, 23, 24, 25] 	 20 25
# Answer: in 2008 My answer: ['in', 'men', "'s", 'tennis', '(', '2008']
# [4] 	 5 6
# Answer: 150 My answer: ['National', 'Institutes']
# [34, 35, 36] 	 20 25
# Answer: 2008 , 2009 My answer: ['in', 'men', "'s", 'tennis', '(', '2008']
# [19] 	 21 22
# Answer: 18th My answer: [',', 'out']
# [1] 	 3 5
# Answer: 1856 My answer: ['the', 'University', 'amended']
# [12] 	 8 10
# Answer: 1963 My answer: ['the', 'federal', 'government']
# [9] 	 9 13
# Answer: 2004 My answer: ['2004', ',', 'formerly', 'home', 'to']
# [6] 	 5 7
# Answer: 1991 My answer: ['in', '1991', ',']
# [23] 	 12 14
# Answer: 1988 My answer: ['Olin', 'Business', 'School']
# [12, 13] 	 12 13
# Answer: 96th percentile My answer: ['96th', 'percentile']
# [] 	 10 12
# Answer: south 40 My answer: ['the', 'South', '40']
# [2] 	 4 6
# Answer: 2006 My answer: ['the', 'Kemper', 'Art']
# [10, 11] 	 10 11
# Answer: 35 % My answer: ['35', '%']
# [13, 14, 15] 	 13 15
# Answer: $ 2 million My answer: ['$', '2', 'million']
# [4, 5] 	 21 22
# Answer: 3 semesters My answer: ['85', 'hours']
# [9] 	 7 8
# Answer: 1891 My answer: ['University', 'in']
# [16] 	 23 20
# Answer: 1990 My answer: []
# [1] 	 11 13
# Answer: 1867 My answer: ['school', 'west', 'of']
# [3] 	 9 7
# Answer: first My answer: []
# [21] 	 4 5
# Answer: eight My answer: ['40–60', '%']
# [4] 	 20 25
# Answer: 19 My answer: ['in', 'men', "'s", 'tennis', '(', '2008']
# [9] 	 12 14
# Answer: 1947 My answer: ['School', 'of', 'Medicine']
# [9] 	 12 14
# Answer: 1917 My answer: ['Olin', 'Business', 'School']
# [14, 15, 16] 	 14 16
# Answer: $ 213 million My answer: ['$', '213', 'million']
# [8, 9, 10] 	 8 10
# Answer: the federal government My answer: ['the', 'federal', 'government']
# [46] 	 13 14
# Answer: 2008 My answer: ['``', 'improbable']
# [3, 4] 	 3 4
# Answer: over two-thirds My answer: ['over', 'two-thirds']
# [9] 	 21 22
# Answer: 1891 My answer: ['centers', 'for']
# [1] 	 1 2
# Answer: 1899 My answer: ['1899', ',']
# [6] 	 6 7
# Answer: co-ed My answer: ['co-ed', '.']
# [8] 	 7 9
# Answer: 1976 My answer: ['in', '1976', ',']
# [22] 	 18 19
# Answer: 2013 My answer: ['journal', 'DesignIntelligence']
# [7, 8] 	 7 8
# Answer: three divisions My answer: ['three', 'divisions']
# [2] 	 12 13
# Answer: 1853 My answer: ['has', 'students']
# [3] 	 5 7
# Answer: four My answer: ['student-run', 'media', 'outlets']
# [14, 15, 16, 17] 	 14 17
# Answer: 12 research centers . My answer: ['12', 'research', 'centers', '.']
# [1, 2] 	 1 2
# Answer: the 1890s My answer: ['the', '1890s']
# [9, 10, 11] 	 9 11
# Answer: full-time or part-time My answer: ['full-time', 'or', 'part-time']
# [1] 	 18 19
# Answer: 1957 My answer: ['modern', 'residential']
# [7] 	 9 10
# Answer: 1988 My answer: ['signing', 'agreements']
# [26] 	 16 21
# Answer: sanctions My answer: ["'s", 'failures', 'in', 'quelling', 'the', 'rebellion']
# [12] 	 14 15
# Answer: 113 My answer: ['160', 'seats']
# [14] 	 3 4
# Answer: nonviolent My answer: ['loss', 'of']
# [13] 	 16 19
# Answer: five-year My answer: ['universal', 'suffrage', 'and', 'is']
# [4] 	 26 28
# Answer: 48 My answer: ['65', 'and', 'older']
# [1] 	 15 16
# Answer: president My answer: ['forces', '.']
# [2, 3] 	 2 3
# Answer: far north My answer: ['far', 'north']
# [19] 	 25 27
# Answer: 69 My answer: ['some', 'kind', '.']
# [8] 	 13 11
# Answer: 53.06 My answer: []
# [36] 	 36 38
# Answer: pro-democracy My answer: ['pro-democracy', 'movement', '.']
# [6] 	 6 7
# Answer: 16.5 My answer: ['16.5', 'deaths']
# [3] 	 6 7
# Answer: 1991 My answer: ['a', 'coup']
# [5, 6] 	 5 6
# Answer: dictatorial regime My answer: ['dictatorial', 'regime']
# [10] 	 13 16
# Answer: mask My answer: ['performed', 'at', 'ceremonial', 'events']
# [27] 	 37 38
# Answer: equinut My answer: ['recipe', 'di-dèguè']
# [4] 	 12 13
# Answer: torrid My answer: ['in', 'the']
# [14] 	 14 15
# Answer: 20 My answer: ['20', 'liquidated']
# [9] 	 15 16
# Answer: pro-democracy My answer: ['was', 'held']
# [22] 	 8 9
# Answer: discrimination My answer: ['after', 'independence']
# [37, 38] 	 37 38
# Answer: recipe di-dèguè My answer: ['recipe', 'di-dèguè']
# [3] 	 25 27
# Answer: 62–65 My answer: ['some', 'kind', '.']
# [17] 	 4 6
# Answer: nightly My answer: ['roadblocks', 'were', 'erected']
# [6] 	 7 9
# Answer: three My answer: ['West', 'African', 'empires']
# [24, 25] 	 24 25
# Answer: judicial review My answer: ['judicial', 'review']
# [2] 	 11 13
# Answer: 85–91 My answer: ['had', 'female', 'genital']
# [2, 3] 	 2 3
# Answer: northern desert My answer: ['northern', 'desert']
# [12, 13, 14] 	 12 14
# Answer: 1968 to 1974 My answer: ['1968', 'to', '1974']
# [16, 17] 	 16 17
# Answer: occupational settings My answer: ['occupational', 'settings']
# [3, 4, 5] 	 3 5
# Answer: a primordialist approach My answer: ['a', 'primordialist', 'approach']
# [69, 70, 71] 	 10 12
# Answer: foreclosed or defensive My answer: ['an', 'optimal', 'level']
# [14, 15] 	 14 15
# Answer: significant others My answer: ['significant', 'others']
# -------------------------------------------------------------------
# KeyboardInterrupt                 Traceback (most recent call last)
# <ipython-input-114-02a779b53e0e> in <module>()
#       1 my_answers = []
#       2 for i,embed_query in enumerate(embed_train_qs):
# ----> 3     start_idx, end_idx = get_start_end(training_input[i:i+1])
#       4     start_idx = np.argmax(start_idx)
#       5     end_idx = np.argmax(end_idx)
#
# <ipython-input-96-abee95b65203> in get_start_end(question)
#       1 def get_start_end(question):
#       2     # Encode the input as state vectors.
# ----> 3     states_value = encoder_model.predict(question)
#       4
#       5     # Generate empty target sequence of length 1.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1833         f = self.predict_function
#    1834         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1835                                   verbose=verbose, steps=steps)
#    1836
#    1837     def train_on_batch(self, x, y,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1329                     ins_batch[i] = ins_batch[i].toarray()
#    1330
# -> 1331                 batch_outs = f(ins_batch)
#    1332                 if not isinstance(batch_outs, list):
#    1333                     batch_outs = [batch_outs]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import csv
with open('result.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["id","answer"])
    for i,embed_query in enumerate(embed_test_qs):
        start_idx, end_idx = get_start_end(testing_input[i:i+1])
        start_idx = np.argmax(start_idx)
        end_idx = np.argmax(end_idx)
        my_answer = tokenized_test_context[i][start_idx:end_idx+1]
        writer.writerow([str(i), " ".join(my_answer)])
