# %%
import numpy as np
import json
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# <b>Word embedding</b>

# %%
embedding_size = 50
gloveFilePath = "data/glove.6B.50d.txt"
def loadGlove(filePath):
    file = open(filePath, 'r')
    
    vocab = {}
    embedding = []
    for i, line in enumerate(file.readlines()):
        line = line.strip().split(' ')
        word = line[0]
        vocab[word] = i
        embedding.append(line[1:])
    file.close()
    return vocab,embedding
vocab, embedding = loadGlove(gloveFilePath)
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 400000

# %% [markdown]
# <b>Load data</b>

# %%
f = open("./data/training.json", encoding='utf-8')
js = json.load(f)
#discard the token '?' at the end of each query
train_qs = [item['question'][:-1] for item in js]
tokenized_train_qs_all = [word_tokenize(item['question'][:-1]) for item in js]
train_texts = [item['text'] for item in js]
tokenized_train_texts_all = [word_tokenize(item['text']) for item in js]
train_aps = [item['answer_paragraph'] for item in js]
train_docids = [item['docid'] for item in js]
f.close()
print(train_qs[0])
print(tokenized_train_qs_all[0])
print(train_texts[0])
print(tokenized_train_texts_all[0])
# Out:
# A kilogram could be definined as having a Planck constant of what value
# ['A', 'kilogram', 'could', 'be', 'definined', 'as', 'having', 'a', 'Planck', 'constant', 'of', 'what', 'value']
# 6966662606895999999♠6.62606896×10−34 j⋅s
# ['6966662606895999999♠6.62606896×10−34', 'j⋅s']

# %%
f = open("./data/testing.json", encoding='utf-8')
js = json.load(f)
#discard the token '?' at the end of each query
test_qs = [item['question'][:-1] for item in js]
tokenized_test_qs_all = [word_tokenize(item['question'][:-1]) for item in js]
test_docids = [item['docid'] for item in js]
f.close()
print(test_qs[0])
print(tokenized_test_qs_all[0])
# Out:
# Modern browser support standards-based and defacto what
# ['Modern', 'browser', 'support', 'standards-based', 'and', 'defacto', 'what']

# %%
f = open("./data/documents.json", encoding='utf-8')
js = json.load(f)
docs = [ [ sent for para in item['text'] for sent in sent_tokenize(para)] for item in js]
tokenized_docs = [[word_tokenize(sent) for sent in doc] for doc in docs]
docids = [item['docid'] for item in js]
f.close()
print(docs[0])
print(tokenized_docs[0])
# Out:
# ['First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.', 'In 1905 the value E, the minimal energy increment of a hypothetical oscillator, was theoretically associated by Einstein with a "quantum" or minimal element of the energy of the electromagnetic wave itself.', 'The light quantum behaved in some respects as an electrically neutral particle, as opposed to an electromagnetic wave.', 'It was eventually called the photon.', 'Classical statistical mechanics requires the existence of h (but does not define its value).', "Eventually, following upon Planck's discovery, it was recognized that physical action cannot take on an arbitrary value.", 'Instead, it must be some multiple of a very small quantity, the "quantum of action", now called the Planck constant.', 'Classical physics cannot explain this fact.', 'In many cases, such as for monochromatic light or for atoms, this quantum of action also implies that only certain energy levels are allowed, and values in between are forbidden.', 'Equivalently, the smallness of the Planck constant reflects the fact that everyday objects and systems are made of a large number of particles.', 'For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).', 'Each photon has an energy E = hf = 6981358000000000000♠3.58×10−19 J.', 'That is a very small amount of energy in terms of everyday experience, but everyday experience is not concerned with individual photons any more than with individual atoms or molecules.', 'An amount of light compatible with everyday experience is the energy of one mole of photons; its energy can be computed by multiplying the photon energy by the Avogadro constant, NA ≈ 7023602200000000000♠6.022×1023 mol−1.', 'The result is that green light of wavelength 555 nm has an energy of 7005216000000000000♠216 kJ/mol, a typical energy of everyday life.', 'In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.', 'It is well known that hot objects glow, and that hotter objects glow brighter than cooler ones.', 'The electromagnetic field obeys laws of motion similarly to a mass on a spring, and can come to thermal equilibrium with hot atoms.', 'The hot object in equilibrium with light absorbs just as much light as it emits.', 'If the object is black, meaning it absorbs all the light that hits it, then its thermal light emission is maximized.', 'The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).', 'But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".', 'Nevertheless, Wilhelm Wien discovered the mathematical relationship between the peaks of the curves at different temperatures, by using the principle of adiabatic invariance.', "At each different temperature, the curve is moved over by Wien's displacement law (1893).", 'Wien also proposed an approximation for the spectrum of the object, which was correct at high frequencies (short wavelength) but not at low frequencies (long wavelength).', 'It still was not clear why the spectrum of a hot object had the form that it has (see diagram).', "Prior to Planck's work, it had been assumed that the energy of a body could take on any value whatsoever – that it was a continuous variable.", 'The Rayleigh–Jeans law makes close predictions for a narrow range of values at one limit of temperatures, but the r ...
# [['First', 'recognized', 'in', '1900', 'by', 'Max', 'Planck', ',', 'it', 'was', 'originally', 'the', 'proportionality', 'constant', 'between', 'the', 'minimal', 'increment', 'of', 'energy', ',', 'E', ',', 'of', 'a', 'hypothetical', 'electrically', 'charged', 'oscillator', 'in', 'a', 'cavity', 'that', 'contained', 'black', 'body', 'radiation', ',', 'and', 'the', 'frequency', ',', 'f', ',', 'of', 'its', 'associated', 'electromagnetic', 'wave', '.'], ['In', '1905', 'the', 'value', 'E', ',', 'the', 'minimal', 'energy', 'increment', 'of', 'a', 'hypothetical', 'oscillator', ',', 'was', 'theoretically', 'associated', 'by', 'Einstein', 'with', 'a', '``', 'quantum', "''", 'or', 'minimal', 'element', 'of', 'the', 'energy', 'of', 'the', 'electromagnetic', 'wave', 'itself', '.'], ['The', 'light', 'quantum', 'behaved', 'in', 'some', 'respects', 'as', 'an', 'electrically', 'neutral', 'particle', ',', 'as', 'opposed', 'to', 'an', 'electromagnetic', 'wave', '.'], ['It', 'was', 'eventually', 'called', 'the', 'photon', '.'], ['Classical', 'statistical', 'mechanics', 'requires', 'the', 'existence', 'of', 'h', '(', 'but', 'does', 'not', 'define', 'its', 'value', ')', '.'], ['Eventually', ',', 'following', 'upon', 'Planck', "'s", 'discovery', ',', 'it', 'was', 'recognized', 'that', 'physical', 'action', 'can', 'not', 'take', 'on', 'an', 'arbitrary', 'value', '.'], ['Instead', ',', 'it', 'must', 'be', 'some', 'multiple', 'of', 'a', 'very', 'small', 'quantity', ',', 'the', '``', 'quantum', 'of', 'action', "''", ',', 'now', 'called', 'the', 'Planck', 'constant', '.'], ['Classical', 'physics', 'can', 'not', 'explain', 'this', 'fact', '.'], ['In', 'many', 'cases', ',', 'such', 'as', 'for', 'monochromatic', 'light', 'or', 'for', 'atoms', ',', 'this', 'quantum', 'of', 'action', 'also', 'implies', 'that', 'only', 'certain', 'energy', 'levels', 'are', 'allowed', ',', 'and', 'values', 'in', 'between', 'are', 'forbidden', '.'], ['Equivalently', ',', 'the', 'smallness', 'of', 'the', 'Planck', 'constant', 'reflects', 'the', 'fact', 'that', 'everyday', 'objects', 'and', 'systems', 'are', 'made', 'of', 'a', 'large', 'number', 'of', 'particles', '.'], ['For', 'example', ',', 'green', 'light', 'with', 'a', 'wavelength', 'of', '555', 'nanometres', '(', 'the', 'approximate', 'wavelength', 'to', 'which', 'human', 'eyes', 'are', 'most', 'sensitive', ')', 'has', 'a', 'frequency', 'of', '7014540000000000000♠540', 'THz', '(', '7014540000000000000♠540×1012', 'Hz', ')', '.'], ['Each', 'photon', 'has', 'an', 'energy', 'E', '=', 'hf', '=', '6981358000000000000♠3.58×10−19', 'J', '.'], ['That', 'is', 'a', 'very', 'small', 'amount', 'of', 'energy', 'in', 'terms', 'of', 'everyday', 'experience', ',', 'but', 'everyday', 'experience', 'is', 'not', 'concerned', 'with', 'individual', 'photons', 'any', 'more', 'than', 'with', 'individual', 'atoms', 'or', 'molecules', '.'], ['An', 'amount', 'of', 'light', 'compatible', 'with', 'everyday', 'experience', 'is', 'the', 'energy', 'of', 'one', 'mole', 'of', 'photons', ';', 'its', 'energy', 'can', 'be', 'computed', 'by', 'multiplying', 'the', 'photon', 'energy', 'by', 'the', 'Avogadro', 'constant', ',', 'NA', '≈', '7023602200000000000♠6.022×1023', 'mol−1', '.'], ['The', 'result', 'is', 'that', 'green', 'light', 'of', 'wavelength', '555', 'nm', 'has', 'an', 'energy', 'of', '7005216000000000000♠216', 'kJ/mol', ',', 'a', 'typical', 'energy', 'of', 'everyday', 'life', '.'], ['In', 'the', 'last', 'years', 'of', 'the', 'nineteenth', 'century', ',', 'Planck', 'was', 'investigating', 'the', 'problem', 'of', 'black-body', 'radiation', 'first', 'posed', 'by', 'Kirchhoff', 'some', 'forty', 'years', 'earlier', '.'], ['It', 'is', 'well', 'known', 'that', 'hot', 'objects', 'glow', ',', 'and', 'that', 'hotter', 'objects', 'glow', 'brighter', 'than', 'cooler', 'ones', '.'], ['The', 'electromagnetic', 'field', 'obeys', 'laws', 'of', 'motion', 'similarly', 'to', 'a', 'mass', 'on', 'a', 'spring', ',', 'and', 'can', 'come', 'to', 'thermal', 'equilibrium', 'with ...

# %% [markdown]
# <b>Locate answer sentence with TF-IDF</b>

# %%
TfidfVectorizers = []
tfidf_paras_mats = []
for paras in docs:
    tfidf = TfidfVectorizer(tokenizer=word_tokenize, lowercase=True)
    tfidf_paras_mats.append(tfidf.fit_transform(paras))
    TfidfVectorizers.append(tfidf)

train_context_sents = []
train_queries = []
train_answers = []
for i,query in enumerate(train_qs):
    docid = train_docids[i]
    tfidf_query = TfidfVectorizers[docid].transform([query])
    relativities = np.dot(tfidf_query, tfidf_paras_mats[docid].T).toarray()
    indices = (-relativities).argsort()[0]
    
    answer = train_texts[i]
    tokenized_answer = word_tokenize(answer)
    for index in indices:
        tokenized_context = tokenized_docs[docid][index]
        #if answer is not in context, which means we failed to find the right context. We discard this train item
        if tokenized_answer[0] in tokenized_context and tokenized_answer[-1] in tokenized_context:
            train_context_sents.append(docs[docid][index])
            train_queries.append(query)
            train_answers.append(answer)
            break
print(train_context_sents[6])
print(train_queries[6])
print(train_answers[6])
            
test_context_sents = []
for i,query in enumerate(test_qs):
    docid = test_docids[i]
    tfidf_query = TfidfVectorizers[docid].transform([query])
    relativities = np.dot(tfidf_query, tfidf_paras_mats[docid].T)
    index = np.argmax(relativities)
    test_context_sents.append(docs[docid][index])
print(test_context_sents[0])
# Out:
# First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.
# What is frequency also known as in science
# f
# Modern web browsers support a combination of standards-based and de facto HTML and XHTML, which should be rendered in the same way by all browsers.

# %% [markdown]
# <b>Get answer indices in context</b>

# %%
tokenized_train_context = [word_tokenize(context) for context in train_context_sents]
tokenized_train_qs = [word_tokenize(query) for query in train_queries]
tokenized_train_answers = [word_tokenize(answer) for answer in train_answers]

# %%
#indices of answer words in context 
train_answers_indices = []
for i,answer in enumerate(tokenized_train_answers):
    start_w = answer[0]
    start_i = -1
    end_w = answer[-1]
    end_i = -1
    
    has_answer = False
    for j,word in enumerate(tokenized_train_context[i]):
        if start_w == word:
            start_i = j
        if end_w == word:
            end_i = j
        
        answer_indices = []
        #answer should be less than 5 words, and start index should smaller than end_i
        if start_i!=-1 and end_i - start_i <= 5 and end_i >= start_i :
            for index in range(start_i, end_i+1):
                answer_indices.append(index)
            train_answers_indices.append(answer_indices)
            has_answer = True
            break
    if not has_answer:
        train_answers_indices.append([])
        
print(tokenized_train_context[0])
print(tokenized_train_answers[0])
print(train_answers_indices[0])
    
tokenized_test_context = [word_tokenize(context) for context in test_context_sents]
tokenized_test_qs = [word_tokenize(query) for query in test_qs]
# Out:
# ['The', 'most', 'urgent', 'unit', 'on', 'the', 'list', 'for', 'redefinition', 'is', 'the', 'kilogram', ',', 'whose', 'value', 'has', 'been', 'fixed', 'for', 'all', 'science', '(', 'since', '1889', ')', 'by', 'the', 'mass', 'of', 'a', 'small', 'cylinder', 'of', 'platinum–iridium', 'alloy', 'kept', 'in', 'a', 'vault', 'just', 'outside', 'Paris', '.']
# ['cylinder']
# [31]

# %%
embed_train_context = [[embedding[vocab[word]] for word in context if word in vocab] for context in tokenized_train_context]
embed_train_qs = [[embedding[vocab[word]] for word in q if word in vocab] for q in tokenized_train_qs]
embed_train_answers = [[embedding[vocab[word]] for word in answer if word in vocab] for answer in tokenized_train_answers]
embed_test_context = [[embedding[vocab[word]] for word in context if word in vocab] for context in tokenized_test_context]
embed_test_qs = [[embedding[vocab[word]] for word in q if word in vocab] for q in tokenized_test_qs]
print(embed_train_answers[0])
# Out:
# [['0.53501', '0.51619', '1.2869', '-0.44228', '-0.6153', '1.5837', '0.77163', '-0.74072', '-0.59075', '0.44771', '0.35128', '0.16073', '-0.43567', '1.5196', '-0.32378', '0.0080341', '-0.37728', '1.537', '-0.44858', '-2.0515', '0.050697', '-1.3163', '-0.074289', '-0.13453', '0.1929', '-0.46173', '0.51555', '1.3476', '-0.38719', '0.38547', '1.7052', '-0.84175', '0.16006', '1.0468', '1.2382', '0.33616', '0.95423', '0.14869', '0.48572', '0.44431', '0.54502', '-0.20186', '-0.43291', '0.1342', '-0.58757', '0.40151', '0.93869', '0.16292', '-0.1962', '-0.99166']]

# %% [markdown]
# <b>Deep learning model</b>

# %%
max_context_size = 0
for tokenized_doc in tokenized_docs:
    for tokenized_sent in tokenized_doc:
        len_sent = len(tokenized_sent)
        if max_context_size < len_sent:
            max_context_size = len_sent

max_query_size = 0
for query in tokenized_train_qs_all:
    len_query = len(query)
    if max_query_size < len_query:
        max_query_size = len_query
for query in tokenized_test_qs_all:
    len_query = len(query)
    if max_query_size < len_query:
        max_query_size = len_query
        
max_answer_size = 0
for answer in tokenized_train_answers:
    len_answer = len(answer)
    if max_answer_size < len_answer:
        max_answer_size = len_answer

print(max_context_size)
print(max_query_size)
print(max_answer_size)
# Out:
# 382
# 59
# 8

# %% [markdown]
# training data

# %%
trainig_size = len(embed_train_qs)

training_contexts = np.zeros(
    (trainig_size, max_context_size, embedding_size),
    dtype='float32')
training_queries = np.zeros(
    (trainig_size, max_query_size, embedding_size),
    dtype='float32')
#answers are indices in context
# training_answers = np.zeros(
#     (trainig_size, max_answer_size, max_context_size),
#     dtype='float32')

#answers are start and end indices in context
training_answers = np.zeros(
    ( 2, trainig_size, max_context_size),
    dtype='float32')

#similarity matrix of context words to context words
training_cc = np.zeros(
    (trainig_size, max_context_size, max_context_size),
    dtype='float32')
#similarity matrix of query words to query words
training_qq = np.zeros(
    (trainig_size, max_query_size, max_query_size),
    dtype='float32')
#similarity matrix of context words to query words
training_qc = np.zeros(
    (trainig_size, max_query_size, max_context_size),
    dtype='float32')
training_input = np.zeros(
    (trainig_size, max_query_size, max_context_size),
    dtype='float32')

for i, embed_context in enumerate(embed_train_context):
    for j, embed_word in enumerate(embed_context):
        training_contexts[i,j] = embed_word
        
for i, embed_query in enumerate(embed_train_qs):
    for j, embed_word in enumerate(embed_query):
        training_queries[i,j] = embed_word

for i, answer_indices in enumerate(train_answers_indices):
    if len(answer_indices) > 1:
        training_answers[0, i, answer_indices[0]] = 1.
        training_answers[1, i, answer_indices[-1]] = 1.
        
for i in range(trainig_size):
    training_cc[i] = np.dot(training_contexts[i], training_contexts[i].T)
    training_qq[i] = np.dot(training_queries[i], training_queries[i].T)
    training_qc[i] = np.dot(training_queries[i], training_contexts[i].T)
    training_input[i] = np.dot( np.dot(training_qq[i], training_qc[i]), training_cc[i])

# %% [markdown]
# testing data

# %%
testing_size = len(embed_test_qs)

testing_contexts = np.zeros(
    (testing_size, max_context_size, embedding_size),
    dtype='float32')
testing_size_queries = np.zeros(
    (testing_size, max_query_size, embedding_size),
    dtype='float32')

#similarity matrix of context words to context words
testing_cc = np.zeros(
    (testing_size, max_context_size, max_context_size),
    dtype='float32')
#similarity matrix of query words to query words
testing_qq = np.zeros(
    (testing_size, max_query_size, max_query_size),
    dtype='float32')
#similarity matrix of context words to query words
testing_qc = np.zeros(
    (testing_size, max_query_size, max_context_size),
    dtype='float32')
testing_input = np.zeros(
    (testing_size, max_query_size, max_context_size),
    dtype='float32')

for i, embed_context in enumerate(embed_test_context):
    for j, embed_word in enumerate(embed_context):
        testing_contexts[i,j] = embed_word
        
for i, embed_query in enumerate(embed_test_qs):
    for j, embed_word in enumerate(embed_query):
        testing_queries[i,j] = embed_word
        
for i in range(testing_size):
    testing_cc[i] = np.dot(testing_contexts[i], testing_contexts[i].T)
    testing_qq[i] = np.dot(testing_queries[i], testing_queries[i].T)
    testing_qc[i] = np.dot(testing_queries[i], testing_contexts[i].T)
    testing_input[i] = np.dot( np.dot(testing_qq[i], testing_qc[i]), testing_cc[i])
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-99-775ec175cdc9> in <module>()
#      30 for i, embed_query in enumerate(embed_test_qs):
#      31     for j, embed_word in enumerate(embed_query):
# ---> 32         testing_queries[i,j] = embed_word
#      33
#      34 for i in range(testing_size):
#
# NameError: name 'testing_queries' is not defined

# %% [markdown]
# '''
# testing_size = len(embed_test_qs)
#
# input_contexts = np.zeros(
#     (testing_size, max_context_size, embedding_size),
#     dtype='float32')
#
# input_queries = np.zeros(
#     (testing_size, max_query_size, embedding_size),
#     dtype='float32')
# '''

# %%
import keras.backend as K
from keras.models import Model
from keras import layers
from keras.layers import Input, GRU, Dense, Reshape, Flatten

batch_size = 128  
epochs = 100
qc_relations_size = max_context_size*max_query_size

# %% [markdown]
# <b>model 1 pure GRU</b>

# %%
qc_relations = Input(shape=(None, max_context_size))
qc_relations_dense = Dense(max_query_size, activation='relu')(qc_relations)
encoder_outputs = GRU(output_dim = max_context_size, activation = 'tanh')(qc_relations_dense) #output_dim #activation

start = Dense(max_context_size, activation='softmax')(encoder_outputs)
end = Dense(max_context_size, activation='softmax')(encoder_outputs)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(activation="tanh", units=50)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model = Model(qc_relations, [start, end])
model.compile(optimizer='adam', loss='categorical_crossentropy') 
model.fit(training_input, [training_answers[0], training_answers[1]] ,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)

# %%
my_answers = []
for i,embed_query in enumerate(embed_train_qs):
    start_idx, end_idx = model.predict(training_input[i:i+1])
    start_idx = np.argmax(start_idx)
    end_idx = np.argmax(end_idx)
    print(train_answers_indices[i], "\t", start_idx, end_idx)
    print("Answer:", train_answers[i], "My answer:", tokenized_train_context[i][start_idx:end_idx+1])
# Out:
# [31] 	 5 8
# Answer: cylinder My answer: ['the', 'list', 'for', 'redefinition']
# [3, 4, 5] 	 5 8
# Answer: time vs. energy My answer: ['energy', '.']
# [15, 16, 17] 	 5 8
# Answer: quantum of action My answer: ['some', 'multiple', 'of', 'a']
# [11] 	 5 8
# Answer: 1913 My answer: ['quantized', 'model', 'of', 'the']
# [7] 	 5 8
# Answer: h My answer: ['existence', 'of', 'h', '(']
# [7] 	 5 8
# Answer: h My answer: ['existence', 'of', 'h', '(']
# [42] 	 5 8
# Answer: f My answer: ['Max', 'Planck', ',', 'it']
# [9] 	 5 8
# Answer: 1839 My answer: ['Alexandre', 'Edmond', 'Becquerel', 'in']
# [19] 	 5 8
# Answer: 1911 My answer: ['as', 'the', '``', 'ultraviolet']
# [78, 79] 	 5 8
# Answer: multiphoton effect My answer: ['each', 'photoelectron', ')', 'is']
# [5, 6] 	 5 8
# Answer: nuclear magneton My answer: ['nuclear', 'magneton', 'are', 'units']
# [9, 10] 	 5 8
# Answer: 555 nanometres My answer: ['with', 'a', 'wavelength', 'of']
# [6] 	 5 8
# Answer: 1911 My answer: ['in', '1911', 'was', 'devoted']
# [22, 23] 	 5 8
# Answer: hot atoms My answer: ['of', 'motion', 'similarly', 'to']
# [6] 	 5 8
# Answer: thermal My answer: ['is', 'thermal', 'leads', 'to']
# [23] 	 5 8
# Answer: quantum My answer: [',', 'the', 'minimal', 'energy']
# [32] 	 5 8
# Answer: forbidden My answer: ['as', 'for', 'monochromatic', 'light']
# [23] 	 5 8
# Answer: particles My answer: ['the', 'Planck', 'constant', 'reflects']
# [17, 18] 	 5 8
# Answer: a wave My answer: [',', 'electromagnetic', 'radiation', 'such']
# [3] 	 5 8
# Answer: green My answer: ['with', 'a', 'wavelength', 'of']
# [7] 	 5 8
# Answer: colour My answer: ['that', 'the', 'colour', 'of']
# [6, 7, 8, 9, 10] 	 5 8
# Answer: the `` ultraviolet catastrophe '' My answer: ['as', 'the', '``', 'ultraviolet']
# [] 	 5 8
# Answer: the kilogram My answer: ['of', 'micrograms', 'in', 'one']
# [13] 	 5 8
# Answer: intensity My answer: ['wave', 'in', 'a', 'given']
# [31, 32] 	 5 8
# Answer: watt-balance measurement My answer: ['is', 'based', 'on', 'three']
# [25, 26, 27] 	 5 8
# Answer: a circular argument My answer: ['of', 'the', 'Planck', 'constant']
# [21, 22] 	 5 8
# Answer: the frequency My answer: ['each', 'photoelectron', ')', 'is']
# [] 	 5 8
# Answer: the light quantum My answer: [',', 'the', 'minimal', 'energy']
# [] 	 5 8
# Answer: time vs. energy My answer: ['spotlight', 'is', 'more', 'intense']
# [5] 	 5 8
# Answer: sound My answer: ['sound', 'or', 'the', 'waves']
# [18] 	 5 8
# Answer: thermal My answer: [',', 'meaning', 'it', 'absorbs']
# [12, 13] 	 5 8
# Answer: physical action My answer: ["'s", 'discovery', ',', 'it']
# [4, 5, 6] 	 5 8
# Answer: laws of motion My answer: ['of', 'motion', 'similarly', 'to']
# [9, 10] 	 5 8
# Answer: 555 nanometres My answer: ['with', 'a', 'wavelength', 'of']
# [16] 	 5 8
# Answer: relativity My answer: ['prize', 'for', 'his', 'work']
# [3, 4] 	 5 8
# Answer: the quantity My answer: [',', 'now', 'known', 'as']
# [4] 	 5 8
# Answer: 1918 My answer: ['Nobel', 'Prize', 'in', 'Physics']
# [15] 	 5 8
# Answer: black-body My answer: ['the', 'nineteenth', 'century', ',']
# [26] 	 5 8
# Answer: h My answer: [',', 'which', 'correctly', 'predicts']
# [15, 16, 17] 	 5 8
# Answer: quantum of action My answer: ['some', 'multiple', 'of', 'a']
# [33] 	 5 8
# Answer: platinum–iridium My answer: ['the', 'list', 'for', 'redefinition']
# [9, 10] 	 5 8
# Answer: blackbody emissions My answer: [',', 'which', 'correctly', 'predicts']
# [30] 	 5 8
# Answer: 2007 My answer: ['is', 'based', 'on', 'three']
# [18, 19, 20] 	 5 8
# Answer: thermal light emission My answer: [',', 'meaning', 'it', 'absorbs']
# [25, 26] 	 5 8
# Answer: white hot My answer: ['that', 'the', 'colour', 'of']
# [15, 16] 	 5 8
# Answer: black-body radiation My answer: ['the', 'nineteenth', 'century', ',']
# [13] 	 5 8
# Answer: intensity My answer: ['wave', 'in', 'a', 'given']
# [19] 	 5 8
# Answer: 1921 My answer: ['the', 'effect', 'in', 'terms']
# [2, 3, 4] 	 5 8
# Answer: the energy account My answer: ['of', 'the', 'photoelectric', 'effect']
# [1] 	 5 8
# Answer: 1905 My answer: [',', 'the', 'minimal', 'energy']
# [17, 18] 	 5 8
# Answer: a wave My answer: [',', 'electromagnetic', 'radiation', 'such']
# [22] 	 5 8
# Answer: forty My answer: ['the', 'nineteenth', 'century', ',']
# [6] 	 5 8
# Answer: 1911 My answer: ['in', '1911', 'was', 'devoted']
# [6] 	 5 8
# Answer: light My answer: ['with', 'light', 'absorbs', 'just']
# [11] 	 5 8
# Answer: hotter My answer: ['hot', 'objects', 'glow', ',']
# [10] 	 5 8
# Answer: accurate My answer: ['is', 'thermal', 'leads', 'to']
# [22] 	 5 8
# Answer: silicon My answer: ['Si', ')', 'requires', 'a']
# [30, 31, 32] 	 5 8
# Answer: the stefan–boltzmann law My answer: ['is', 'thermal', 'leads', 'to']
# [20, 21, 22] 	 5 8
# Answer: renewable energy technologies My answer: ['Change', 'has', 'said', 'that']
# [5] 	 5 8
# Answer: 2006 My answer: ['2006', 'pushed', 'renewable', 'energy']
# [8, 9, 10] 	 5 8
# Answer: $ 140.4 billion My answer: ['in', '2012', 'was', '$']
# [26, 27] 	 5 8
# Answer: global warming My answer: ['%', 'renewable', 'energy', ',']
# [3] 	 5 8
# Answer: three My answer: ['plants', 'larger', 'than', '10']
# [24] 	 5 8
# Answer: half My answer: ['``', 'Photovoltaic', 'and', 'solar-thermal']
# [12, 13, 14] 	 5 8
# Answer: renewable energy policy My answer: ['can', 'be', 'an', 'important']
# [5, 6] 	 5 8
# Answer: 58 percent My answer: ['58', 'percent', ',', 'to']
# [8, 9] 	 5 8
# Answer: 18.1 percent My answer: ['2012', 'increased', 'by', '18.1']
# [16, 17] 	 5 8
# Answer: 22 percent My answer: ['report', ',', 'renewables', 'contributed']
# [5] 	 5 8
# Answer: renewables My answer: ['renewables', 'exceeded', 'fossils', '.']
# [] 	 5 8
# Answer: tax shifting My answer: ['already', 'shifting', 'taxes', 'in']
# [5, 6] 	 5 8
# Answer: 19 % My answer: ['19', '%', 'of', 'electricity']
# [13, 14, 15] 	 5 8
# Answer: social and political My answer: ['energy', 'plan', 'are', 'seen']
# [21] 	 5 8
# Answer: 2060 My answer: ['``', 'Photovoltaic', 'and', 'solar-thermal']
# [13, 14] 	 5 8
# Answer: 10 percent My answer: ['in', 'the', 'United', 'States']
# [3] 	 5 8
# Answer: hydroelectricity My answer: ['low', ',', 'making', 'it']
# [] 	 5 8
# Answer: renewable energy commercialization My answer: ['deployment', 'of', 'three', 'generations']
# [3] 	 5 8
# Answer: 144 My answer: ['with', 'renewable', 'energy', 'policy']
# [9, 10] 	 5 8
# Answer: 19 percent My answer: ['report', ',', 'renewables', 'contributed']
# [22] 	 5 8
# Answer: coal My answer: ['reducing', 'climate', 'disrupting', 'subsidies']
# [2] 	 5 8
# Answer: 2011 My answer: [']', ',', 'there', 'have']
# [10] 	 5 8
# Answer: 2008 My answer: ['drops', 'in', 'module', 'prices']
# [4, 5] 	 5 8
# Answer: renewable energy My answer: ['energy', 'accounts', 'for', 'about']
# [3] 	 5 8
# Answer: hydroelectricity My answer: ['low', ',', 'making', 'it']
# [13, 14] 	 5 8
# Answer: 9 % My answer: ['19', '%', 'of', 'electricity']
# [10, 11] 	 5 8
# Answer: renewable energy My answer: ['Ki-moon', 'has', 'said', 'that']
# [26, 27] 	 5 8
# Answer: 17 percent My answer: ['power', 'accounts', 'for', 'a']
# [8, 9, 10] 	 5 8
# Answer: $ 244 billion My answer: ['in', '2012', 'was', '$']
# [13, 14] 	 5 8
# Answer: market expansion My answer: ['the', 'main', 'driver', 'of']
# [7] 	 5 8
# Answer: 2030 My answer: ['triple', 'by', '2030', '.']
# [4] 	 5 8
# Answer: 150 My answer: ['countries', ',', 'with', 'the']
# [4, 5, 6, 7] 	 5 8
# Answer: renewable technologies My answer: ['power', 'generation', 'technologies', 'accounted']
# [1, 2, 3, 4] 	 5 8
# Answer: $ 1.00/w installed cost My answer: [',', 'is', 'often', 'regarded']
# [36] 	 5 8
# Answer: 2030 My answer: ['of', 'civil', 'and', 'environmental']
# [] 	 5 8
# Answer: energy regulators My answer: ['to', 'carry', 'out', 'a']
# [4, 5] 	 5 8
# Answer: renewable energy My answer: ['energy', 'accounts', 'for', 'about']
# [4, 5] 	 5 8
# Answer: renewable energy My answer: ['energy', 'plays', 'a', 'major']
# [1] 	 5 8
# Answer: 1958 My answer: ['a', 'Boy', 'Scout', 'and']
# [8] 	 5 8
# Answer: 1997 My answer: ['producer', 'for', 'the', '1997']
# [9] 	 5 8
# Answer: 1995 My answer: ['from', 'that', 'time', 'until']
# [1, 2] 	 5 8
# Answer: vice president My answer: ['was', 'impressed', 'by', 'the']
# [1] 	 5 8
# Answer: 1997 My answer: ['Film', 'Institute', 'listed', 'it']
# [27] 	 5 8
# Answer: 1,100 My answer: ['Schindler', "'s", 'List', ',']
# [9] 	 5 8
# Answer: 2005 My answer: ['Fame', 'inducted', 'Spielberg', 'in']
# [14] 	 5 8
# Answer: intrusive My answer: ['use', 'of', 'cut', 'scenes']
# [10] 	 5 8
# Answer: 1993 My answer: [',', 'and', 'Jurassic', 'Park']
# [2] 	 5 8
# Answer: 1984 My answer: ['their', 'romance', ',', 'and']
# [11, 12, 13] 	 5 8
# Answer: $ 200 million My answer: ['box', 'office', 'success', ',']
# [18, 19] 	 5 8
# Answer: # 9 My answer: ['Film', 'Institute', 'listed', 'it']
# [6] 	 5 8
# Answer: 1989 My answer: ['the', '1989', 'National', 'Scout']
# [8] 	 5 8
# Answer: 1979 My answer: ['broke', 'up', 'in', '1979']
# [21, 22] 	 5 8
# Answer: the 1930s My answer: ['began', 'opening', 'to', 'Western']
# [13, 14] 	 5 8
# Answer: his father My answer: ['$', '500', ',', 'most']
# [31, 32] 	 5 8
# Answer: his father My answer: ['most', 'autobiographical', 'aspect', 'of']
# [2] 	 5 8
# Answer: 1984 My answer: ['their', 'romance', ',', 'and']
# [13, 14] 	 5 8
# Answer: 15–20 years My answer: ['global', 'human', 'war', 'against']
# [17] 	 5 8
# Answer: two My answer: ['on', 'the', 'critically', 'acclaimed']
# [4] 	 5 8
# Answer: co-producer My answer: ['of', 'the', '1987', 'film']
# [2] 	 5 8
# Answer: five My answer: ['nominations', ',', 'including', 'Best']
# [16] 	 5 8
# Answer: 26-minute My answer: ['opportunity', 'to', 'make', 'a']
# [13] 	 5 8
# Answer: actress My answer: ['that', 'Spielberg', 'also', 'met']
# [13] 	 5 8
# Answer: four My answer: ['his', 'work', ',', 'Universal']
# [23] 	 5 8
# Answer: seven-year My answer: ['was', 'impressed', 'by', 'the']
# [18] 	 5 8
# Answer: 1989 My answer: ['serious', 'dramatic', 'films', ',']
# [20] 	 5 8
# Answer: cinematography My answer: ['in', 'Scouting', ',', 'Spielberg']
# [13] 	 5 8
# Answer: four My answer: ['his', 'work', ',', 'Universal']
# [7] 	 5 8
# Answer: poorly My answer: ['film', 'fared', 'poorly', 'at']
# [23] 	 5 8
# Answer: 1996 My answer: ['publishers', 'Knowledge', 'Adventure', 'on']
# [24] 	 5 8
# Answer: 1980 My answer: ['Encounters', 'project', 'and', ',']
# [13] 	 5 8
# Answer: six My answer: ['reviews', 'from', 'critics', ',']
# [18] 	 5 8
# Answer: 1982 My answer: ['the', 'novel', 'of', 'the']
# [15, 16, 17] 	 5 8
# Answer: reportedly close friends My answer: [',', "''", 'starred', 'Joan']
# [50] 	 5 8
# Answer: terrorism My answer: ['films', 'began', 'addressing', 'humanistic']
# [10] 	 5 8
# Answer: 1981 My answer: ['at', 'the', 'box', 'office']
# [18] 	 5 8
# Answer: editing My answer: ['he', 'was', 'offered', 'a']
# [6] 	 5 8
# Answer: impressed My answer: ['was', 'impressed', 'by', 'the']
# [9] 	 5 8
# Answer: 2005 My answer: ['on', 'the', 'critically', 'acclaimed']
# [7, 8, 9, 10] 	 5 8
# Answer: exceeds $ 9 billion My answer: ['Spielberg-directed', 'films', 'exceeds', '$']
# [1] 	 5 8
# Answer: two My answer: ['serious', 'dramatic', 'films', ',']
# [25] 	 5 8
# Answer: 1989 My answer: ['years', 'of', 'marriage', ',']
# [7] 	 5 8
# Answer: 1974 My answer: ['Jaws', 'in', '1974', ',']
# [26] 	 5 8
# Answer: three My answer: ['Best', 'Production', 'Design', 'and']
# [3] 	 5 8
# Answer: eleven My answer: ['Award', 'nominations', ',', 'including']
# [2, 3] 	 5 8
# Answer: science fiction My answer: ['impressed', 'Universal', 'Studios', 'and']
# [3] 	 5 8
# Answer: actress My answer: ['Irving', 'in', '1976', 'at']
# [4] 	 5 8
# Answer: two My answer: ['categories', '(', 'Cinematography', ',']
# [6] 	 5 8
# Answer: 1975 My answer: ['(', '1975', ')', ',']
# [] 	 5 8
# Answer: `` bachelor funky '' My answer: ['E-Poll', 'Market', 'Research', ',']
# [1] 	 5 8
# Answer: two My answer: ['serious', 'dramatic', 'films', ',']
# [24] 	 5 8
# Answer: 1994 My answer: ['own', 'directorial', 'copy', 'of']
# [18] 	 5 8
# Answer: 1969 My answer: ['came', 'when', 'he', 'was']
# [47] 	 5 8
# Answer: 1953 My answer: ['directed', 'a', 'modern', 'adaptation']
# [38] 	 5 8
# Answer: 2054 My answer: ['collaborated', 'for', 'the', 'first']
# [21] 	 5 8
# Answer: 1938 My answer: ['own', 'directorial', 'copy', 'of']
# [7, 8, 9] 	 5 8
# Answer: $ 250 million My answer: ['have', 'cost', '$', '250']
# [7] 	 5 8
# Answer: 2014 My answer: ['Influential', 'Celebrities', '2014', 'list']
# [6] 	 5 8
# Answer: 2149 My answer: ['year', '2149', 'when', 'all']
# [5, 6] 	 5 8
# Answer: $ 500 My answer: ['$', '500', ',', 'most']
# [8, 9] 	 5 8
# Answer: during childhood My answer: ['like', 'an', 'alien', 'during']
# [36] 	 5 8
# Answer: six My answer: ['both', 'written', 'and', 'directed']
# [64] 	 5 8
# Answer: 1999 My answer: ['to', 'his', 'games', 'of']
# [25] 	 5 8
# Answer: 2018 My answer: ['early', '2017', 'for', 'release']
# [26] 	 5 8
# Answer: three My answer: ['Best', 'Production', 'Design', 'and']
# [8, 9, 10, 11] 	 5 8
# Answer: $ 470 million worldwide My answer: ['Spielberg-directed', 'films', 'exceeds', '$']
# [15, 16] 	 5 8
# Answer: 92 % My answer: ['with', 'the', 'review', 'tallying']
# [30, 31, 32] 	 5 8
# Answer: 85 million years My answer: ['year', '2149', 'when', 'all']
# [33] 	 5 8
# Answer: embarrassed My answer: ['I', 'enjoy', 'admitting', ',']
# [2] 	 5 8
# Answer: 2010 My answer: ['Pacific', 'he', 'teamed', 'up']
# [45] 	 5 8
# Answer: 2009 My answer: ['honored', 'with', 'the', 'Cecil']
# [13] 	 5 8
# Answer: three My answer: ['Best', 'Picture', 'and', 'featured']
# [2] 	 5 8
# Answer: thirteen My answer: ['living', 'in', 'Phoenix', ',']
# [15] 	 5 8
# Answer: 40-minute My answer: ['living', 'in', 'Phoenix', ',']
# [12] 	 5 8
# Answer: 1858 My answer: ['story', 'of', 'a', 'young']
# [11] 	 5 8
# Answer: 2001 My answer: ['a', 'moderate', 'success', ',']
# [1] 	 5 8
# Answer: 2002 My answer: ['one', 'of', 'eight', 'flagbearers']
# [8, 9] 	 5 8
# Answer: 47 % My answer: ['47', ',', 'meaning', '47']
# [33, 34] 	 5 8
# Answer: electrical engineer My answer: ['Adler', ')', 'Posner', '(']
# [14, 15] 	 5 8
# Answer: a headteacher My answer: ['Indiana', 'Jones', ',', 'Spielberg']
# [23, 24, 25] 	 5 8
# Answer: as a child My answer: ['most', 'autobiographical', 'aspect', 'of']
# [16] 	 5 8
# Answer: 1941 My answer: [',', 'Spielberg', 'purchased', 'a']
# [21] 	 5 8
# Answer: guns My answer: ['the', 'missile', 'found', 'itself']
# [23] 	 5 8
# Answer: 1950s My answer: ['have', 'for', 'the', 'most']
# [35, 36] 	 5 8
# Answer: anti-aircraft artillery My answer: ['concrete', 'blockhouses', ',', 'some']
# [10, 11] 	 5 8
# Answer: the railgun My answer: ['weapons', 'may', 'be', 'found']
# [17, 18] 	 5 8
# Answer: machine guns My answer: [',', 'at', 'RAF', 'insistence']
# [36, 37, 38] 	 5 8
# Answer: the late 1960s My answer: ['such', 'as', 'the', 'F-102']
# [13] 	 5 8
# Answer: mechanical My answer: ['(', 'based', 'on', 'a']
# [18, 19, 20] 	 5 8
# Answer: self-propelled anti-aircraft guns My answer: ['regiment-level', 'and', 'consist', 'of']
# [12] 	 5 8
# Answer: 1918 My answer: ['new', 'HAA', 'gun', ',']
# [43, 44, 45] 	 5 8
# Answer: 90 km away My answer: ['a', 'claimed', 'ability', 'to']
# [3, 4] 	 5 8
# Answer: air defence My answer: ['in', 'depth', ',', 'from']
# [4, 5] 	 5 8
# Answer: air defence My answer: ['defence', 'was', 'one', 'of']
# [11, 12] 	 5 8
# Answer: non-ballistic factors My answer: ['heavy', 'AA', 'guns', 'was']
# [5, 6, 7] 	 5 8
# Answer: for anti-aircraft fire My answer: ['for', 'anti-aircraft', 'fire', ',']
# [1] 	 5 8
# Answer: 3-inch My answer: ['at', 'the', 'end', 'of']
# [12, 13] 	 5 8
# Answer: aimed fire My answer: ['approach', 'to', 'HAA', 'fire']
# [14, 15] 	 5 8
# Answer: the backblast My answer: ['angles', 'poses', 'a', 'danger']
# [10] 	 5 8
# Answer: 1925 My answer: ['volunteer', 'Observer', 'Corps', 'formed']
# [5] 	 5 8
# Answer: 183 My answer: ['183', 'AA', 'Sections', 'defending']
# [26] 	 5 8
# Answer: four My answer: ['met', 'with', 'smaller-calibre', 'ordnance']
# [3, 4, 5] 	 5 8
# Answer: solid fuel rockets My answer: ['rockets', 'were', 'under', 'development']
# [9, 10] 	 5 8
# Answer: homeland defence My answer: ['defence', 'may', 'be', 'for']
# [8, 9] 	 5 8
# Answer: 24,000 feet My answer: ['targets', 'up', 'to', '24,000']
# [1] 	 5 8
# Answer: radar My answer: ['airspace', 'surveillance', 'to', 'detect']
# [12, 13] 	 5 8
# Answer: guided missiles My answer: ['ballistic', 'munitions', 'were', 'the']
# [23] 	 5 8
# Answer: 125 My answer: ['was', 'a', 'bit', 'light']
# [41] 	 5 8
# Answer: permanently My answer: ['to', 'destroy', ';', 'nonetheless']
# [21] 	 5 8
# Answer: aircraft My answer: ['defence', 'was', 'one', 'of']
# [10, 11] 	 5 8
# Answer: the kerrison predictor My answer: ['operators', 'tracked', 'the', 'target']
# [28] 	 5 8
# Answer: 1925 My answer: ['probably', 'first', 'used', 'by']
# [24] 	 5 8
# Answer: bombers My answer: ['simply', 'interceptor', ')', 'is']
# [10, 11, 12] 	 5 8
# Answer: 2 to 12 My answer: ['is', 'typically', 'a', 'battery']
# [9, 10] 	 5 8
# Answer: elevation angle My answer: ['the', 'target', 'and', 'the']
# [6] 	 5 8
# Answer: 1940 My answer: ['in', '1940', '.']
# [2] 	 5 8
# Answer: altitude My answer: ['jet', 'aircraft', 'limit', 'target']
# [32] 	 5 8
# Answer: 1954 My answer: ['arms', ',', 'PVO', 'Strany']
# [3, 4, 5, 6] 	 5 8
# Answer: `` effective ceiling '' My answer: ['ceiling', "''", ',', 'meaning']
# [19, 20, 21] 	 5 8
# Answer: 8 july 1914 My answer: ['for', 'anti-aircraft', 'capability', 'a']
# [33, 34] 	 5 8
# Answer: its height My answer: ['approach', 'to', 'HAA', 'fire']
# [27, 28] 	 5 8
# Answer: experimental usefulness My answer: ['lasers', 'in', 'combat', 'since']
# [8, 9] 	 5 8
# Answer: 18-pdr guns My answer: ['the', 'war', 'but', '18-pdr']
# [4, 5] 	 5 8
# Answer: into battalions My answer: ['battalions', 'or', 'equivalent', '.']
# [27, 28, 29] 	 5 8
# Answer: for 20 seconds My answer: ['British', 'definition', 'was', '``']
# [22, 23, 24, 25] 	 5 8
# Answer: the carrier 's escorts My answer: ['to', 'penetrate', 'this', 'layer']
# [5] 	 5 8
# Answer: missiles My answer: ['missiles', 'will', 'replace', 'gun']
# [2, 3] 	 5 8
# Answer: the maximum distance My answer: ['the', 'target', 'and', 'the']
# [] 	 5 8
# Answer: the gun My answer: ['to', 'the', 'British', 'war']
# [7, 8, 9] 	 5 8
# Answer: three aa corps My answer: ['it', 'comprised', 'three', 'AA']
# [21] 	 5 8
# Answer: 1943 My answer: ['these', 'devices', 'during', 'an']
# [7, 8, 9] 	 5 8
# Answer: a steel plate My answer: ['sometimes', 'welded', 'a', 'steel']
# [25, 26] 	 5 8
# Answer: slide rules My answer: ['aircraft', 'remains', 'in', 'firing']
# [7] 	 5 8
# Answer: shrapnel My answer: [')', 'and', 'shrapnel', 'were']
# [18, 19] 	 5 8
# Answer: smallest mounts My answer: ['caliber', 'or', 'even', '8']
# [3] 	 5 8
# Answer: 1924 My answer: ['started', 'on', 'a', 'new']
# [7] 	 5 8
# Answer: searchlights My answer: ['night', ',', 'searchlights', 'were']
# [9, 10] 	 5 8
# Answer: barrage balloons My answer: ['was', 'the', 'use', 'of']
# [1] 	 5 8
# Answer: 2-inch My answer: ['or', 'wire', 'obstacle', 'warheads']
# [17, 18, 19] 	 5 8
# Answer: `` archibald , certainly not ! '' My answer: ['AA', ',', 'AAA', 'or']
# [30, 31] 	 5 8
# Answer: fighter jets My answer: ['well', 'defended', ',', 'as']
# [7, 8, 9] 	 5 8
# Answer: detect hostile aircraft My answer: ['is', 'to', 'detect', 'hostile']
# [9] 	 5 8
# Answer: minimal My answer: ['application', ',', 'and', 'had']
# [4, 5] 	 5 8
# Answer: guided missile My answer: ['missile', 'resulted', 'in', 'a']
# [31, 32] 	 5 8
# Answer: guided missiles My answer: ['defence', 'was', 'one', 'of']
# [4, 5] 	 5 8
# Answer: important buildings My answer: ['buildings', 'were', 'common', 'in']
# [14] 	 5 8
# Answer: 1950s My answer: ['mm', 'guns', 'would', 'continue']
# [23, 24] 	 5 8
# Answer: the u.s. army My answer: ['some', '(', 'largely', 'communist']
# [6, 7] 	 5 8
# Answer: maximum ceiling My answer: [',', 'maximum', 'ceiling', 'being']
# [9] 	 5 8
# Answer: .50-inch My answer: ['considering', 'anything', 'larger', 'than']
# [25, 26, 27, 28, 29] 	 5 8
# Answer: `` flaktürme '' flak towers My answer: ['concrete', 'blockhouses', ',', 'some']
# [9, 10] 	 5 8
# Answer: homeland air defence My answer: ['defence', 'may', 'be', 'for']
# [1] 	 5 8
# Answer: 1925 My answer: ['a', 'new', 'instrument', 'developed']
# [8, 9] 	 5 8
# Answer: the laser My answer: ['anti-aircraft', 'use', 'is', 'the']
# [38] 	 5 8
# Answer: 1990 My answer: ['for', 'instance', ',', 'air']
# [6, 7, 8] 	 5 8
# Answer: machine-gun based weapons My answer: ['various', 'machine-gun', 'based', 'weapons']
# [4] 	 5 8
# Answer: eight My answer: ['countries', 'developed', 'radar', ',']
# [1] 	 5 8
# Answer: 1928 My answer: ['preferred', 'solution', ',', 'but']
# [11, 12] 	 5 8
# Answer: destroy them My answer: ['is', 'to', 'detect', 'hostile']
# [30, 31] 	 5 8
# Answer: 60,000 ft My answer: ['at', 'the', 'start', 'of']
# [21, 22, 23] 	 5 8
# Answer: 30-second running time My answer: ['both', '3.7', 'and', '4.5-in']
# [11, 12, 13] 	 5 8
# Answer: speed and height My answer: ['would', 'maintain', 'a', 'steady']
# [17] 	 5 8
# Answer: 74 My answer: ['183', 'AA', 'Sections', 'defending']
# [20, 21] 	 5 8
# Answer: lighter weapons My answer: ['been', 'set', ':', 'anti-aircraft']
# [25, 26] 	 5 8
# Answer: predicted trajectory My answer: ['aiming', 'a', 'shell', 'to']
# [9, 10] 	 5 8
# Answer: anti-stealth technology My answer: ['grows', ',', 'so', 'does']
# [14, 15] 	 5 8
# Answer: a movie My answer: ['to', 'the', 'British', 'war']
# [1, 2, 3] 	 5 8
# Answer: 30 september 1915 My answer: ['troops', 'of', 'the', 'Serbian']
# [15] 	 5 8
# Answer: aéronef My answer: ['is', 'called', 'DCA', '(']
# [17] 	 5 8
# Answer: 2004 My answer: ['defence', 'was', 'removed', 'from']
# [18, 19, 20] 	 5 8
# Answer: fire control elements My answer: ['is', 'typically', 'a', 'battery']
# [7] 	 5 8
# Answer: mobile My answer: ['are', 'fairly', 'mobile', '.']
# [7, 8, 9] 	 5 8
# Answer: 2020 to 2025 My answer: ['ready', 'in', '2020', 'to']
# [7] 	 5 8
# Answer: zenitnye My answer: ['are', 'called', 'zenitnye', '(']
# [3, 4, 5] 	 5 8
# Answer: a 3.7 cm My answer: ['cm', '.']
# [9, 10] 	 5 8
# Answer: air-search radar My answer: ['usually', 'be', 'acquired', 'by']
# [14] 	 5 8
# Answer: autocannons My answer: ['and', 'relatively', 'cheap', 'short-range']
# [13, 14] 	 5 8
# Answer: the 1960s My answer: ['they', 'are', 'known', 'today']
# [5] 	 5 8
# Answer: 1943 My answer: ['1943', 'an', 'entirely', 'new']
# [5, 6] 	 5 8
# Answer: steel cable My answer: ['steel', 'cable', 'were', 'a']
# [] 	 5 8
# Answer: the interceptor aircraft My answer: ['jet', 'aircraft', 'limit', 'target']
# [34, 35, 36] 	 5 8
# Answer: speed and direction My answer: ['have', 'to', 'be', 'guided']
# [43] 	 5 8
# Answer: 100 My answer: ['to', 'penetrate', 'this', 'layer']
# [1, 2] 	 5 8
# Answer: short range My answer: ['apparent', 'target', 'area', 'is']
# [38, 39] 	 5 8
# Answer: infantry positions My answer: ['the', 'infantry', ',', 'particularly']
# [14, 15] 	 5 8
# Answer: artillery arm My answer: ['for', 'instance', ',', 'air']
# [4, 5] 	 5 8
# Answer: range measurement My answer: ['measurement', 'first', ',', 'when']
# [16, 17] 	 5 8
# Answer: passive measures My answer: ['systems', ',', 'associated', 'sensor']
# [12] 	 5 8
# Answer: concealment My answer: ['by', 'ground', 'forces', 'and']
# [39] 	 5 8
# Answer: hydraulics My answer: ['control', 'system', 'including', 'both']
# [4] 	 5 8
# Answer: 1935 My answer: ['and', 'production', 'stopped', 'the']
# [1] 	 5 8
# Answer: 1938 My answer: ['the', '12.8', 'cm', 'FlaK']
# [13, 14] 	 5 8
# Answer: anti-aircraft warfare My answer: ['defence', 'as', 'counter-air', 'and']
# [10, 11] 	 5 8
# Answer: the user My answer: ['angles', 'poses', 'a', 'danger']
# [20, 21, 22] 	 5 8
# Answer: most anti-aircraft gunnery My answer: [',', 'originally', 'intended', 'for']
# [11, 12, 13] 	 5 8
# Answer: in the air My answer: ['recognised', 'that', 'ammunition', 'needed']
# [15] 	 5 8
# Answer: 45 My answer: ['shotguns', 'and', 'machine-guns', 'but']
# [26, 27] 	 5 8
# Answer: many kilometers My answer: ['Germany', "'s", '20', 'mm']
# [21, 22, 23] 	 5 8
# Answer: smaller force levels My answer: ['in', 'depth', ',', 'from']
# [32] 	 5 8
# Answer: optronics My answer: ['acoustic', 'devices', 'developed', 'during']
# [17] 	 5 8
# Answer: vertically My answer: [',', 'maximum', 'ceiling', 'being']
# [] 	 5 8
# Answer: air forces My answer: ['defence', 'may', 'be', 'for']
# [9, 10] 	 5 8
# Answer: ground forces My answer: ['the', 'air', 'force', 'and']
# [21] 	 5 8
# Answer: guns My answer: ['the', 'missile', 'found', 'itself']
# [24, 25] 	 5 8
# Answer: 75 mm My answer: ['electrical', ',', 'the', 'operator']
# [9] 	 5 8
# Answer: trailers My answer: ['to', 'be', 'mounted', 'on']
# [7, 8, 9, 10, 11] 	 5 8
# Answer: counter-air defence My answer: ['defence', 'as', 'counter-air', 'and']
# [13, 14, 15] 	 5 8
# Answer: in the 1960s My answer: ['at', 'least', 'supplanting', ',']
# [23] 	 5 8
# Answer: 3 My answer: [',', 'which', 'was', 'under']
# [] 	 5 8
# Answer: area air defence My answer: ['air', 'defence', 'of', 'a']
# [8, 9] 	 5 8
# Answer: the cold war My answer: ['by', 'Germany', 'during', 'the']
# [17, 18, 19] 	 5 8
# Answer: 90-day screening period My answer: ['for', 'both', 'types', 'except']
# [5, 6] 	 5 8
# Answer: $ 500,000 My answer: ['$', '500,000', 'the', 'Secretary']
# [4, 5] 	 5 8
# Answer: eight years My answer: ['years', 'before', 'the', 'first']
# [21] 	 5 8
# Answer: seven My answer: ['fifty-six', 'species', 'have', 'been']
# [30] 	 5 8
# Answer: butterflies My answer: ['San', 'Bruno', 'plan', 'was']
# [6, 7] 	 5 8
# Answer: two ways My answer: ['in', 'two', 'ways', '.']
# [28, 29] 	 5 8
# Answer: the clinton administration My answer: ['Endangered', 'Species', 'Act', ':']
# [11, 12] 	 5 8
# Answer: 16 birds My answer: ['1941', 'was', 'estimated', 'at']
# [] 	 5 8
# Answer: habitat conservation plan My answer: ['San', 'Bruno', 'plan', 'was']
# [12, 13] 	 5 8
# Answer: 45 days My answer: ['if', 'any', 'person', 'has']
# [18, 19] 	 5 8
# Answer: cotton-top tamarin My answer: ['noted', 'another', 'exploit', 'of']
# [11] 	 5 8
# Answer: twenty-eight My answer: ['fifty-six', 'species', 'have', 'been']
# [29, 30, 31] 	 5 8
# Answer: candidate assessment program My answer: ['Wildlife', 'Service', '(', 'FWS']
# [8, 9, 10, 11, 12] 	 5 8
# Answer: `` class of '67 '' My answer: ['to', 'as', 'the', '``']
# [9, 10] 	 5 8
# Answer: over 2,000 My answer: ['Act', 'argue', 'that', 'with']
# [24, 25] 	 5 8
# Answer: the northwest My answer: ['of', 'landscapes', ',', 'from']
# [29, 30, 31] 	 5 8
# Answer: about 75 % My answer: ['closely', 'linked', 'to', 'the']
# [7, 8] 	 5 8
# Answer: 2.8 % My answer: ['has', 'averaged', '2.8', '%']
# [1, 2, 3] 	 5 8
# Answer: the early seventies My answer: ['there', 'was', 'active', 'resistance']
# [13] 	 5 8
# Answer: one My answer: ['are', '55', 'tinkhundla', 'in']
# [] 	 5 8
# Answer: the king My answer: ['minister', 'from', 'the', 'legislature']
# [5] 	 5 8
# Answer: five My answer: ['five', 'years', 'after', 'dissolution']
# [19, 20, 21] 	 5 8
# Answer: a five-year term My answer: ['committee', '(', 'bucopho', ')']
# [18, 19, 20] 	 5 8
# Answer: neighbourhood care points My answer: ['and', 'education', '(', 'ECCE']
# [2] 	 5 8
# Answer: four My answer: ['regions', '.']
# [6] 	 5 8
# Answer: four My answer: ['is', 'four', 'and', 'the']
# [16, 17, 18, 19] 	 5 8
# Answer: more than 50 % My answer: ['200', '%', 'between', '2000']
# [12, 13] 	 5 8
# Answer: textile manufacturing My answer: ['Swazi', 'economy', ',', 'with']
# [17, 18, 19] 	 5 8
# Answer: 9 september 1964 My answer: ['took', 'place', 'and', 'the']
# [10] 	 5 8
# Answer: liqoqo My answer: ['the', 'Swazi', 'National', 'Council']
# [28, 29] 	 5 8
# Answer: 20 % My answer: ['African', 'churches', ',', 'including']
# [6, 7] 	 5 8
# Answer: 17,364 km2 My answer: ['of', '17,364', 'km2', '.']
# [19, 20] 	 5 8
# Answer: 38.8 % My answer: ['government', 'acknowledged', 'for', 'the']
# [6, 7] 	 5 8
# Answer: mid-18th century My answer: ['the', 'mid-18th', 'century', 'under']
# [4] 	 5 8
# Answer: king My answer: ["''", '.']
# [7, 8, 9] 	 5 8
# Answer: at the inkhundla My answer: ['is', 'elected', 'at', 'the']
# [2] 	 5 8
# Answer: 14 My answer: ['.']
# [6] 	 5 8
# Answer: kubhula My answer: ['``', 'kubhula', "''", ',']
# [9, 10] 	 5 8
# Answer: 18 % My answer: ['problem', ',', 'with', 'an']
# [18, 19] 	 5 8
# Answer: the majority My answer: [',', 'support', 'for', 'the']
# [20, 21] 	 5 8
# Answer: the chiefdoms My answer: ['all', 'matters', 'of', 'interest']
# [5, 6] 	 5 8
# Answer: $ 9,714 My answer: ['$', '9,714', 'means', 'it']
# [6, 7, 8] 	 5 8
# Answer: 5-year or younger My answer: ['children', '5-year', 'or', 'younger']
# [15] 	 5 8
# Answer: three My answer: ['education', 'system', 'in', 'Swaziland']
# [14] 	 5 8
# Answer: 10 My answer: ['Libandla', 'consists', 'of', 'the']
# [18, 19, 20] 	 5 8
# Answer: over 90 % My answer: ['closely', 'linked', 'to', 'the']
# [13, 14, 15] 	 5 8
# Answer: indvuna ye nkhundla My answer: ['is', 'elected', 'at', 'the']
# [19] 	 5 8
# Answer: 1906 My answer: ['(', 'for', 'example', ',']
# [14, 15, 16] 	 5 8
# Answer: at least ten My answer: ['it', ',', 'he', 'or']
# [] 	 5 8
# Answer: constituency executive committee My answer: ['committee', '(', 'bucopho', ')']
# [11, 12] 	 5 8
# Answer: 30 seats My answer: ['Libandla', 'consists', 'of', 'the']
# [3, 4] 	 5 8
# Answer: 21.6 % My answer: ['of', 'preschool', 'age', 'children']
# [27] 	 5 8
# Answer: 1982 My answer: [',', 'the', 'constitution', 'of']
# [1] 	 5 8
# Answer: 1903 My answer: ['victory', 'in', 'the', 'Anglo-Boer']
# [12, 13, 14] 	 5 8
# Answer: 19 august 2005 My answer: ['chastity', 'rite', 'of', '``']
# [33, 34, 35, 36] 	 5 8
# Answer: less than 20 % My answer: ['the', 'external', 'debt', 'burden']
# [0, 1] 	 5 8
# Answer: 83 % My answer: ['population', 'adheres', 'to', 'Christianity']
# [1, 2, 3, 4] 	 5 8
# Answer: childless , unmarried girls My answer: ['can', 'take', 'part', '.']
# [17, 18] 	 5 8
# Answer: 81 mi My answer: ['kilometres', '(', '120', 'mi']
# [10, 11] 	 5 8
# Answer: declined markedly My answer: ['the', 'external', 'debt', 'burden']
# [5, 6, 7] 	 5 8
# Answer: all young girls My answer: ['all', 'young', 'girls', 'were']
# [12] 	 5 8
# Answer: 1972 My answer: ['established', 'as', 'Mananga', 'Agricultural']
# [11, 12] 	 5 8
# Answer: 55 % My answer: ['over', '15', '%', 'of']
# [3, 4, 5] 	 5 8
# Answer: a traditional diviner My answer: ['diviner', 'chosen', 'by', 'the']
# [12, 13] 	 5 8
# Answer: a minority My answer: ['minister', 'from', 'the', 'legislature']
# [27] 	 5 8
# Answer: 2013 My answer: ['Director', 'of', 'National', 'Intelligence']
# [16, 17] 	 5 8
# Answer: home appliances My answer: ['in', 'the', 'fields', 'of']
# [3, 4, 5] 	 5 8
# Answer: about 45 % My answer: ['%', 'of', 'the', 'government']
# [4, 5] 	 5 8
# Answer: twelve jurists My answer: ['jurists', 'including', 'six', 'appointed']
# [15, 16, 17] 	 5 8
# Answer: rugged mountain ranges My answer: ['world', "'s", 'most', 'mountainous']
# [7, 8, 9] 	 5 8
# Answer: $ 15 billion My answer: ['country', 'spent', '$', '15']
# [13, 14] 	 5 8
# Answer: 70,000 citizens My answer: ['the', 'complete', 'massacre', 'of']
# [8, 9, 10] 	 5 8
# Answer: 636,372 sq mi My answer: ['1,648,195', 'km2', '(', '636,372']
# [16, 17] 	 5 8
# Answer: below zero My answer: ['in', 'the', 'Zagros', 'basin']
# [8, 9, 10] 	 5 8
# Answer: one week annually My answer: ['which', 'meets', 'for', 'one']
# [1] 	 5 8
# Answer: 2006 My answer: ['films', ',', 'of', 'six']
# [7, 8] 	 5 8
# Answer: foreign embargoes My answer: ['to', 'overcome', 'foreign', 'embargoes']
# [1] 	 5 8
# Answer: 1960s My answer: ['decade', 'for', 'Iranian', 'cinema']
# [19, 20] 	 5 8
# Answer: 33,000 megawatts My answer: ['stations', 'and', 'the', 'streamlining']
# [41, 42, 43] 	 5 8
# Answer: proven oil reserves My answer: ['and', 'middle', 'power', ',']
# [9, 10] 	 5 8
# Answer: four-year terms My answer: ['by', 'public', 'vote', 'to']
# [19] 	 5 8
# Answer: 90,000 My answer: ['volunteer', 'militia', 'force', 'within']
# [25] 	 5 8
# Answer: 65 My answer: ['decade', 'for', 'Iranian', 'cinema']
# [23, 24, 25, 26] 	 5 8
# Answer: the sassanid empire My answer: ['Shah', ',', 'Iran', 'reached']
# [23, 24] 	 5 8
# Answer: 156 years My answer: ['conqueror', ',', 'Timur', ',']
# [11, 12] 	 5 8
# Answer: 22 % My answer: ['in', 'Iran', 'make', 'up']
# [8] 	 5 8
# Answer: embargo My answer: ['such', 'as', 'the', 'embargo']
# [10, 11] 	 5 8
# Answer: 153,600,000,000 barrels My answer: ['oil', 'reserves', 'with', 'an']
# [7] 	 5 8
# Answer: six My answer: ['jurists', 'including', 'six', 'appointed']
# [1] 	 5 8
# Answer: 2010 My answer: ['reform', 'plan', 'was', 'approved']
# [11, 12, 13] 	 5 8
# Answer: 25 commercial films My answer: ['decade', 'for', 'Iranian', 'cinema']
# [13, 14] 	 5 8
# Answer: in 1906 My answer: ['the', 'first', 'national', 'parliament']
# [13, 14] 	 5 8
# Answer: construction materials My answer: ['in', 'the', 'fields', 'of']
# [11] 	 5 8
# Answer: 19 My answer: ['is', 'reflected', 'in', 'part']
# [62, 63, 64] 	 5 8
# Answer: the achaemenid empire My answer: ['its', 'power', 'during', 'the']
# [10, 11, 12, 13] 	 5 8
# Answer: mamluks ( slave-warriors ) My answer: ['in', 'the', 'Abbasid', 'army']
# [46] 	 5 8
# Answer: watermelons My answer: ['has', 'been', 'a', 'top']
# [7, 8] 	 5 8
# Answer: the 1979 constitution My answer: ['incompatible', 'with', 'the', 'constitution']
# [18, 19] 	 5 8
# Answer: were executed My answer: ['had', 'initially', 'joined', 'with']
# [33] 	 5 8
# Answer: petrochemicals My answer: ['in', 'the', 'fields', 'of']
# [13, 14] 	 5 8
# Answer: 18 % My answer: ['75', '%', 'was', 'based']
# [1] 	 5 8
# Answer: 2004 My answer: ['its', 'first', 'wind-powered', 'and']
# [32, 33] 	 5 8
# Answer: natural gas My answer: ['and', 'middle', 'power', ',']
# [48] 	 5 8
# Answer: *ar-yo- My answer: ['aryān', 'are', 'oblique', 'plural']
# [52, 53] 	 5 8
# Answer: scientific writing My answer: ['Persian', 'language', ',', 'alongside']
# [12, 13, 14] 	 5 8
# Answer: large-scale state subsidies My answer: ['a', 'chronic', 'problem', ',']
# [62, 63, 64] 	 5 8
# Answer: the achaemenid empire My answer: ['its', 'power', 'during', 'the']
# [18] 	 5 8
# Answer: 11,000–16,000 My answer: ['the', 'war', 'were', 'estimated']
# [4, 5] 	 5 8
# Answer: the gentilic My answer: ['gentilic', 'is', 'attested', 'as']
# [6] 	 5 8
# Answer: 2015 My answer: ['the', '2015', 'nuclear', 'and']
# [1] 	 5 8
# Answer: 1370 My answer: ['conqueror', ',', 'Timur', ',']
# [] 	 5 8
# Answer: the fajr-3 ( mirv ) My answer: ['the', 'most', 'mountainous', ',']
# [14] 	 5 8
# Answer: 3rd-century My answer: ['from', 'Middle', 'Persian', 'Ērān']
# [4, 5] 	 5 8
# Answer: restoring order My answer: ['order', ',', 'the', 'Russians']
# [5, 6, 7] 	 5 8
# Answer: around 40 % My answer: ['around', '40', '%', 'of']
# [7, 8] 	 5 8
# Answer: 1.4 million My answer: ['of', 'around', '1.4', 'million']
# [5, 6] 	 5 8
# Answer: military spending My answer: ['military', 'spending', 'represented', '2.6']
# [11] 	 5 8
# Answer: 1979 My answer: ['the', 'new', 'government', 'began']
# [13] 	 5 8
# Answer: 86 My answer: ['which', 'meets', 'for', 'one']
# [5, 6, 7] 	 5 8
# Answer: an economic recession My answer: ['an', 'economic', 'recession', 'led']
# [5, 6] 	 5 8
# Answer: ranked 69 My answer: ['ranked', '69', ',', 'out']
# [13, 14] 	 5 8
# Answer: in 1906 My answer: ['the', 'first', 'national', 'parliament']
# [1] 	 5 8
# Answer: 1960 My answer: ['co-invented', 'the', 'first', 'gas']
# [7] 	 5 8
# Answer: 1993 My answer: ['Internet', 'in', '1993', '.']
# [14, 15, 16] 	 5 8
# Answer: between 21.6–30 % My answer: [',', 'the', 'number', 'of']
# [4] 	 5 8
# Answer: 1988 My answer: [',', 'when', 'the', 'Iraqi']
# [1] 	 5 8
# Answer: summer My answer: ['38', '°C', '(', '100.4']
# [1, 2] 	 5 8
# Answer: 78.4 million My answer: ['Iran', 'is', 'the', 'world']
# [21, 22] 	 5 8
# Answer: rated 4th My answer: ['deputy', 'head', 'of', 'research']
# [17] 	 5 8
# Answer: 1921 My answer: ['the', 'British', 'occupied', 'much']
# [8, 9] 	 5 8
# Answer: until 1911 My answer: ['constitutional', 'movement', 'continued', 'until']
# [28, 29] 	 5 8
# Answer: 25 % My answer: [',', 'the', 'number', 'of']
# [10, 11, 12] 	 5 8
# Answer: $ 70 billion My answer: [']', ',', 'Iran', 'had']
# [24] 	 5 8
# Answer: 36,000 My answer: ['steep', 'fall', 'in', 'the']
# [] 	 5 8
# Answer: the assyrian empire My answer: ['region', 'since', 'the', '9th']
# [1, 2, 3] 	 5 8
# Answer: the 19th century My answer: ['Iran', 'irrevocably', 'lost', 'swaths']
# [6, 7, 8] 	 5 8
# Answer: over 80 % My answer: ['ruled', 'over', '44', '%']
# [13] 	 5 8
# Answer: twenty-two My answer: ['President', ',', 'as', 'well']
# [] 	 5 8
# Answer: the golrizan festival My answer: ['festival', 'that', 'had', 'begun']
# [6, 7] 	 5 8
# Answer: the bonyads My answer: ['as', 'the', 'bonyads', 'have']
# [44, 45, 46] 	 5 8
# Answer: to the south My answer: ['northwest', 'by', 'Armenia', ',']
# [26, 27, 28, 29] 	 5 8
# Answer: the sassanid era My answer: ['Iran', ',', 'like', 'those']
# [5, 6] 	 5 8
# Answer: 75 % My answer: ['75', '%', 'was', 'based']
# [6, 7, 8] 	 5 8
# Answer: the iraqi army My answer: [',', 'the', 'Iraqi', 'army']
# [3] 	 5 8
# Answer: 1973 My answer: ['in', 'oil', 'prices', ',']
# [5, 6] 	 5 8
# Answer: a third My answer: ['a', 'third', 'of', 'black']
# [9, 10] 	 5 8
# Answer: class rank My answer: ['replaced', 'racial', 'quotas', 'with']
# [1] 	 5 8
# Answer: 2006 My answer: ['%', 'of', 'Michigan', 'voters']
# [24, 25, 26] 	 5 8
# Answer: whites and males My answer: ['and', 'women', 'have', 'faced']
# [26] 	 5 8
# Answer: two My answer: ['mandated', 'the', 'end', 'of']
# [21, 22, 23] 	 5 8
# Answer: enforcing equal opportunity My answer: ['against', 'affirmative', 'action', ',']
# [25, 26] 	 5 8
# Answer: 12 % My answer: ['educated', 'major', 'ethnic', 'group']
# [5, 6, 7] 	 5 8
# Answer: integrate public facilities My answer: ['integrate', 'public', 'facilities', ',']
# [6] 	 5 8
# Answer: reservations My answer: ['onto', 'reservations', 'which', 'were']
# [21, 22] 	 5 8
# Answer: legacy admissions My answer: ['language', ',', 'social', 'class']
# [13, 14] 	 5 8
# Answer: class inequality My answer: ["'s", 'effectiveness', 'is', 'based']
# [3] 	 5 8
# Answer: 17 My answer: ['and', 'two', 'Hispanics', 'the']
# [4, 5] 	 5 8
# Answer: 60 % My answer: ['%', 'of', 'Michigan', 'voters']
# [6] 	 5 8
# Answer: 1952 My answer: ['in', '1952', ',', 'he']
# [] 	 5 8
# Answer: executive order 10925 My answer: [',', 'Kennedy', 'issued', 'Executive']
# [12, 13, 14] 	 5 8
# Answer: mediocrity and incompetence My answer: ['is', 'the', 'idea', 'that']
# [7, 8] 	 5 8
# Answer: positive action My answer: ['words', '``', 'positive', 'action']
# [3] 	 5 8
# Answer: 5-4 My answer: [',', 'the', 'Supreme', 'Court']
# [46, 47] 	 5 8
# Answer: the descendants My answer: ['in', 'the', 'South', 'Bronx']
# [30, 31, 32] 	 5 8
# Answer: remedying past discrimination My answer: ['who', 'wrote', 'From', 'Ending']
# [8, 9] 	 5 8
# Answer: compensation argument My answer: ['action', 'is', 'the', 'compensation']
# [23] 	 5 8
# Answer: 14 My answer: ['affirmative', 'action', 'itself', 'is']
# [18, 19, 20] 	 5 8
# Answer: 52 million acres My answer: ['belonging', 'to', 'Native', 'Americans']
# [3] 	 5 8
# Answer: 10,000 My answer: ['at', 'the', 'Lincoln', 'Memorial']
# [23, 24, 25] 	 5 8
# Answer: just outlawing discrimination My answer: ['similar', 'to', 'President', 'Lyndon']
# [14, 15] 	 5 8
# Answer: 80 % My answer: [',', 'Puerto', 'Ricans', ',']
# [4] 	 5 8
# Answer: racial My answer: ['classifications', 'that', 'identified', 'race']
# [1] 	 5 8
# Answer: 1976 My answer: ['of', 'Italian', 'American', 'professors']
# [30, 31] 	 5 8
# Answer: reverse discrimination My answer: ['of', 'Invisible', 'Victims', ':']
# [35, 36] 	 5 8
# Answer: white students My answer: ['of', 'minority', 'enrollment', 'can']
# [4, 5] 	 5 8
# Answer: higher educational My answer: ['educational', 'opportunities', 'were', 'so']
# [44, 45] 	 5 8
# Answer: race-conscious policy My answer: [',', 'an', 'undergraduate', 'student']
# [5] 	 5 8
# Answer: white My answer: ['white', 'in', 'the', 'US']
# [16] 	 5 8
# Answer: federal My answer: ["'s", 'executive', 'order', '11114']
# [10, 11, 12] 	 5 8
# Answer: more than triple My answer: ['rate', 'for', 'Native', 'Americans']
# [1] 	 5 8
# Answer: 1947 My answer: ['its', 'findings', ',', 'To']
# [29, 30, 31] 	 5 8
# Answer: high dropout rates My answer: ['artificially', 'elevating', 'minority', 'students']
# [7, 8, 9] 	 5 8
# Answer: more than 60 My answer: ['coalition', 'of', 'more', 'than']
# [7] 	 5 8
# Answer: white My answer: ['discrimination', 'against', 'white', 'and']
# [34, 35, 36] 	 5 8
# Answer: equality of opportunity My answer: ['America', 'had', '``', 'reached']
# [5, 6, 7] 	 5 8
# Answer: against affirmative action My answer: ['against', 'affirmative', 'action', ',']
# [24, 25] 	 5 8
# Answer: four times My answer: ['of', 'black', 'college', 'students']
# [20, 21] 	 5 8
# Answer: eight percent My answer: ['estimate', 'that', 'the', 'production']
# [14, 15] 	 5 8
# Answer: 3.1 % My answer: ['9', '%', 'of', 'the']
# [25] 	 5 8
# Answer: reverse My answer: ['action', ',', 'such', 'as']
# [8, 9] 	 5 8
# Answer: school segregation My answer: ['of', 'the', 'same', 'school']
# [12, 13] 	 5 8
# Answer: gender quotas My answer: ['action', ',', 'such', 'as']
# [6] 	 5 8
# Answer: merit My answer: ['that', 'merit', 'should', 'be']
# [12] 	 5 8
# Answer: minorities My answer: ['workers', 'and', 'unions', 'it']
# [8] 	 5 8
# Answer: 11114 My answer: ["'s", 'executive', 'order', '11114']
# [9, 10] 	 5 8
# Answer: inherently unequal My answer: ['that', 'the', 'policy', 'is']
# [3] 	 5 8
# Answer: 2007 My answer: ['Mark', 'Long', ',', 'an']
# [9] 	 5 8
# Answer: economics My answer: ['Mark', 'Long', ',', 'an']
# [11, 12] 	 5 8
# Answer: possible remedies My answer: ['of', 'historic', 'African', 'Americans']
# [3, 4, 5] 	 5 8
# Answer: least well educated My answer: ['educated', 'major', 'ethnic', 'group']
# [20, 21] 	 5 8
# Answer: craft unions My answer: ['test', 'case', 'because', ',']
# [19, 20] 	 5 8
# Answer: the states My answer: ['in', '1952', ',', 'he']
# [] 	 5 8
# Answer: executive order 10925 My answer: ['Order', '10925', 'that', '``']
# [1, 2, 3] 	 5 8
# Answer: a panel discussion My answer: ['Harvard', 'University', "'s", 'reunion']
# [1] 	 5 8
# Answer: 23 My answer: ['taking', 'the', 'test', 'were']
# [13, 14, 15] 	 5 8
# Answer: class-based affirmative action My answer: ['made', 'up', 'of', 'people']
# [9, 10, 11] 	 5 8
# Answer: became less prevalent My answer: ['advancements', 'in', 'affirmative', 'action']
# [13] 	 5 8
# Answer: education My answer: ['States', 'tends', 'to', 'focus']
# [12, 13, 14] 	 5 8
# Answer: bottom 20 percent My answer: ['of', 'black', 'college', 'students']
# [23, 24] 	 5 8
# Answer: alliterative quality My answer: ['words', '``', 'positive', 'action']
# [26] 	 5 8
# Answer: achievement My answer: ['action', 'lowers', 'the', 'bar']
# [8, 9] 	 5 8
# Answer: undesirable side-effects My answer: ['affirmative', 'action', 'has', 'undesirable']
# [] 	 5 8
# Answer: executive order 10925 My answer: [',', 'Kennedy', 'issued', 'Executive']
# [1, 2, 3] 	 5 8
# Answer: 1 september 1870 My answer: ['the', 'battle', 'opened', 'with']
# [5, 6, 7] 	 5 8
# Answer: the main power My answer: ['the', 'main', 'power', 'in']
# [5, 6, 7, 8] 	 5 8
# Answer: bronze , rifled muzzle-loading My answer: ['bronze', ',', 'rifled', 'muzzle-loading']
# [3, 4, 5] 	 5 8
# Answer: over 17,000 men My answer: ['men', ',', 'killed', 'or']
# [8] 	 5 8
# Answer: 400,000 My answer: ['peacetime', 'of', 'approximately', '400,000']
# [11] 	 5 8
# Answer: 35,000 My answer: ['reinforced', 'and', 'their', 'force']
# [30] 	 5 8
# Answer: uniforms My answer: ['Paris', 'National', 'Guard', ',']
# [11, 12] 	 5 8
# Answer: longer range My answer: ['the', 'Chassepot', ',', 'had']
# [6, 7, 8] 	 5 8
# Answer: multiple competing companies My answer: ['with', 'multiple', 'competing', 'companies']
# [16, 17, 18] 	 5 8
# Answer: steel breech-loading guns My answer: ['bronze', ',', 'rifled', 'muzzle-loading']
# [5, 6, 7] 	 5 8
# Answer: declaration of war My answer: ['declaration', 'of', 'war', ',']
# [23, 24, 25] 	 5 8
# Answer: belt of fortresses My answer: ['small', 'victories', 'at', 'towns']
# [18] 	 5 8
# Answer: 270,000 My answer: ['Franco-Prussian', 'War', ',', '462,000']
# [10, 11, 12] 	 5 8
# Answer: 4 august 1870 My answer: ['Franco-Prussian', 'War', 'took', 'place']
# [13, 14] 	 5 8
# Answer: 20 miles My answer: ['to', 'Wissembourg', ',', 'spread']
# [8] 	 5 8
# Answer: war My answer: ['III', 'also', 'sought', 'war']
# [24, 25] 	 5 8
# Answer: independent thinking My answer: ['military', 'education', 'system', 'was']
# [5, 6, 7] 	 5 8
# Answer: 10 may 1871 My answer: ['10', 'May', '1871', 'gave']
# [12, 13] 	 5 8
# Answer: 1,000 dead My answer: ['not', 'surrender', 'retreated', 'westward']
# [5, 6] 	 5 8
# Answer: heavy guns My answer: ['heavy', 'guns', 'to', 'engage']
# [12] 	 5 8
# Answer: nobody My answer: ['became', 'choked', 'with', 'loaded']
# [8, 9] 	 5 8
# Answer: 5,000 men My answer: ['which', 'they', 'lost', '5,000']
# [26] 	 5 8
# Answer: 1,000,000 My answer: ['of', 'men', 'of', 'military']
# [18, 19] 	 5 8
# Answer: 1,000 prisoners My answer: ['not', 'surrender', 'retreated', 'westward']
# [1, 2, 3] 	 5 8
# Answer: 28 january 1871 My answer: ['Government', 'of', 'National', 'Defence']
# [12, 13, 14] 	 5 8
# Answer: 16 august 1870 My answer: ['Posen', 'situation', ',', 'sent']
# [16, 17] 	 5 8
# Answer: the franco-austrian war My answer: ['declared', 'the', 'Third', 'Republic']
# [28, 29] 	 5 8
# Answer: over 150,000 My answer: ['Bazaine', "'s", 'Army', 'of']
# [1, 2, 3] 	 5 8
# Answer: 16 july 1870 My answer: ['the', 'French', 'parliament', 'voted']
# [8] 	 5 8
# Answer: westward My answer: ['not', 'surrender', 'retreated', 'westward']
# [11, 12, 13] 	 5 8
# Answer: incessant cavalry charges My answer: ['and', 'III', 'Corps', 'was']
# [9, 10] 	 5 8
# Answer: pre-war preparations My answer: ['was', 'accentuated', 'by', 'the']
# [2] 	 5 8
# Answer: starving My answer: ['Gambetta', "'s", 'provincial', 'armies']
# [20] 	 5 8
# Answer: reforms My answer: ['Prussian', 'Minister', 'of', 'War']
# [8] 	 5 8
# Answer: 462,000 My answer: ['Franco-Prussian', 'War', ',', '462,000']
# [] 	 5 8
# Answer: the north sea My answer: ['French', 'Navy', 'put', 'to']
# [3, 4, 5] 	 5 8
# Answer: four to one My answer: ['one', ',', 'the', 'III']
# [12, 13] 	 5 8
# Answer: working-class neighbourhoods My answer: ['Paris', 'National', 'Guard', ',']
# [1, 2, 3] 	 5 8
# Answer: a contact-detonated shell My answer: ['the', 'Krupp', 'gun', 'had']
# [21, 22] 	 5 8
# Answer: government buildings My answer: ['Communards', 'killed', 'c.', '500']
# [3, 4] 	 5 8
# Answer: encirclement battles My answer: ['like', 'Cannae', 'and', 'using']
# [8, 9] 	 5 8
# Answer: 500 people My answer: ['Communards', 'killed', 'c.', '500']
# [31, 32] 	 5 8
# Answer: 140,000 troops My answer: ["'s", '3rd', 'army', 'had']
# [10] 	 5 8
# Answer: food My answer: ['by', 'allowing', 'train', 'loads']
# [] 	 5 8
# Answer: the second empire My answer: ['considered', 'a', 'war', 'against']
# [10, 11] 	 5 8
# Answer: military thinking My answer: ['War', 'had', 'great', 'influence']
# [28, 29] 	 5 8
# Answer: only five My answer: ['the', 'French', 'government', 'ordered']
# [19, 20] 	 5 8
# Answer: coal reserves My answer: ['because', 'of', 'the', 'question']
# [9] 	 5 8
# Answer: conscripts My answer: ['not', 'of', 'regulars', 'but']
# [1, 2, 3] 	 5 8
# Answer: 19 july 1870 My answer: ['declaration', 'of', 'war', 'was']
# [10] 	 5 8
# Answer: 4,420 My answer: ['killed', 'and', 'wounded', 'along']
# [10, 11] 	 5 8
# Answer: 2–3 kilometres My answer: ['fire', 'at', 'a', 'range']
# [14, 15] 	 5 8
# Answer: intellectual development My answer: ['suffered', 'from', 'an', 'education']
# [11, 12] 	 5 8
# Answer: breaking up My answer: ['Prussian', 'southern', 'attacks', 'in']
# [27, 28, 29] 	 5 8
# Answer: inflamed public opinion My answer: ['the', 'public', ',', 'Bismarck']
# [15, 16] 	 5 8
# Answer: significant distances My answer: ['Moltke', "'s", 'ability', 'to']
# [11, 12, 13] 	 5 8
# Answer: their military system My answer: ['advantages', 'given', 'to', 'the']
# [4] 	 5 8
# Answer: 7,855 My answer: ['killed', 'and', 'wounded', 'along']
# [7, 8] 	 5 8
# Answer: war reparations My answer: ['amenable', 'to', 'war', 'reparations']
# [11] 	 5 8
# Answer: trench-warfare My answer: ['use', 'of', 'the', 'Chassepot']
# [24, 25] 	 5 8
# Answer: very limited My answer: ['Great', 'Britain', 'remained', 'the']
# [7, 8, 9] 	 5 8
# Answer: the chassepot rifle My answer: ['worth', 'against', 'the', 'Dreyse']
# [10, 11, 12] 	 5 8
# Answer: 1859 to 1873 My answer: ['Prussian', 'Minister', 'of', 'War']
# [4] 	 5 8
# Answer: 20,163 My answer: ['German', 'troops', 'were', 'killed']
# [9, 10, 11, 12] 	 5 8
# Answer: literally `` circle '' My answer: ['within', 'a', 'Kreis', '(']
# [15] 	 5 8
# Answer: eidos My answer: ['οἶδα', ',', '``', '(']
# [3] 	 5 8
# Answer: labrys My answer: ['was', 'the', 'holy', 'symbol']
# [10] 	 5 8
# Answer: paion My answer: ['as', 'a', 'healer', 'are']
# [4] 	 5 8
# Answer: kouros My answer: ['(', 'a', 'beardless', ',']
# [4] 	 5 8
# Answer: kouros My answer: ['(', 'a', 'beardless', ',']
# [6] 	 5 8
# Answer: paeans My answer: ['called', 'paeans', '.']
# [7, 8, 9] 	 5 8
# Answer: early archaic period My answer: ['during', 'the', 'early', 'archaic']
# [13] 	 5 8
# Answer: dolphins My answer: ['hymns', 'associated', 'the', 'epithet']
# [24] 	 5 8
# Answer: amber My answer: ['into', 'letting', 'her', 'go']
# [7] 	 5 8
# Answer: pella My answer: ['πέλλα', '(', 'pella', ')']
# [12] 	 5 8
# ...
# [1] 	 5 8
# Answer: 1578 My answer: ['granted', 'a', 'patent', 'to']
# [10] 	 5 8
# Answer: 1867 My answer: ['British', 'North', 'America', 'Act']
# [1] 	 5 8
# Answer: 1655 My answer: ['the', 'island', 'of', 'Jamaica']
# [12] 	 5 8
# Answer: 20,000 My answer: ['by', 'the', 'Chinese', 'authorities']
# [1] 	 5 8
# Answer: 1562 My answer: ['Crown', 'encouraged', 'the', 'privateers']
# [1] 	 5 8
# Answer: sixteen My answer: ['and', 'equal', 'legal', 'entities']
# [1] 	 5 8
# Answer: 1922 My answer: ['which', 'had', 'been', 'declared']
# [32, 33] 	 5 8
# Answer: 2.2 billion My answer: ['protectorates', 'are', 'among', 'the']
# [24] 	 5 8
# Answer: 1615 My answer: ['by', 'England', 'as', 'a']
# [18] 	 5 8
# Answer: 1968 My answer: ['Africa', ',', 'except', 'for']
# [1] 	 5 8
# Answer: 1919 My answer: ['caused', 'by', 'delays', 'to']
# [13] 	 5 8
# Answer: one-fifth My answer: ['held', 'sway', 'over', 'about']
# [4] 	 5 8
# Answer: 14 My answer: ['territories', 'outside', 'the', 'British']
# [15] 	 5 8
# Answer: 1807 My answer: ['abolitionist', 'movement', ',', 'Parliament']
# [] 	 5 8
# Answer: the thirteen colonies My answer: ['exporters', 'of', 'wool', 'and']
# [26, 27, 28] 	 5 8
# Answer: one in seven My answer: ['and', 'unhygienic', 'conditions', 'on']
# [7] 	 5 8
# Answer: 1853 My answer: ['Balkans', 'in', '1853', ',']
# [27] 	 5 8
# Answer: 1813 My answer: ['Parliament', 'were', 'passed', ',']
# [1] 	 5 8
# Answer: 1984 My answer: ['Britain', "'s", 'last', 'remaining']
# [28] 	 5 8
# Answer: 1707 My answer: ['the', '17th', 'and', '18th']
# [1] 	 5 8
# Answer: 1980 My answer: ['Britain', "'s", 'last', 'African']
# [4, 5, 6, 7, 8, 9] 	 5 8
# Answer: a quarter My answer: ['financial', 'disaster', 'for', 'Scotland—a']
# [7] 	 5 8
# Answer: 1688 My answer: ['Revolution', 'of', '1688', 'when']
# [10] 	 5 8
# Answer: 1915 My answer: ['New', 'Zealand', 'troops', 'during']
# [36] 	 5 8
# Answer: 1954 My answer: ['which', 'had', 'been', 'declared']
# [24] 	 5 8
# Answer: 1932 My answer: ['since', '1920', ',', 'also']
# [25] 	 5 8
# Answer: 1916 My answer: ['by', 'Parliament', 'in', '1914']
# [16] 	 5 8
# Answer: 1806 My answer: [',', 'and', 'its', 'large']
# [15] 	 5 8
# Answer: 1807 My answer: ['abolitionist', 'movement', ',', 'Parliament']
# [1] 	 5 8
# Answer: 1583 My answer: ['a', 'second', 'attempt', ',']
# [4] 	 5 8
# Answer: 1951 My answer: ['ANZUS', 'Pact', 'between', 'Australia']
# [23] 	 5 8
# Answer: 1,800,000 My answer: ['concluding', 'Treaty', 'of', 'Versailles']
# [1] 	 5 8
# Answer: 18th My answer: ['(', 'after', '1707', ',']
# [27] 	 5 8
# Answer: 13,000,000 My answer: ['held', 'sway', 'over', 'about']
# [11] 	 5 8
# Answer: 1919 My answer: ['concluding', 'Treaty', 'of', 'Versailles']
# [8] 	 5 8
# Answer: 1997 My answer: ['to', 'China', 'in', '1997']
# [1] 	 5 8
# Answer: 1869 My answer: ['opened', 'under', 'Napoleon', 'III']
# [16] 	 5 8
# Answer: opium My answer: [',', 'the', 'Company', 'had']
# [5] 	 5 8
# Answer: 1605 My answer: ['1605', ')', 'and', 'Grenada']
# [11] 	 5 8
# Answer: 1948 My answer: ['it', 'was', 'called', ',']
# [19] 	 5 8
# Answer: 1756–1763 My answer: ['in', 'India', 'became', 'but']
# [6] 	 5 8
# Answer: 1967 My answer: ['in', '1967', ',', 'Bahrain']
# [10] 	 5 8
# Answer: 1914 My answer: ['with', 'Germany', 'were', 'realised']
# [17, 18, 19, 20] 	 5 8
# Answer: $ us 4.33 billion My answer: [',', 'with', 'insolvency', 'only']
# [39, 40, 41, 42, 43, 44] 	 5 8
# Answer: the `` great game '' My answer: ['Portuguese', 'activity', 'in', 'the']
# [10] 	 5 8
# Answer: 1971 My answer: ['in', '1967', ',', 'Bahrain']
# [9] 	 5 8
# Answer: 1604 My answer: ['colony', 'in', 'Guiana', 'in']
# [12] 	 5 8
# Answer: spice My answer: ['companies', 'was', 'to', 'tap']
# [17] 	 5 8
# Answer: 1652 My answer: ['had', 'founded', 'the', 'Cape']
# [32, 33] 	 5 8
# Answer: 400 million My answer: ['a', 'period', 'referred', 'to']
# [15] 	 5 8
# Answer: 1839 My answer: ['the', 'white', 'colonies', 'of']
# [9, 10] 	 5 8
# Answer: after 1900 My answer: ['similar', 'levels', 'of', 'self-government']
# [5] 	 5 8
# Answer: 1776 My answer: ['1776', ',', 'the', 'United']
# [8] 	 5 8
# Answer: 1914 My answer: ['by', 'Parliament', 'in', '1914']
# [5] 	 5 8
# Answer: 1757 My answer: ['1757', ',', 'in', 'which']
# [31, 32] 	 5 8
# Answer: 13 million My answer: ['concluding', 'Treaty', 'of', 'Versailles']
# [23] 	 5 8
# Answer: 1948 My answer: ['administered', 'as', 'part', 'of']
# [19] 	 5 8
# Answer: 1957 My answer: ['it', 'was', 'called', ',']
# [4] 	 5 8
# Answer: 1966 My answer: ['and', 'the', 'remainder', 'of']
# [11] 	 5 8
# Answer: 1607 My answer: ['in', 'the', 'Americas', 'was']
# [18, 19] 	 5 8
# Answer: two years My answer: ['of', 'New', 'Granada', ',']
# [14] 	 5 8
# Answer: 1937 My answer: ['Britain', 'with', 'the', 'introduction']
# [43] 	 5 8
# Answer: 2006 My answer: [',', 'with', 'insolvency', 'only']
# [5] 	 5 8
# Answer: 1921 My answer: ['1921', 'with', 'a', 'stalemate']
# [15] 	 5 8
# Answer: 1976 My answer: ['in', '1967', ',', 'Bahrain']
# [1] 	 5 8
# Answer: 1695 My answer: ['Parliament', 'granted', 'a', 'charter']
# [1] 	 5 8
# Answer: 1922 My answer: ['held', 'sway', 'over', 'about']
# [8] 	 5 8
# Answer: 1763 My answer: ['of', 'Paris', '(', '1763']
# [18] 	 5 8
# Answer: 1642 My answer: ['also', 'visited', 'New', 'Zealand']
# [12] 	 5 8
# Answer: 1919 My answer: ['India', 'when', 'the', 'Government']
# [4] 	 5 8
# Answer: 1965 My answer: ['Unilateral', 'Declaration', 'of', 'Independence']
# [20] 	 5 8
# Answer: 1698 My answer: ['Parliament', 'granted', 'a', 'charter']
# [11] 	 5 8
# Answer: 1815 My answer: ['a', 'coalition', 'of', 'European']
# [1] 	 5 8
# Answer: 1902 My answer: ['republics', ',', 'concluding', 'a']
# [3] 	 5 8
# Answer: 1707 My answer: ['the', 'Treaty', 'of', 'Union']
# [26] 	 5 8
# Answer: 1947 My answer: ['the', 'problem', ',', 'attacks']
# [15] 	 5 8
# Answer: 1885 My answer: ['1890s', ',', 'and', 'caused']
# [1] 	 5 8
# Answer: 1982 My answer: ['by', 'the', 'British', 'parliament']
# [10] 	 5 8
# Answer: 1783 My answer: ['Colonies', 'in', 'North', 'America']
# [15] 	 5 8
# Answer: 1666 My answer: ['the', 'island', 'of', 'Jamaica']
# [18, 19] 	 5 8
# Answer: 700 million My answer: ['the', 'number', 'of', 'people']
# [5, 6, 7] 	 5 8
# Answer: 1 january 1956 My answer: ['1', 'January', '1956', '.']
# [20] 	 5 8
# Answer: 1923 My answer: ['to', 'set', 'their', 'own']
# [9, 10] 	 5 8
# Answer: after 1900 My answer: ['similar', 'levels', 'of', 'self-government']
# [9] 	 5 8
# Answer: 53 My answer: ['protectorates', 'are', 'among', 'the']
# [24] 	 5 8
# Answer: 1922 My answer: ['with', 'the', 'United', 'States']
# [24] 	 5 8
# Answer: three My answer: ['Netherlands', 'as', 'a', 'colonial']
# [48] 	 5 8
# Answer: 1600 My answer: ['16th', 'century', ',', 'England']
# [21] 	 5 8
# Answer: 1784 My answer: ['Parliament', 'were', 'passed', ',']
# [25, 26] 	 5 8
# Answer: £4 million My answer: ['government', 'of', 'Benjamin', 'Disraeli']
# [10] 	 5 8
# Answer: 17th My answer: ['take', 'shape', 'during', 'the']
# [9] 	 5 8
# Answer: 1926 My answer: ['South', 'Africa', ',', 'the']
# [8] 	 5 8
# Answer: 1778 My answer: ['the', 'war', 'in', '1778']
# [10] 	 5 8
# Answer: 1783 My answer: ['the', 'Peace', 'of', 'Paris']
# [19] 	 5 8
# Answer: 2002 My answer: ['territories', 'outside', 'the', 'British']
# [17, 18] 	 5 8
# Answer: 3.5 million My answer: ['slave', 'trade', 'in', '1807']
# [34] 	 5 8
# Answer: 1787 My answer: [',', 'Cook', "'s", 'botanist']
# [17] 	 5 8
# Answer: 1876 My answer: ['Central', 'Asia', 'for', 'two']
# [8] 	 5 8
# Answer: 1931 My answer: ['substance', 'under', 'the', '1931']
# [12] 	 5 8
# Answer: one-third My answer: ['was', 'a', 'slave', 'state']
# [11, 12] 	 5 8
# Answer: the black mountains My answer: ['lower', 'in', 'the', 'Piedmont']
# [15] 	 5 8
# Answer: laborers My answer: ['had', 'arrived', 'as', 'indentured']
# [5] 	 5 8
# Answer: three My answer: ['three', 'major', 'league', 'sports']
# [17] 	 5 8
# Answer: uplands My answer: ['of', 'eastern', 'and', 'western']
# [29] 	 5 8
# Answer: 1000 My answer: ['the', 'war', 'took', 'place']
# [5, 6] 	 5 8
# Answer: 425 million My answer: ['425', 'million', 'packs', 'of']
# [18, 19] 	 5 8
# Answer: 6,684 feet My answer: ['highest', 'in', 'the', 'eastern']
# [31] 	 5 8
# Answer: increased My answer: ['of', 'northerners', 'and', 'immigrants']
# [3, 4] 	 5 8
# Answer: fall colors My answer: [',', 'freshwater', 'and', 'saltwater']
# [8, 9, 10] 	 5 8
# Answer: the tidewater region My answer: ['state', ',', 'especially', 'the']
# [13, 14] 	 5 8
# Answer: poll taxes My answer: ['passed', 'a', 'new', 'constitution']
# [27, 28, 29] 	 5 8
# Answer: $ 119 million My answer: ['industry', 'generates', '$', '1.2']
# [0] 	 5 8
# Answer: 5 My answer: ['metro', 'areas', 'in', 'the']
# [24] 	 5 8
# Answer: passage My answer: ['had', 'arrived', 'as', 'indentured']
# [29] 	 5 8
# Answer: 1000 My answer: ['the', 'war', 'took', 'place']
# [16] 	 5 8
# Answer: mild My answer: ['plain', 'is', 'influenced', 'by']
# [26] 	 5 8
# Answer: farmers My answer: ['by', 'the', 'Great', 'Depression']
# [8, 9] 	 5 8
# Answer: indentured servants My answer: ['had', 'arrived', 'as', 'indentured']
# [2] 	 5 8
# Answer: two My answer: ['the', 'coast', 'in', 'the']
# [6, 7, 8] 	 5 8
# Answer: eastern coastal plain My answer: ['the', 'eastern', 'coastal', 'plain']
# [10] 	 5 8
# Answer: 18 My answer: ['in', 'North', 'Carolina', ',']
# [7] 	 5 8
# Answer: recreational My answer: ['range', 'of', 'recreational', 'activities']
# [6] 	 5 8
# Answer: 30 My answer: ['exceeds', '30', 'in', '(']
# [2] 	 5 8
# Answer: 1718 My answer: ['aka', 'Edward', 'Teach', ',']
# [13, 14] 	 5 8
# Answer: pork shoulder My answer: ['uses', 'a', 'tomato-based', 'sauce']
# [8] 	 5 8
# Answer: 1718 My answer: [',', 'but', 'by', '1718']
# [4] 	 5 8
# Answer: tobacco My answer: [',', 'and', 'the', 'invention']
# [12] 	 5 8
# Answer: four My answer: ['2nd', 'congressional', 'district', 'elected']
# [15, 16, 17] 	 5 8
# Answer: to get reinforcements My answer: ["''", ',', 'Cornwallis', 'chose']
# [22, 23, 24] 	 5 8
# Answer: 1862 and 1863 My answer: ['were', 'raised', 'in', 'the']
# [14] 	 5 8
# Answer: tobacco My answer: [',', 'the', 'state', 'continued']
# [21] 	 5 8
# Answer: 43,600 My answer: ['industry', 'generates', '$', '1.2']
# [6] 	 5 8
# Answer: occasionally My answer: ['only', 'occasionally', 'drop', 'below']
# [17] 	 5 8
# Answer: west My answer: ['Railroad', 'was', 'created', 'by']
# [20, 21] 	 5 8
# Answer: the board My answer: ['Public', 'Instruction', 'is', 'the']
# [33] 	 5 8
# Answer: 34,000 My answer: [',', 'North', 'Carolina', 'has']
# [18, 19] 	 5 8
# Answer: the appalachian mountains My answer: ['range', 'of', 'recreational', 'activities']
# [16] 	 5 8
# Answer: 1992 My answer: ['Bill', 'Clinton', 'came', 'within']
# [16] 	 5 8
# Answer: 14 My answer: ['utilizing', 'numerous', 'local', 'bike']
# [7] 	 5 8
# Answer: doughnut My answer: ['chain', 'of', 'doughnut', 'stores']
# [7, 8, 9] 	 5 8
# Answer: late 19th century My answer: ['in', 'the', 'late', '19th']
# [29, 30] 	 5 8
# Answer: $ 2.4bn My answer: ['total', 'gross', 'state', 'product']
# [1] 	 5 8
# Answer: 1584 My answer: ['granted', 'a', 'charter', 'to']
# [16, 17] 	 5 8
# Answer: literacy tests My answer: ['passed', 'a', 'new', 'constitution']
# [46] 	 5 8
# Answer: . My answer: ['for', 'the', 'temperature', 'to']
# [30] 	 5 8
# Answer: millions My answer: ['Carolina', 'Museum', 'of', 'Art']
# [6, 7] 	 5 8
# Answer: several million My answer: ['attract', 'several', 'million', 'tourists']
# [11] 	 5 8
# Answer: 1729 My answer: ['of', 'the', 'original', 'province']
# [25, 26, 27] 	 5 8
# Answer: over 25 million My answer: ['and', 'Great', 'Smoky', 'Mountains']
# [7] 	 5 8
# Answer: rose My answer: ['of', 'color', 'rose', 'markedly']
# [17] 	 5 8
# Answer: 1964 My answer: ['voice', 'in', 'the', 'state']
# [33] 	 5 8
# Answer: 1954 My answer: ['the', 'state', 'include', 'Hurricane']
# [25] 	 5 8
# Answer: 1996 My answer: ['Bill', 'Clinton', 'came', 'within']
# [4] 	 5 8
# Answer: 3 My answer: ['percent', 'of', 'the', 'free']
# [24] 	 5 8
# Answer: 1780 My answer: ['the', 'war', 'took', 'place']
# [10, 11, 12] 	 5 8
# Answer: $ 424.9 billion My answer: ['total', 'gross', 'state', 'product']
# [11] 	 5 8
# Answer: 34 My answer: ['utilizing', 'numerous', 'local', 'bike']
# [31] 	 5 8
# Answer: 4 My answer: ['the', 'state', 'include', 'Hurricane']
# [15] 	 5 8
# Answer: 1655 My answer: ['Chowan', 'River', 'and', 'east']
# [] 	 5 8
# Answer: the british cavalry My answer: ['Virginia', 'in', 'April', '1865']
# [3] 	 5 8
# Answer: yeoman My answer: ['in', 'the', 'state', "'s"]
# [3, 4] 	 5 8
# Answer: small farmers My answer: [',', 'sometimes', 'having', 'a']
# [1] 	 5 8
# Answer: weaker My answer: ['Atlantic', 'Ocean', 'also', 'means']
# [16] 	 5 8
# Answer: 7,800 My answer: ['per-capita', 'contribution', 'to', 'the']
# [1] 	 5 8
# Answer: 1996 My answer: [',', 'a', 'private', 'firm']
# [1] 	 5 8
# Answer: 1840 My answer: ['the', 'state', 'capitol', 'building']
# [12] 	 5 8
# Answer: 1540 My answer: ['attested', 'to', 'his', 'meeting']
# [] 	 5 8
# Answer: the hurricanes My answer: ['the', 'state', 'include', 'Hurricane']
# [12] 	 5 8
# Answer: 1976 My answer: ["'s", 'comfortable', 'victory', 'in']
# [5] 	 5 8
# Answer: 1898 My answer: ['1898', 'in', 'New', 'Bern']
# [9, 10, 11] 	 5 8
# Answer: once a decade My answer: ['hurricane', 'hits', 'the', 'state']
# [4] 	 5 8
# Answer: 1776 My answer: [',', 'the', 'colony', 'became']
# [] 	 5 8
# Answer: the constitution My answer: ['passed', 'a', 'new', 'constitution']
# [24] 	 5 8
# Answer: 33 My answer: ['concentrated', 'than', 'in', 'some']
# [1] 	 5 8
# Answer: 1795 My answer: ['opened', 'the', 'first', 'public']
# [22] 	 5 8
# Answer: five My answer: ['Zoo', 'in', 'Asheboro', 'attracts']
# [3, 4, 5] 	 5 8
# Answer: fewer than 20 My answer: ['20', 'tornadoes', 'per', 'year']
# [12, 13, 14] 	 5 8
# Answer: prehistoric indigenous cultures My answer: ['thousands', 'of', 'years', 'by']
# [11] 	 5 8
# Answer: slaves My answer: ['line', 'between', 'indentured', 'servants']
# [1] 	 5 8
# Answer: western My answer: ['state', 'is', 'part', 'of']
# [10] 	 5 8
# Answer: pirates My answer: [',', 'but', 'by', '1718']
# [7, 8, 9] 	 5 8
# Answer: ancient mississippian culture My answer: ['of', 'the', 'ancient', 'Mississippian']
# [1] 	 5 8
# Answer: winter My answer: ['is', 'colder', 'than', 'the']
# [8] 	 5 8
# Answer: 1780–81 My answer: [',', 'especially', 'in', '1780–81']
# -------------------------------------------------------------------
# KeyboardInterrupt                 Traceback (most recent call last)
# <ipython-input-47-1c8961907053> in <module>()
#       1 my_answers = []
#       2 for i,embed_query in enumerate(embed_train_qs):
# ----> 3     start_idx, end_idx = model.predict(training_input[i:i+1])
#       4     start_idx = np.argmax(start_idx)
#       5     end_idx = np.argmax(end_idx)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1833         f = self.predict_function
#    1834         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1835                                   verbose=verbose, steps=steps)
#    1836
#    1837     def train_on_batch(self, x, y,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1325                     ins_batch = _slice_arrays(ins[:-1], batch_ids) + [ins[-1]]
#    1326                 else:
# -> 1327                     ins_batch = _slice_arrays(ins, batch_ids)
#    1328                 for i in indices_for_conversion_to_dense:
#    1329                     ins_batch[i] = ins_batch[i].toarray()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in _slice_arrays(arrays, start, stop)
#     383             if hasattr(start, 'shape'):
#     384                 start = start.tolist()
# --> 385             return [None if x is None else x[start] for x in arrays]
#     386         else:
#     387             return [None if x is None else x[start:stop] for x in arrays]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in <listcomp>(.0)
#     383             if hasattr(start, 'shape'):
#     384                 start = start.tolist()
# --> 385             return [None if x is None else x[start] for x in arrays]
#     386         else:
#     387             return [None if x is None else x[start:stop] for x in arrays]
#
# KeyboardInterrupt:

# %% [markdown]
# <b>model 2 GRU seq2seq</b>

# %%
decoder_input_data = np.zeros(
    (trainig_size, 2, max_context_size),
    dtype='float32')

decoder_target_data = np.zeros(
    (trainig_size, 2, max_context_size),
    dtype='float32')

for i, answer_indices in enumerate(train_answers_indices):
    if len(answer_indices) > 1:
        decoder_input_data[i, 1, answer_indices[0]] = 1.
        decoder_target_data[i, 0, answer_indices[0]] = 1.
        decoder_target_data[i, 1, answer_indices[-1]] = 1.

# %%
qc_relations = Input(shape=(None, max_context_size))
encoder_outputs, encoder_state= GRU(output_dim = max_context_size,
                                    return_state = True,
                                    activation = 'tanh')(qc_relations)

decoder_inputs = Input(shape=(None, max_context_size))
decoder_gru = GRU(output_dim = max_context_size,
                  return_sequences = True,
                  return_state = True,
                  activation = 'tanh')
decoder_outputs, _ = decoder_gru(decoder_inputs,
                                 initial_state = encoder_state)
decoder_dense = Dense(max_context_size,
                      activation='softmax')

start_end = decoder_dense(decoder_outputs)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(return_state=True, activation="tanh", units=382)`
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(return_sequences=True, return_state=True, activation="tanh", units=382)`
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([qc_relations, decoder_inputs], start_end)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy') #optimizer
model.fit([training_input, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)

#define inference model
encoder_model = Model(qc_relations, encoder_state)

decoder_state_inputs = Input(shape=(max_context_size,))
decoder_outputs, decoder_state = decoder_gru(decoder_inputs,
                                             initial_state = decoder_state_inputs)
start_end = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs, decoder_state_inputs],
    [start_end, decoder_state])
# Out:
# Train on 19400 samples, validate on 4850 samples
# Epoch 1/100
# 19400/19400 [==============================] - 121s 6ms/step - loss: 1.5799 - val_loss: 1.2244
# Epoch 2/100
# 19400/19400 [==============================] - 119s 6ms/step - loss: 1.1797 - val_loss: 0.9656
# Epoch 3/100
# 19400/19400 [==============================] - 117s 6ms/step - loss: 1.0375 - val_loss: 0.9333
# Epoch 4/100
# 19400/19400 [==============================] - 115s 6ms/step - loss: 1.0017 - val_loss: 0.9150
# Epoch 5/100
# 19400/19400 [==============================] - 117s 6ms/step - loss: 0.9793 - val_loss: 0.9012
# Epoch 6/100
# 19400/19400 [==============================] - 116s 6ms/step - loss: 0.9618 - val_loss: 0.9115
# Epoch 7/100
# 19400/19400 [==============================] - 120s 6ms/step - loss: 0.9446 - val_loss: 0.9102
# Epoch 8/100
# 19400/19400 [==============================] - 113s 6ms/step - loss: 0.9258 - val_loss: 0.9154
# Epoch 9/100
# 19400/19400 [==============================] - 117s 6ms/step - loss: 0.9056 - val_loss: 0.9254
# Epoch 10/100
# 19400/19400 [==============================] - 118s 6ms/step - loss: 0.8838 - val_loss: 0.9542
# Epoch 11/100
# 19400/19400 [==============================] - 121s 6ms/step - loss: 0.8572 - val_loss: 0.9682
# Epoch 12/100
# 19400/19400 [==============================] - 117s 6ms/step - loss: 0.8302 - val_loss: 0.9785
# Epoch 13/100
# 19400/19400 [==============================] - 115s 6ms/step - loss: 0.7997 - val_loss: 1.0152
# Epoch 14/100
# 19400/19400 [==============================] - 119s 6ms/step - loss: 0.7681 - val_loss: 1.0363
# Epoch 15/100
# 19400/19400 [==============================] - 116s 6ms/step - loss: 0.7367 - val_loss: 1.0624
# Epoch 16/100
# 19400/19400 [==============================] - 112s 6ms/step - loss: 0.7047 - val_loss: 1.1152
# Epoch 17/100
# 19400/19400 [==============================] - 114s 6ms/step - loss: 0.6701 - val_loss: 1.1344
# Epoch 18/100
# 19400/19400 [==============================] - 113s 6ms/step - loss: 0.6365 - val_loss: 1.1918
# Epoch 19/100
# 19400/19400 [==============================] - 114s 6ms/step - loss: 0.5993 - val_loss: 1.2292
# Epoch 20/100
# 19400/19400 [==============================] - 114s 6ms/step - loss: 0.5612 - val_loss: 1.3435
# Epoch 21/100
# 19400/19400 [==============================] - 118s 6ms/step - loss: 0.5293 - val_loss: 1.3670
# Epoch 22/100
# 19400/19400 [==============================] - 117s 6ms/step - loss: 0.4915 - val_loss: 1.4056
# Epoch 23/100
# 19400/19400 [==============================] - 119s 6ms/step - loss: 0.4599 - val_loss: 1.5252
# Epoch 24/100
# 19400/19400 [==============================] - 115s 6ms/step - loss: 0.4332 - val_loss: 1.5290
# Epoch 25/100
# 19400/19400 [==============================] - 119s 6ms/step - loss: 0.4079 - val_loss: 1.5686
# Epoch 26/100
# 19400/19400 [==============================] - 120s 6ms/step - loss: 0.3803 - val_loss: 1.7105
# Epoch 27/100
# 19400/19400 [==============================] - 120s 6ms/step - loss: 0.3503 - val_loss: 1.7216
# Epoch 28/100
# 19400/19400 [==============================] - 116s 6ms/step - loss: 0.3265 - val_loss: 1.7429
# Epoch 29/100
# 19400/19400 [==============================] - 117s 6ms/step - loss: 0.3004 - val_loss: 1.8751
# Epoch 30/100
# 19400/19400 [==============================] - 116s 6ms/step - loss: 0.2786 - val_loss: 1.9173
# Epoch 31/100
# 19400/19400 [==============================] - 115s 6ms/step - loss: 0.2600 - val_loss: 1.9687
# Epoch 32/100
# 19400/19400 [==============================] - 118s 6ms/step - loss: 0.2373 - val_loss: 1.9948
# Epoch 33/100
# 19400/19400 [==============================] - 116s 6ms/step - loss: 0.2254 - val_loss: 2.0726
# Epoch 34/100
# 19400/19400 [==============================] - 115s 6ms/step - loss: 0.2067 - val_loss: 2.1216
# Epoch 35/100
# 19400/19400 [==============================] - 113s 6ms/step - loss: 0.2061 - val_loss: 2.1599
# Epoch 36/100
# 19400/19400 [==============================] - 113s 6ms/step - loss: 0.2044 - val_loss: 2.0894
# Epoch 37/100
# 19400/19400 [==============================] - 121s 6ms/step - loss: 0.1907 - val_loss: 2.1894
# Epoch 38/100
# 19400/19400 [==============================] - 115s 6ms/step - loss: 0.1745 - val_loss: 2.2595
# Epoch 39/100
# 19400/19400 [==============================] - 113s 6ms/step - loss: 0.1637 - val_loss: 2.3114
# Epoch 40/100
# 19400/19400 [==============================] - 115s 6ms/step - loss: 0.1678 - val_loss: 2.2622
# Epoch 41/100
# 19400/19400 [==============================] - 115s 6ms/step - loss: 0.1554 - val_loss: 2.3373
# Epoch 42/100
# 19400/19400 [==============================] - 114s 6ms/step - loss: 0.1415 - val_loss: 2.3643
# Epoch 43/100
# 19400/19400 [==============================] - 116s 6ms/step - loss: 0.1483 - val_loss: 2.3313
# Epoch 44/100
# 19400/19400 [==============================] - 116s 6ms/step - loss: 0.1399 - val_loss: 2.4001
# Epoch 45/100
# 19400/19400 [==============================] - 118s 6ms/step - loss: 0.1335 - val_loss: 2.3892
# Epoch 46/100
# 19400/19400 [==============================] - 116s 6ms/step - loss: 0.1191 - val_loss: 2.4567
# Epoch 47/100
# 19400/19400 [==============================] - 115s 6ms/step - loss: 0.1170 - val_loss: 2.5046
# Epoch 48/100
# 19400/19400 [==============================] - 112s 6ms/step - loss: 0.1135 - val_loss: 2.4989
# Epoch 49/100
# 19400/19400 [==============================] - 110s 6ms/step - loss: 0.1057 - val_loss: 2.5042
# Epoch 50/100
# 19400/19400 [==============================] - 109s 6ms/step - loss: 0.1039 - val_loss: 2.5053
# Epoch 51/100
# 19400/19400 [==============================] - 109s 6ms/step - loss: 0.1004 - val_loss: 2.5434
# Epoch 52/100
# 19400/19400 [==============================] - 109s 6ms/step - loss: 0.0929 - val_loss: 2.5395
# Epoch 53/100
# 19400/19400 [==============================] - 108s 6ms/step - loss: 0.0922 - val_loss: 2.6236
# Epoch 54/100
# 19400/19400 [==============================] - 109s 6ms/step - loss: 0.0884 - val_loss: 2.5781
# Epoch 55/100
# 19400/19400 [==============================] - 110s 6ms/step - loss: 0.0816 - val_loss: 2.6048
# Epoch 56/100
# 19400/19400 [==============================] - 116s 6ms/step - loss: 0.0845 - val_loss: 2.6535
# Epoch 57/100
#  3328/19400 [====>.........................] - ETA: 1:23 - loss: 0.0691

# %%
def get_start_end(question):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(question)

    # Generate empty target sequence of length 1.
    Go_index = np.zeros((1, 1, max_context_size))
    
    start_index , states_value = decoder_model.predict( [Go_index, states_value])
    end_index, _ = decoder_model.predict( [start_index, states_value])

    return start_index, end_index

# %%
my_answers = []
for i,embed_query in enumerate(embed_train_qs):
    start_idx, end_idx = get_start_end(training_input[i:i+1])
    start_idx = np.argmax(start_idx)
    end_idx = np.argmax(end_idx)
    print(train_answers_indices[i], "\t", start_idx, end_idx)
    print("Answer:", train_answers[i], "My answer:", tokenized_train_context[i][start_idx:end_idx+1])
# Out:
# [31] 	 5 9
# Answer: cylinder My answer: ['the', 'list', 'for', 'redefinition', 'is']
# [3, 4, 5] 	 6 7
# Answer: time vs. energy My answer: ['.']
# [15, 16, 17] 	 5 9
# Answer: quantum of action My answer: ['some', 'multiple', 'of', 'a', 'very']
# [11] 	 5 9
# Answer: 1913 My answer: ['quantized', 'model', 'of', 'the', 'atom']
# [7] 	 5 9
# Answer: h My answer: ['existence', 'of', 'h', '(', 'but']
# [7] 	 5 9
# Answer: h My answer: ['existence', 'of', 'h', '(', 'but']
# [42] 	 1 8
# Answer: f My answer: ['recognized', 'in', '1900', 'by', 'Max', 'Planck', ',', 'it']
# [9] 	 5 9
# Answer: 1839 My answer: ['Alexandre', 'Edmond', 'Becquerel', 'in', '1839']
# [19] 	 5 9
# Answer: 1911 My answer: ['as', 'the', '``', 'ultraviolet', 'catastrophe']
# [78, 79] 	 1 8
# Answer: multiphoton effect My answer: ['kinetic', 'energy', '(', 'for', 'each', 'photoelectron', ')', 'is']
# [5, 6] 	 5 9
# Answer: nuclear magneton My answer: ['nuclear', 'magneton', 'are', 'units', 'which']
# [9, 10] 	 5 9
# Answer: 555 nanometres My answer: ['with', 'a', 'wavelength', 'of', '555']
# [6] 	 5 9
# Answer: 1911 My answer: ['in', '1911', 'was', 'devoted', 'to']
# [22, 23] 	 5 9
# Answer: hot atoms My answer: ['of', 'motion', 'similarly', 'to', 'a']
# [6] 	 5 9
# Answer: thermal My answer: ['is', 'thermal', 'leads', 'to', 'an']
# [23] 	 5 9
# Answer: quantum My answer: [',', 'the', 'minimal', 'energy', 'increment']
# [32] 	 5 9
# Answer: forbidden My answer: ['as', 'for', 'monochromatic', 'light', 'or']
# [23] 	 5 9
# Answer: particles My answer: ['the', 'Planck', 'constant', 'reflects', 'the']
# [17, 18] 	 5 8
# Answer: a wave My answer: [',', 'electromagnetic', 'radiation', 'such']
# [3] 	 5 9
# Answer: green My answer: ['with', 'a', 'wavelength', 'of', '555']
# [7] 	 5 9
# Answer: colour My answer: ['that', 'the', 'colour', 'of', 'the']
# [6, 7, 8, 9, 10] 	 5 9
# Answer: the `` ultraviolet catastrophe '' My answer: ['as', 'the', '``', 'ultraviolet', 'catastrophe']
# [] 	 5 9
# Answer: the kilogram My answer: ['of', 'micrograms', 'in', 'one', 'kilogram']
# [13] 	 5 9
# Answer: intensity My answer: ['wave', 'in', 'a', 'given', 'time']
# [31, 32] 	 5 8
# Answer: watt-balance measurement My answer: ['is', 'based', 'on', 'three']
# [25, 26, 27] 	 5 9
# Answer: a circular argument My answer: ['of', 'the', 'Planck', 'constant', 'obtained']
# [21, 22] 	 1 8
# Answer: the frequency My answer: ['kinetic', 'energy', '(', 'for', 'each', 'photoelectron', ')', 'is']
# [] 	 5 9
# Answer: the light quantum My answer: [',', 'the', 'minimal', 'energy', 'increment']
# [] 	 33 8
# Answer: time vs. energy My answer: []
# [5] 	 5 9
# Answer: sound My answer: ['sound', 'or', 'the', 'waves', 'crashing']
# [18] 	 5 9
# Answer: thermal My answer: [',', 'meaning', 'it', 'absorbs', 'all']
# [12, 13] 	 5 9
# Answer: physical action My answer: ["'s", 'discovery', ',', 'it', 'was']
# [4, 5, 6] 	 5 9
# Answer: laws of motion My answer: ['of', 'motion', 'similarly', 'to', 'a']
# [9, 10] 	 5 9
# Answer: 555 nanometres My answer: ['with', 'a', 'wavelength', 'of', '555']
# [16] 	 1 8
# Answer: relativity My answer: ['Nobel', 'committee', 'awarded', 'the', 'prize', 'for', 'his', 'work']
# [3, 4] 	 5 9
# Answer: the quantity My answer: [',', 'now', 'known', 'as', 'the']
# [4] 	 5 9
# Answer: 1918 My answer: ['Nobel', 'Prize', 'in', 'Physics', '``']
# [15] 	 5 9
# Answer: black-body My answer: ['the', 'nineteenth', 'century', ',', 'Planck']
# [26] 	 5 9
# Answer: h My answer: [',', 'which', 'correctly', 'predicts', 'blackbody']
# [15, 16, 17] 	 5 9
# Answer: quantum of action My answer: ['some', 'multiple', 'of', 'a', 'very']
# [33] 	 5 9
# Answer: platinum–iridium My answer: ['the', 'list', 'for', 'redefinition', 'is']
# [9, 10] 	 5 9
# Answer: blackbody emissions My answer: [',', 'which', 'correctly', 'predicts', 'blackbody']
# [30] 	 5 8
# Answer: 2007 My answer: ['is', 'based', 'on', 'three']
# [18, 19, 20] 	 5 9
# Answer: thermal light emission My answer: [',', 'meaning', 'it', 'absorbs', 'all']
# [25, 26] 	 5 9
# Answer: white hot My answer: ['that', 'the', 'colour', 'of', 'the']
# [15, 16] 	 5 9
# Answer: black-body radiation My answer: ['the', 'nineteenth', 'century', ',', 'Planck']
# [13] 	 5 8
# Answer: intensity My answer: ['wave', 'in', 'a', 'given']
# [19] 	 5 9
# Answer: 1921 My answer: ['the', 'effect', 'in', 'terms', 'of']
# [2, 3, 4] 	 5 9
# Answer: the energy account My answer: ['of', 'the', 'photoelectric', 'effect', 'did']
# [1] 	 5 9
# Answer: 1905 My answer: [',', 'the', 'minimal', 'energy', 'increment']
# [17, 18] 	 5 8
# Answer: a wave My answer: [',', 'electromagnetic', 'radiation', 'such']
# [22] 	 5 9
# Answer: forty My answer: ['the', 'nineteenth', 'century', ',', 'Planck']
# [6] 	 5 9
# Answer: 1911 My answer: ['in', '1911', 'was', 'devoted', 'to']
# [6] 	 5 9
# Answer: light My answer: ['with', 'light', 'absorbs', 'just', 'as']
# [11] 	 5 9
# Answer: hotter My answer: ['hot', 'objects', 'glow', ',', 'and']
# [10] 	 5 9
# Answer: accurate My answer: ['is', 'thermal', 'leads', 'to', 'an']
# [22] 	 5 9
# Answer: silicon My answer: ['Si', ')', 'requires', 'a', 'knowledge']
# [30, 31, 32] 	 5 9
# Answer: the stefan–boltzmann law My answer: ['is', 'thermal', 'leads', 'to', 'an']
# [20, 21, 22] 	 5 9
# Answer: renewable energy technologies My answer: ['Change', 'has', 'said', 'that', 'there']
# [5] 	 5 9
# Answer: 2006 My answer: ['2006', 'pushed', 'renewable', 'energy', 'up']
# [8, 9, 10] 	 5 9
# Answer: $ 140.4 billion My answer: ['in', '2012', 'was', '$', '140.4']
# [26, 27] 	 5 8
# Answer: global warming My answer: ['%', 'renewable', 'energy', ',']
# [3] 	 5 9
# Answer: three My answer: ['plants', 'larger', 'than', '10', 'GW']
# [24] 	 5 8
# Answer: half My answer: ['``', 'Photovoltaic', 'and', 'solar-thermal']
# [12, 13, 14] 	 5 8
# Answer: renewable energy policy My answer: ['can', 'be', 'an', 'important']
# [5, 6] 	 6 7
# Answer: 58 percent My answer: ['percent', ',']
# [8, 9] 	 5 9
# Answer: 18.1 percent My answer: ['2012', 'increased', 'by', '18.1', 'percent']
# [16, 17] 	 5 9
# Answer: 22 percent My answer: ['report', ',', 'renewables', 'contributed', '19']
# [5] 	 6 7
# Answer: renewables My answer: ['exceeded', 'fossils']
# [] 	 5 9
# Answer: tax shifting My answer: ['already', 'shifting', 'taxes', 'in', 'a']
# [5, 6] 	 5 9
# Answer: 19 % My answer: ['19', '%', 'of', 'electricity', 'generated']
# [13, 14, 15] 	 5 9
# Answer: social and political My answer: ['energy', 'plan', 'are', 'seen', 'to']
# [21] 	 5 8
# Answer: 2060 My answer: ['``', 'Photovoltaic', 'and', 'solar-thermal']
# [13, 14] 	 5 9
# Answer: 10 percent My answer: ['in', 'the', 'United', 'States', 'today']
# [3] 	 5 9
# Answer: hydroelectricity My answer: ['low', ',', 'making', 'it', 'a']
# [] 	 5 9
# Answer: renewable energy commercialization My answer: ['deployment', 'of', 'three', 'generations', 'of']
# [3] 	 6 7
# Answer: 144 My answer: ['renewable', 'energy']
# [9, 10] 	 5 9
# Answer: 19 percent My answer: ['report', ',', 'renewables', 'contributed', '19']
# [22] 	 5 9
# Answer: coal My answer: ['reducing', 'climate', 'disrupting', 'subsidies', 'and']
# [2] 	 5 9
# Answer: 2011 My answer: [']', ',', 'there', 'have', 'been']
# [10] 	 6 7
# Answer: 2008 My answer: ['in', 'module']
# [4, 5] 	 5 9
# Answer: renewable energy My answer: ['energy', 'accounts', 'for', 'about', 'half']
# [3] 	 5 9
# Answer: hydroelectricity My answer: ['low', ',', 'making', 'it', 'a']
# [13, 14] 	 5 9
# Answer: 9 % My answer: ['19', '%', 'of', 'electricity', 'generated']
# [10, 11] 	 5 9
# Answer: renewable energy My answer: ['Ki-moon', 'has', 'said', 'that', '``']
# [26, 27] 	 5 8
# Answer: 17 percent My answer: ['power', 'accounts', 'for', 'a']
# [8, 9, 10] 	 5 9
# Answer: $ 244 billion My answer: ['in', '2012', 'was', '$', '140.4']
# [13, 14] 	 5 9
# Answer: market expansion My answer: ['the', 'main', 'driver', 'of', 'reduced']
# [7] 	 6 7
# Answer: 2030 My answer: ['by', '2030']
# [4] 	 5 9
# Answer: 150 My answer: ['countries', ',', 'with', 'the', 'Asia-Pacific']
# [4, 5, 6, 7] 	 5 9
# Answer: renewable technologies My answer: ['power', 'generation', 'technologies', 'accounted', 'for']
# [1, 2, 3, 4] 	 5 9
# Answer: $ 1.00/w installed cost My answer: [',', 'is', 'often', 'regarded', 'in']
# [36] 	 5 8
# Answer: 2030 My answer: ['of', 'civil', 'and', 'environmental']
# [] 	 5 9
# Answer: energy regulators My answer: ['to', 'carry', 'out', 'a', 'number']
# [4, 5] 	 5 9
# Answer: renewable energy My answer: ['energy', 'accounts', 'for', 'about', 'half']
# [4, 5] 	 5 9
# Answer: renewable energy My answer: ['energy', 'plays', 'a', 'major', 'role']
# [1] 	 5 9
# Answer: 1958 My answer: ['a', 'Boy', 'Scout', 'and', 'fulfilled']
# [8] 	 5 9
# Answer: 1997 My answer: ['producer', 'for', 'the', '1997', 'film']
# [9] 	 5 9
# Answer: 1995 My answer: ['from', 'that', 'time', 'until', '1995']
# [1, 2] 	 5 9
# Answer: vice president My answer: ['was', 'impressed', 'by', 'the', 'film']
# [1] 	 5 8
# Answer: 1997 My answer: ['Film', 'Institute', 'listed', 'it']
# [27] 	 5 9
# Answer: 1,100 My answer: ['Schindler', "'s", 'List', ',', 'was']
# [9] 	 5 8
# Answer: 2005 My answer: ['Fame', 'inducted', 'Spielberg', 'in']
# [14] 	 5 9
# Answer: intrusive My answer: ['use', 'of', 'cut', 'scenes', 'in']
# [10] 	 5 9
# Answer: 1993 My answer: [',', 'and', 'Jurassic', 'Park', '(']
# [2] 	 5 9
# Answer: 1984 My answer: ['their', 'romance', ',', 'and', 'in']
# [11, 12, 13] 	 5 8
# Answer: $ 200 million My answer: ['box', 'office', 'success', ',']
# [18, 19] 	 5 9
# Answer: # 9 My answer: ['Film', 'Institute', 'listed', 'it', 'among']
# [6] 	 5 9
# Answer: 1989 My answer: ['the', '1989', 'National', 'Scout', 'Jamboree']
# [8] 	 5 9
# Answer: 1979 My answer: ['broke', 'up', 'in', '1979', ',']
# [21, 22] 	 5 8
# Answer: the 1930s My answer: ['began', 'opening', 'to', 'Western']
# [13, 14] 	 5 9
# Answer: his father My answer: ['$', '500', ',', 'most', 'of']
# [31, 32] 	 5 9
# Answer: his father My answer: ['most', 'autobiographical', 'aspect', 'of', 'Spielberg']
# [2] 	 5 9
# Answer: 1984 My answer: ['their', 'romance', ',', 'and', 'in']
# [13, 14] 	 5 9
# Answer: 15–20 years My answer: ['global', 'human', 'war', 'against', 'a']
# [17] 	 5 9
# Answer: two My answer: ['on', 'the', 'critically', 'acclaimed', '2005']
# [4] 	 6 7
# Answer: co-producer My answer: ['the', '1987']
# [2] 	 5 9
# Answer: five My answer: ['nominations', ',', 'including', 'Best', 'Picture']
# [16] 	 5 9
# Answer: 26-minute My answer: ['opportunity', 'to', 'make', 'a', 'short']
# [13] 	 5 9
# Answer: actress My answer: ['that', 'Spielberg', 'also', 'met', 'his']
# [13] 	 5 9
# Answer: four My answer: ['his', 'work', ',', 'Universal', 'signed']
# [23] 	 5 9
# Answer: seven-year My answer: ['was', 'impressed', 'by', 'the', 'film']
# [18] 	 5 9
# Answer: 1989 My answer: ['serious', 'dramatic', 'films', ',', 'Spielberg']
# [20] 	 5 9
# Answer: cinematography My answer: ['in', 'Scouting', ',', 'Spielberg', 'helped']
# [13] 	 5 9
# Answer: four My answer: ['his', 'work', ',', 'Universal', 'signed']
# [7] 	 5 9
# Answer: poorly My answer: ['film', 'fared', 'poorly', 'at', 'the']
# [23] 	 5 9
# Answer: 1996 My answer: ['publishers', 'Knowledge', 'Adventure', 'on', 'the']
# [24] 	 5 9
# Answer: 1980 My answer: ['Encounters', 'project', 'and', ',', 'with']
# [13] 	 5 9
# Answer: six My answer: ['reviews', 'from', 'critics', ',', 'and']
# [18] 	 1 8
# Answer: 1982 My answer: ['film', ',', 'based', 'on', 'the', 'novel', 'of', 'the']
# [15, 16, 17] 	 5 9
# Answer: reportedly close friends My answer: [',', "''", 'starred', 'Joan', 'Crawford']
# [50] 	 5 8
# Answer: terrorism My answer: ['films', 'began', 'addressing', 'humanistic']
# [10] 	 5 9
# Answer: 1981 My answer: ['at', 'the', 'box', 'office', 'in']
# [18] 	 5 9
# Answer: editing My answer: ['he', 'was', 'offered', 'a', 'small']
# [6] 	 5 9
# Answer: impressed My answer: ['was', 'impressed', 'by', 'the', 'film']
# [9] 	 5 9
# Answer: 2005 My answer: ['on', 'the', 'critically', 'acclaimed', '2005']
# [7, 8, 9, 10] 	 5 9
# Answer: exceeds $ 9 billion My answer: ['Spielberg-directed', 'films', 'exceeds', '$', '9']
# [1] 	 5 9
# Answer: two My answer: ['serious', 'dramatic', 'films', ',', 'Spielberg']
# [25] 	 5 9
# Answer: 1989 My answer: ['years', 'of', 'marriage', ',', 'however']
# [7] 	 5 9
# Answer: 1974 My answer: ['Jaws', 'in', '1974', ',', 'Spielberg']
# [26] 	 5 8
# Answer: three My answer: ['Best', 'Production', 'Design', 'and']
# [3] 	 6 7
# Answer: eleven My answer: ['nominations', ',']
# [2, 3] 	 5 9
# Answer: science fiction My answer: ['impressed', 'Universal', 'Studios', 'and', 'they']
# [3] 	 5 9
# Answer: actress My answer: ['Irving', 'in', '1976', 'at', 'the']
# [4] 	 5 9
# Answer: two My answer: ['categories', '(', 'Cinematography', ',', 'Vilmos']
# [6] 	 6 7
# Answer: 1975 My answer: ['1975', ')']
# [] 	 5 8
# Answer: `` bachelor funky '' My answer: ['E-Poll', 'Market', 'Research', ',']
# [1] 	 5 9
# Answer: two My answer: ['serious', 'dramatic', 'films', ',', 'Spielberg']
# [24] 	 5 9
# Answer: 1994 My answer: ['own', 'directorial', 'copy', 'of', 'the']
# [18] 	 5 9
# Answer: 1969 My answer: ['came', 'when', 'he', 'was', 'hired']
# [47] 	 5 8
# Answer: 1953 My answer: ['directed', 'a', 'modern', 'adaptation']
# [38] 	 5 8
# Answer: 2054 My answer: ['collaborated', 'for', 'the', 'first']
# [21] 	 5 9
# Answer: 1938 My answer: ['own', 'directorial', 'copy', 'of', 'the']
# [7, 8, 9] 	 5 9
# Answer: $ 250 million My answer: ['have', 'cost', '$', '250', 'million']
# [7] 	 5 9
# Answer: 2014 My answer: ['Influential', 'Celebrities', '2014', 'list', ',']
# [6] 	 5 9
# Answer: 2149 My answer: ['year', '2149', 'when', 'all', 'life']
# [5, 6] 	 5 9
# Answer: $ 500 My answer: ['$', '500', ',', 'most', 'of']
# [8, 9] 	 1 8
# Answer: during childhood My answer: ['described', 'himself', 'as', 'feeling', 'like', 'an', 'alien', 'during']
# [36] 	 5 8
# Answer: six My answer: ['both', 'written', 'and', 'directed']
# [64] 	 33 8
# Answer: 1999 My answer: []
# [25] 	 5 9
# Answer: 2018 My answer: ['early', '2017', 'for', 'release', 'at']
# [26] 	 5 8
# Answer: three My answer: ['Best', 'Production', 'Design', 'and']
# [8, 9, 10, 11] 	 5 9
# Answer: $ 470 million worldwide My answer: ['Spielberg-directed', 'films', 'exceeds', '$', '9']
# [15, 16] 	 5 9
# Answer: 92 % My answer: ['with', 'the', 'review', 'tallying', 'website']
# [30, 31, 32] 	 5 9
# Answer: 85 million years My answer: ['year', '2149', 'when', 'all', 'life']
# [33] 	 5 8
# Answer: embarrassed My answer: ['I', 'enjoy', 'admitting', ',']
# [2] 	 5 9
# Answer: 2010 My answer: ['Pacific', 'he', 'teamed', 'up', 'once']
# [45] 	 5 8
# Answer: 2009 My answer: ['honored', 'with', 'the', 'Cecil']
# [13] 	 5 8
# Answer: three My answer: ['Best', 'Picture', 'and', 'featured']
# [2] 	 5 9
# Answer: thirteen My answer: ['living', 'in', 'Phoenix', ',', 'Spielberg']
# [15] 	 5 9
# Answer: 40-minute My answer: ['living', 'in', 'Phoenix', ',', 'Spielberg']
# [12] 	 1 8
# Answer: 1858 My answer: ['book', 'follows', 'the', 'true', 'story', 'of', 'a', 'young']
# [11] 	 5 9
# Answer: 2001 My answer: ['a', 'moderate', 'success', ',', 'while']
# [1] 	 5 9
# Answer: 2002 My answer: ['one', 'of', 'eight', 'flagbearers', 'who']
# [8, 9] 	 5 9
# Answer: 47 % My answer: ['47', ',', 'meaning', '47', '%']
# [33, 34] 	 5 8
# Answer: electrical engineer My answer: ['Adler', ')', 'Posner', '(']
# [14, 15] 	 5 9
# Answer: a headteacher My answer: ['Indiana', 'Jones', ',', 'Spielberg', 'also']
# [23, 24, 25] 	 5 9
# Answer: as a child My answer: ['most', 'autobiographical', 'aspect', 'of', 'Spielberg']
# [16] 	 5 9
# Answer: 1941 My answer: [',', 'Spielberg', 'purchased', 'a', 'balsa']
# [21] 	 5 9
# Answer: guns My answer: ['the', 'missile', 'found', 'itself', 'being']
# [23] 	 5 8
# Answer: 1950s My answer: ['have', 'for', 'the', 'most']
# [35, 36] 	 1 8
# Answer: anti-aircraft artillery My answer: ['Germans', 'developed', 'massive', 'reinforced', 'concrete', 'blockhouses', ',', 'some']
# [10, 11] 	 5 9
# Answer: the railgun My answer: ['weapons', 'may', 'be', 'found', 'in']
# [17, 18] 	 5 9
# Answer: machine guns My answer: [',', 'at', 'RAF', 'insistence', ',']
# [36, 37, 38] 	 1 8
# Answer: the late 1960s My answer: ['number', 'of', 'jet', 'interceptors', 'such', 'as', 'the', 'F-102']
# [13] 	 5 9
# Answer: mechanical My answer: ['(', 'based', 'on', 'a', 'burning']
# [18, 19, 20] 	 5 9
# Answer: self-propelled anti-aircraft guns My answer: ['regiment-level', 'and', 'consist', 'of', 'platoons']
# [12] 	 6 7
# Answer: 1918 My answer: ['HAA', 'gun']
# [43, 44, 45] 	 5 8
# Answer: 90 km away My answer: ['a', 'claimed', 'ability', 'to']
# [3, 4] 	 5 9
# Answer: air defence My answer: ['in', 'depth', ',', 'from', 'integral']
# [4, 5] 	 1 8
# Answer: air defence My answer: ['the', '20th', 'century', 'air', 'defence', 'was', 'one', 'of']
# [11, 12] 	 6 7
# Answer: non-ballistic factors My answer: ['AA', 'guns']
# [5, 6, 7] 	 5 9
# Answer: for anti-aircraft fire My answer: ['for', 'anti-aircraft', 'fire', ',', 'it']
# [1] 	 6 8
# Answer: 3-inch My answer: ['the', 'end', 'of']
# [12, 13] 	 5 8
# Answer: aimed fire My answer: ['approach', 'to', 'HAA', 'fire']
# [14, 15] 	 5 9
# Answer: the backblast My answer: ['angles', 'poses', 'a', 'danger', 'to']
# [10] 	 5 9
# Answer: 1925 My answer: ['volunteer', 'Observer', 'Corps', 'formed', 'in']
# [5] 	 5 9
# Answer: 183 My answer: ['183', 'AA', 'Sections', 'defending', 'Britain']
# [26] 	 1 8
# Answer: four My answer: ['needs', 'could', 'cogently', 'be', 'met', 'with', 'smaller-calibre', 'ordnance']
# [3, 4, 5] 	 5 9
# Answer: solid fuel rockets My answer: ['rockets', 'were', 'under', 'development', 'in']
# [9, 10] 	 5 8
# Answer: homeland defence My answer: ['defence', 'may', 'be', 'for']
# [8, 9] 	 6 7
# Answer: 24,000 feet My answer: ['up', 'to']
# [1] 	 6 8
# Answer: radar My answer: ['surveillance', 'to', 'detect']
# [12, 13] 	 5 9
# Answer: guided missiles My answer: ['ballistic', 'munitions', 'were', 'the', 'standard']
# [23] 	 5 8
# Answer: 125 My answer: ['was', 'a', 'bit', 'light']
# [41] 	 5 8
# Answer: permanently My answer: ['to', 'destroy', ';', 'nonetheless']
# [21] 	 1 8
# Answer: aircraft My answer: ['the', '20th', 'century', 'air', 'defence', 'was', 'one', 'of']
# [10, 11] 	 5 9
# Answer: the kerrison predictor My answer: ['operators', 'tracked', 'the', 'target', 'and']
# [28] 	 5 9
# Answer: 1925 My answer: ['probably', 'first', 'used', 'by', 'Britain']
# [24] 	 5 8
# Answer: bombers My answer: ['simply', 'interceptor', ')', 'is']
# [10, 11, 12] 	 5 9
# Answer: 2 to 12 My answer: ['is', 'typically', 'a', 'battery', 'with']
# [9, 10] 	 5 9
# Answer: elevation angle My answer: ['the', 'target', 'and', 'the', 'elevation']
# [6] 	 6 7
# Answer: 1940 My answer: ['1940', '.']
# [2] 	 5 9
# Answer: altitude My answer: ['jet', 'aircraft', 'limit', 'target', 'opportunities']
# [32] 	 5 9
# Answer: 1954 My answer: ['arms', ',', 'PVO', 'Strany', ',']
# [3, 4, 5, 6] 	 1 8
# Answer: `` effective ceiling '' My answer: ['British', 'adopted', '``', 'effective', 'ceiling', "''", ',', 'meaning']
# [19, 20, 21] 	 1 8
# Answer: 8 july 1914 My answer: ['British', 'recognised', 'the', 'need', 'for', 'anti-aircraft', 'capability', 'a']
# [33, 34] 	 5 8
# Answer: its height My answer: ['approach', 'to', 'HAA', 'fire']
# [27, 28] 	 5 9
# Answer: experimental usefulness My answer: ['lasers', 'in', 'combat', 'since', 'the']
# [8, 9] 	 5 9
# Answer: 18-pdr guns My answer: ['the', 'war', 'but', '18-pdr', 'guns']
# [4, 5] 	 6 7
# Answer: into battalions My answer: ['or', 'equivalent']
# [27, 28, 29] 	 5 8
# Answer: for 20 seconds My answer: ['British', 'definition', 'was', '``']
# [22, 23, 24, 25] 	 1 8
# Answer: the carrier 's escorts My answer: ['an', 'attacker', 'is', 'able', 'to', 'penetrate', 'this', 'layer']
# [5] 	 5 9
# Answer: missiles My answer: ['missiles', 'will', 'replace', 'gun', 'systems']
# [2, 3] 	 5 9
# Answer: the maximum distance My answer: ['the', 'target', 'and', 'the', 'elevation']
# [] 	 5 9
# Answer: the gun My answer: ['to', 'the', 'British', 'war', 'effort']
# [7, 8, 9] 	 5 9
# Answer: three aa corps My answer: ['it', 'comprised', 'three', 'AA', 'corps']
# [21] 	 5 9
# Answer: 1943 My answer: ['these', 'devices', 'during', 'an', 'air']
# [7, 8, 9] 	 5 9
# Answer: a steel plate My answer: ['sometimes', 'welded', 'a', 'steel', 'plate']
# [25, 26] 	 1 8
# Answer: slide rules My answer: ['long', 'range', ',', 'the', 'aircraft', 'remains', 'in', 'firing']
# [7] 	 5 9
# Answer: shrapnel My answer: [')', 'and', 'shrapnel', 'were', 'used']
# [18, 19] 	 5 9
# Answer: smallest mounts My answer: ['caliber', 'or', 'even', '8', 'mm']
# [3] 	 1 8
# Answer: 1924 My answer: [',', 'in', '1924', 'work', 'started', 'on', 'a', 'new']
# [7] 	 5 9
# Answer: searchlights My answer: ['night', ',', 'searchlights', 'were', 'soon']
# [9, 10] 	 5 9
# Answer: barrage balloons My answer: ['was', 'the', 'use', 'of', 'barrage']
# [1] 	 5 9
# Answer: 2-inch My answer: ['or', 'wire', 'obstacle', 'warheads', 'was']
# [17, 18, 19] 	 1 8
# Answer: `` archibald , certainly not ! '' My answer: ['for', 'anti-aircraft', 'guns', 'include', 'AA', ',', 'AAA', 'or']
# [30, 31] 	 5 8
# Answer: fighter jets My answer: ['well', 'defended', ',', 'as']
# [7, 8, 9] 	 5 9
# Answer: detect hostile aircraft My answer: ['is', 'to', 'detect', 'hostile', 'aircraft']
# [9] 	 5 9
# Answer: minimal My answer: ['application', ',', 'and', 'had', 'minimal']
# [4, 5] 	 5 9
# Answer: guided missile My answer: ['missile', 'resulted', 'in', 'a', 'significant']
# [31, 32] 	 1 8
# Answer: guided missiles My answer: ['the', '20th', 'century', 'air', 'defence', 'was', 'one', 'of']
# [4, 5] 	 6 8
# Answer: important buildings My answer: ['were', 'common', 'in']
# [14] 	 5 9
# Answer: 1950s My answer: ['mm', 'guns', 'would', 'continue', 'to']
# [23, 24] 	 1 8
# Answer: the u.s. army My answer: ['is', 'in', 'contrast', 'to', 'some', '(', 'largely', 'communist']
# [6, 7] 	 1 8
# Answer: maximum ceiling My answer: ['term', 'is', "'ceiling", "'", ',', 'maximum', 'ceiling', 'being']
# [9] 	 6 7
# Answer: .50-inch My answer: ['anything', 'larger']
# [25, 26, 27, 28, 29] 	 5 9
# Answer: `` flaktürme '' flak towers My answer: ['concrete', 'blockhouses', ',', 'some', 'more']
# [9, 10] 	 5 8
# Answer: homeland air defence My answer: ['defence', 'may', 'be', 'for']
# [1] 	 6 7
# Answer: 1925 My answer: ['new', 'instrument']
# [8, 9] 	 6 7
# Answer: the laser My answer: ['use', 'is']
# [38] 	 5 9
# Answer: 1990 My answer: ['for', 'instance', ',', 'air', 'defence']
# [6, 7, 8] 	 5 8
# Answer: machine-gun based weapons My answer: ['various', 'machine-gun', 'based', 'weapons']
# [4] 	 5 9
# Answer: eight My answer: ['countries', 'developed', 'radar', ',', 'these']
# [1] 	 5 9
# Answer: 1928 My answer: ['preferred', 'solution', ',', 'but', 'it']
# [11, 12] 	 5 9
# Answer: destroy them My answer: ['is', 'to', 'detect', 'hostile', 'aircraft']
# [30, 31] 	 5 8
# Answer: 60,000 ft My answer: ['at', 'the', 'start', 'of']
# [21, 22, 23] 	 5 9
# Answer: 30-second running time My answer: ['both', '3.7', 'and', '4.5-in', 'guns']
# [11, 12, 13] 	 5 9
# Answer: speed and height My answer: ['would', 'maintain', 'a', 'steady', 'course']
# [17] 	 5 9
# Answer: 74 My answer: ['183', 'AA', 'Sections', 'defending', 'Britain']
# [20, 21] 	 5 9
# Answer: lighter weapons My answer: ['been', 'set', ':', 'anti-aircraft', 'weapons']
# [25, 26] 	 5 9
# Answer: predicted trajectory My answer: ['aiming', 'a', 'shell', 'to', 'burst']
# [9, 10] 	 6 7
# Answer: anti-stealth technology My answer: [',', 'so']
# [14, 15] 	 5 9
# Answer: a movie My answer: ['to', 'the', 'British', 'war', 'effort']
# [1, 2, 3] 	 5 9
# Answer: 30 september 1915 My answer: ['troops', 'of', 'the', 'Serbian', 'Army']
# [15] 	 5 9
# Answer: aéronef My answer: ['is', 'called', 'DCA', '(', 'Défense']
# [17] 	 5 9
# Answer: 2004 My answer: ['defence', 'was', 'removed', 'from', 'Royal']
# [18, 19, 20] 	 5 9
# Answer: fire control elements My answer: ['is', 'typically', 'a', 'battery', 'with']
# [7] 	 6 7
# Answer: mobile My answer: ['fairly', 'mobile']
# [7, 8, 9] 	 6 7
# Answer: 2020 to 2025 My answer: ['in', '2020']
# [7] 	 6 7
# Answer: zenitnye My answer: ['called', 'zenitnye']
# [3, 4, 5] 	 6 7
# Answer: a 3.7 cm My answer: ['.']
# [9, 10] 	 5 9
# Answer: air-search radar My answer: ['usually', 'be', 'acquired', 'by', 'air-search']
# [14] 	 5 9
# Answer: autocannons My answer: ['and', 'relatively', 'cheap', 'short-range', 'missiles']
# [13, 14] 	 5 9
# Answer: the 1960s My answer: ['they', 'are', 'known', 'today', ',']
# [5] 	 5 9
# Answer: 1943 My answer: ['1943', 'an', 'entirely', 'new', 'system']
# [5, 6] 	 5 9
# Answer: steel cable My answer: ['steel', 'cable', 'were', 'a', 'danger']
# [] 	 5 9
# Answer: the interceptor aircraft My answer: ['jet', 'aircraft', 'limit', 'target', 'opportunities']
# [34, 35, 36] 	 1 8
# Answer: speed and direction My answer: ['means', 'that', 'projectiles', 'either', 'have', 'to', 'be', 'guided']
# [43] 	 1 8
# Answer: 100 My answer: ['an', 'attacker', 'is', 'able', 'to', 'penetrate', 'this', 'layer']
# [1, 2] 	 5 8
# Answer: short range My answer: ['apparent', 'target', 'area', 'is']
# [38, 39] 	 5 8
# Answer: infantry positions My answer: ['the', 'infantry', ',', 'particularly']
# [14, 15] 	 5 9
# Answer: artillery arm My answer: ['for', 'instance', ',', 'air', 'defence']
# [4, 5] 	 5 9
# Answer: range measurement My answer: ['measurement', 'first', ',', 'when', 'it']
# [16, 17] 	 5 9
# Answer: passive measures My answer: ['systems', ',', 'associated', 'sensor', 'systems']
# [12] 	 5 9
# Answer: concealment My answer: ['by', 'ground', 'forces', 'and', 'includes']
# [39] 	 1 8
# Answer: hydraulics My answer: ['system', 'used', 'a', 'centralised', 'control', 'system', 'including', 'both']
# [4] 	 6 7
# Answer: 1935 My answer: ['production', 'stopped']
# [1] 	 6 7
# Answer: 1938 My answer: ['12.8', 'cm']
# [13, 14] 	 5 9
# Answer: anti-aircraft warfare My answer: ['defence', 'as', 'counter-air', 'and', 'naval']
# [10, 11] 	 5 9
# Answer: the user My answer: ['angles', 'poses', 'a', 'danger', 'to']
# [20, 21, 22] 	 1 8
# Answer: most anti-aircraft gunnery My answer: ['of', 'the', 'standard', 'autocannon', ',', 'originally', 'intended', 'for']
# [11, 12, 13] 	 5 9
# Answer: in the air My answer: ['recognised', 'that', 'ammunition', 'needed', 'to']
# [15] 	 5 8
# Answer: 45 My answer: ['shotguns', 'and', 'machine-guns', 'but']
# [26, 27] 	 1 8
# Answer: many kilometers My answer: ['of', 'less', 'power', 'than', 'Germany', "'s", '20', 'mm']
# [21, 22, 23] 	 5 9
# Answer: smaller force levels My answer: ['in', 'depth', ',', 'from', 'integral']
# [32] 	 5 9
# Answer: optronics My answer: ['acoustic', 'devices', 'developed', 'during', 'the']
# [17] 	 1 8
# Answer: vertically My answer: ['term', 'is', "'ceiling", "'", ',', 'maximum', 'ceiling', 'being']
# [] 	 5 8
# Answer: air forces My answer: ['defence', 'may', 'be', 'for']
# [9, 10] 	 6 7
# Answer: ground forces My answer: ['air', 'force']
# [21] 	 5 9
# Answer: guns My answer: ['the', 'missile', 'found', 'itself', 'being']
# [24, 25] 	 5 9
# Answer: 75 mm My answer: ['electrical', ',', 'the', 'operator', 'entered']
# [9] 	 5 9
# Answer: trailers My answer: ['to', 'be', 'mounted', 'on', 'trailers']
# [7, 8, 9, 10, 11] 	 5 9
# Answer: counter-air defence My answer: ['defence', 'as', 'counter-air', 'and', 'naval']
# [13, 14, 15] 	 5 9
# Answer: in the 1960s My answer: ['at', 'least', 'supplanting', ',', 'similar']
# [23] 	 5 9
# Answer: 3 My answer: [',', 'which', 'was', 'under', 'command']
# [] 	 5 8
# Answer: area air defence My answer: ['air', 'defence', 'of', 'a']
# [8, 9] 	 5 9
# Answer: the cold war My answer: ['by', 'Germany', 'during', 'the', 'war']
# [17, 18, 19] 	 5 9
# Answer: 90-day screening period My answer: ['for', 'both', 'types', 'except', 'with']
# [5, 6] 	 5 9
# Answer: $ 500,000 My answer: ['$', '500,000', 'the', 'Secretary', 'of']
# [4, 5] 	 5 9
# Answer: eight years My answer: ['years', 'before', 'the', 'first', 'national']
# [21] 	 33 8
# Answer: seven My answer: []
# [30] 	 1 8
# Answer: butterflies My answer: ['further', 'noted', 'that', 'the', 'San', 'Bruno', 'plan', 'was']
# [6, 7] 	 6 7
# Answer: two ways My answer: ['two', 'ways']
# [28, 29] 	 5 9
# Answer: the clinton administration My answer: ['Endangered', 'Species', 'Act', ':', 'law']
# [11, 12] 	 5 9
# Answer: 16 birds My answer: ['1941', 'was', 'estimated', 'at', 'about']
# [] 	 5 8
# Answer: habitat conservation plan My answer: ['San', 'Bruno', 'plan', 'was']
# [12, 13] 	 5 9
# Answer: 45 days My answer: ['if', 'any', 'person', 'has', 'requested']
# [18, 19] 	 5 9
# Answer: cotton-top tamarin My answer: ['noted', 'another', 'exploit', 'of', 'the']
# [11] 	 33 8
# Answer: twenty-eight My answer: []
# [29, 30, 31] 	 5 8
# Answer: candidate assessment program My answer: ['Wildlife', 'Service', '(', 'FWS']
# [8, 9, 10, 11, 12] 	 5 8
# Answer: `` class of '67 '' My answer: ['to', 'as', 'the', '``']
# [9, 10] 	 1 8
# Answer: over 2,000 My answer: ['of', 'the', 'Endangered', 'Species', 'Act', 'argue', 'that', 'with']
# [24, 25] 	 5 9
# Answer: the northwest My answer: ['of', 'landscapes', ',', 'from', 'the']
# [29, 30, 31] 	 5 9
# Answer: about 75 % My answer: ['closely', 'linked', 'to', 'the', 'economy']
# [7, 8] 	 5 9
# Answer: 2.8 % My answer: ['has', 'averaged', '2.8', '%', ',']
# [1, 2, 3] 	 5 8
# Answer: the early seventies My answer: ['there', 'was', 'active', 'resistance']
# [13] 	 5 9
# Answer: one My answer: ['are', '55', 'tinkhundla', 'in', 'Swaziland']
# [] 	 5 9
# Answer: the king My answer: ['minister', 'from', 'the', 'legislature', 'and']
# [5] 	 5 9
# Answer: five My answer: ['five', 'years', 'after', 'dissolution', 'of']
# [19, 20, 21] 	 5 9
# Answer: a five-year term My answer: ['committee', '(', 'bucopho', ')', 'elected']
# [18, 19, 20] 	 5 9
# Answer: neighbourhood care points My answer: ['and', 'education', '(', 'ECCE', ')']
# [2] 	 6 7
# Answer: four My answer: ['.']
# [6] 	 6 7
# Answer: four My answer: ['four', 'and']
# [16, 17, 18, 19] 	 5 9
# Answer: more than 50 % My answer: ['200', '%', 'between', '2000', 'and']
# [12, 13] 	 1 8
# Answer: textile manufacturing My answer: ['dual', 'nature', 'of', 'the', 'Swazi', 'economy', ',', 'with']
# [17, 18, 19] 	 5 9
# Answer: 9 september 1964 My answer: ['took', 'place', 'and', 'the', 'first']
# [10] 	 6 7
# Answer: liqoqo My answer: ['Swazi', 'National']
# [28, 29] 	 5 9
# Answer: 20 % My answer: ['African', 'churches', ',', 'including', 'African']
# [6, 7] 	 6 7
# Answer: 17,364 km2 My answer: ['17,364', 'km2']
# [19, 20] 	 5 9
# Answer: 38.8 % My answer: ['government', 'acknowledged', 'for', 'the', 'first']
# [6, 7] 	 5 9
# Answer: mid-18th century My answer: ['the', 'mid-18th', 'century', 'under', 'the']
# [4] 	 6 7
# Answer: king My answer: ['.']
# [7, 8, 9] 	 6 8
# Answer: at the inkhundla My answer: ['elected', 'at', 'the']
# [2] 	 6 7
# Answer: 14 My answer: []
# [6] 	 5 9
# Answer: kubhula My answer: ['``', 'kubhula', "''", ',', 'a']
# [9, 10] 	 5 9
# Answer: 18 % My answer: ['problem', ',', 'with', 'an', '18']
# [18, 19] 	 5 9
# Answer: the majority My answer: [',', 'support', 'for', 'the', 'monarchy']
# [20, 21] 	 5 9
# Answer: the chiefdoms My answer: ['all', 'matters', 'of', 'interest', 'and']
# [5, 6] 	 5 9
# Answer: $ 9,714 My answer: ['$', '9,714', 'means', 'it', 'is']
# [6, 7, 8] 	 5 9
# Answer: 5-year or younger My answer: ['children', '5-year', 'or', 'younger', 'after']
# [15] 	 5 9
# Answer: three My answer: ['education', 'system', 'in', 'Swaziland', 'is']
# [14] 	 1 8
# Answer: 10 My answer: ['Swazi', 'bicameral', 'Parliament', 'or', 'Libandla', 'consists', 'of', 'the']
# [18, 19, 20] 	 5 9
# Answer: over 90 % My answer: ['closely', 'linked', 'to', 'the', 'economy']
# [13, 14, 15] 	 6 8
# Answer: indvuna ye nkhundla My answer: ['elected', 'at', 'the']
# [19] 	 5 9
# Answer: 1906 My answer: ['(', 'for', 'example', ',', 'postal']
# [14, 15, 16] 	 5 9
# Answer: at least ten My answer: ['it', ',', 'he', 'or', 'she']
# [] 	 5 9
# Answer: constituency executive committee My answer: ['committee', '(', 'bucopho', ')', 'elected']
# [11, 12] 	 1 8
# Answer: 30 seats My answer: ['Swazi', 'bicameral', 'Parliament', 'or', 'Libandla', 'consists', 'of', 'the']
# [3, 4] 	 5 9
# Answer: 21.6 % My answer: ['of', 'preschool', 'age', 'children', 'have']
# [27] 	 5 9
# Answer: 1982 My answer: [',', 'the', 'constitution', 'of', 'Swaziland']
# [1] 	 6 7
# Answer: 1903 My answer: ['in', 'the']
# [12, 13, 14] 	 6 8
# Answer: 19 august 2005 My answer: ['rite', 'of', '``']
# [33, 34, 35, 36] 	 5 8
# Answer: less than 20 % My answer: ['the', 'external', 'debt', 'burden']
# [0, 1] 	 5 9
# Answer: 83 % My answer: ['population', 'adheres', 'to', 'Christianity', ',']
# [1, 2, 3, 4] 	 6 7
# Answer: childless , unmarried girls My answer: ['take', 'part']
# [17, 18] 	 5 9
# Answer: 81 mi My answer: ['kilometres', '(', '120', 'mi', ')']
# [10, 11] 	 5 8
# Answer: declined markedly My answer: ['the', 'external', 'debt', 'burden']
# [5, 6, 7] 	 6 8
# Answer: all young girls My answer: ['young', 'girls', 'were']
# [12] 	 5 9
# Answer: 1972 My answer: ['established', 'as', 'Mananga', 'Agricultural', 'Management']
# [11, 12] 	 5 9
# Answer: 55 % My answer: ['over', '15', '%', 'of', 'GDP']
# [3, 4, 5] 	 5 9
# Answer: a traditional diviner My answer: ['diviner', 'chosen', 'by', 'the', 'ancestors']
# [12, 13] 	 5 9
# Answer: a minority My answer: ['minister', 'from', 'the', 'legislature', 'and']
# [27] 	 5 9
# Answer: 2013 My answer: ['Director', 'of', 'National', 'Intelligence', 'said']
# [16, 17] 	 5 8
# Answer: home appliances My answer: ['in', 'the', 'fields', 'of']
# [3, 4, 5] 	 5 9
# Answer: about 45 % My answer: ['%', 'of', 'the', 'government', "'s"]
# [4, 5] 	 6 7
# Answer: twelve jurists My answer: ['including', 'six']
# [15, 16, 17] 	 5 9
# Answer: rugged mountain ranges My answer: ['world', "'s", 'most', 'mountainous', 'countries']
# [7, 8, 9] 	 5 9
# Answer: $ 15 billion My answer: ['country', 'spent', '$', '15', 'billion']
# [13, 14] 	 6 8
# Answer: 70,000 citizens My answer: ['complete', 'massacre', 'of']
# [8, 9, 10] 	 5 9
# Answer: 636,372 sq mi My answer: ['1,648,195', 'km2', '(', '636,372', 'sq']
# [16, 17] 	 5 9
# Answer: below zero My answer: ['in', 'the', 'Zagros', 'basin', 'experience']
# [8, 9, 10] 	 5 9
# Answer: one week annually My answer: ['which', 'meets', 'for', 'one', 'week']
# [1] 	 5 9
# Answer: 2006 My answer: ['films', ',', 'of', 'six', 'different']
# [7, 8] 	 1 8
# Answer: foreign embargoes My answer: ['the', '1979', 'Revolution', ',', 'to', 'overcome', 'foreign', 'embargoes']
# [1] 	 5 9
# Answer: 1960s My answer: ['decade', 'for', 'Iranian', 'cinema', ',']
# [19, 20] 	 5 9
# Answer: 33,000 megawatts My answer: ['stations', 'and', 'the', 'streamlining', 'of']
# [41, 42, 43] 	 5 8
# Answer: proven oil reserves My answer: ['and', 'middle', 'power', ',']
# [9, 10] 	 5 9
# Answer: four-year terms My answer: ['by', 'public', 'vote', 'to', 'four-year']
# [19] 	 5 9
# Answer: 90,000 My answer: ['volunteer', 'militia', 'force', 'within', 'the']
# [25] 	 5 9
# Answer: 65 My answer: ['decade', 'for', 'Iranian', 'cinema', ',']
# [23, 24, 25, 26] 	 5 9
# Answer: the sassanid empire My answer: ['Shah', ',', 'Iran', 'reached', 'its']
# [23, 24] 	 5 9
# Answer: 156 years My answer: ['conqueror', ',', 'Timur', ',', 'followed']
# [11, 12] 	 5 8
# Answer: 22 % My answer: ['in', 'Iran', 'make', 'up']
# [8] 	 5 9
# Answer: embargo My answer: ['such', 'as', 'the', 'embargo', 'against']
# [10, 11] 	 6 7
# Answer: 153,600,000,000 barrels My answer: ['reserves', 'with']
# [7] 	 6 7
# Answer: six My answer: ['including', 'six']
# [1] 	 5 9
# Answer: 2010 My answer: ['reform', 'plan', 'was', 'approved', 'by']
# [11, 12, 13] 	 5 9
# Answer: 25 commercial films My answer: ['decade', 'for', 'Iranian', 'cinema', ',']
# [13, 14] 	 5 9
# Answer: in 1906 My answer: ['the', 'first', 'national', 'parliament', 'of']
# [13, 14] 	 5 8
# Answer: construction materials My answer: ['in', 'the', 'fields', 'of']
# [11] 	 5 9
# Answer: 19 My answer: ['is', 'reflected', 'in', 'part', 'by']
# [62, 63, 64] 	 1 8
# Answer: the achaemenid empire My answer: ['reached', 'the', 'pinnacle', 'of', 'its', 'power', 'during', 'the']
# [10, 11, 12, 13] 	 5 9
# Answer: mamluks ( slave-warriors ) My answer: ['in', 'the', 'Abbasid', 'army', 'as']
# [46] 	 5 9
# Answer: watermelons My answer: ['has', 'been', 'a', 'top', 'five']
# [7, 8] 	 5 9
# Answer: the 1979 constitution My answer: ['incompatible', 'with', 'the', 'constitution', 'or']
# [18, 19] 	 5 9
# Answer: were executed My answer: ['had', 'initially', 'joined', 'with', 'Islamists']
# [33] 	 5 8
# Answer: petrochemicals My answer: ['in', 'the', 'fields', 'of']
# [13, 14] 	 5 9
# Answer: 18 % My answer: ['75', '%', 'was', 'based', 'on']
# [1] 	 5 9
# Answer: 2004 My answer: ['its', 'first', 'wind-powered', 'and', 'geothermal']
# [32, 33] 	 5 8
# Answer: natural gas My answer: ['and', 'middle', 'power', ',']
# [48] 	 1 8
# Answer: *ar-yo- My answer: ['Middle', 'Iranian', 'ērān', 'and', 'aryān', 'are', 'oblique', 'plural']
# [52, 53] 	 1 8
# Answer: scientific writing My answer: ['the', '10th', 'century', ',', 'Persian', 'language', ',', 'alongside']
# [12, 13, 14] 	 5 8
# Answer: large-scale state subsidies My answer: ['a', 'chronic', 'problem', ',']
# [62, 63, 64] 	 1 8
# Answer: the achaemenid empire My answer: ['reached', 'the', 'pinnacle', 'of', 'its', 'power', 'during', 'the']
# [18] 	 5 9
# Answer: 11,000–16,000 My answer: ['the', 'war', 'were', 'estimated', 'to']
# [4, 5] 	 5 8
# Answer: the gentilic My answer: ['gentilic', 'is', 'attested', 'as']
# [6] 	 1 8
# Answer: 2015 My answer: ['a', 'successful', 'implementation', 'of', 'the', '2015', 'nuclear', 'and']
# [1] 	 5 9
# Answer: 1370 My answer: ['conqueror', ',', 'Timur', ',', 'followed']
# [] 	 5 8
# Answer: the fajr-3 ( mirv ) My answer: ['the', 'most', 'mountainous', ',']
# [14] 	 5 9
# Answer: 3rd-century My answer: ['from', 'Middle', 'Persian', 'Ērān', ',']
# [4, 5] 	 5 9
# Answer: restoring order My answer: ['order', ',', 'the', 'Russians', 'occupied']
# [5, 6, 7] 	 5 9
# Answer: around 40 % My answer: ['around', '40', '%', 'of', 'the']
# [7, 8] 	 5 9
# Answer: 1.4 million My answer: ['of', 'around', '1.4', 'million', '(']
# [5, 6] 	 5 9
# Answer: military spending My answer: ['military', 'spending', 'represented', '2.6', '%']
# [11] 	 5 9
# Answer: 1979 My answer: ['the', 'new', 'government', 'began', 'by']
# [13] 	 5 9
# Answer: 86 My answer: ['which', 'meets', 'for', 'one', 'week']
# [5, 6, 7] 	 9 9
# Answer: an economic recession My answer: ['to']
# [5, 6] 	 5 9
# Answer: ranked 69 My answer: ['ranked', '69', ',', 'out', 'of']
# [13, 14] 	 5 9
# Answer: in 1906 My answer: ['the', 'first', 'national', 'parliament', 'of']
# [1] 	 5 9
# Answer: 1960 My answer: ['co-invented', 'the', 'first', 'gas', 'laser']
# [7] 	 6 7
# Answer: 1993 My answer: ['in', '1993']
# [14, 15, 16] 	 5 8
# Answer: between 21.6–30 % My answer: [',', 'the', 'number', 'of']
# [4] 	 5 9
# Answer: 1988 My answer: [',', 'when', 'the', 'Iraqi', 'army']
# [1] 	 6 8
# Answer: summer My answer: ['°C', '(', '100.4']
# [1, 2] 	 6 7
# Answer: 78.4 million My answer: ['is', 'the']
# [21, 22] 	 5 9
# Answer: rated 4th My answer: ['deputy', 'head', 'of', 'research', 'for']
# [17] 	 6 8
# Answer: 1921 My answer: ['British', 'occupied', 'much']
# [8, 9] 	 5 9
# Answer: until 1911 My answer: ['constitutional', 'movement', 'continued', 'until', '1911']
# [28, 29] 	 5 9
# Answer: 25 % My answer: [',', 'the', 'number', 'of', 'ethnic']
# [10, 11, 12] 	 5 9
# Answer: $ 70 billion My answer: [']', ',', 'Iran', 'had', 'earned']
# [24] 	 5 9
# Answer: 36,000 My answer: ['steep', 'fall', 'in', 'the', 'value']
# [] 	 5 9
# Answer: the assyrian empire My answer: ['region', 'since', 'the', '9th', 'century']
# [1, 2, 3] 	 5 9
# Answer: the 19th century My answer: ['Iran', 'irrevocably', 'lost', 'swaths', 'of']
# [6, 7, 8] 	 5 9
# Answer: over 80 % My answer: ['ruled', 'over', '44', '%', 'of']
# [13] 	 5 9
# Answer: twenty-two My answer: ['President', ',', 'as', 'well', 'as']
# [] 	 5 9
# Answer: the golrizan festival My answer: ['festival', 'that', 'had', 'begun', 'in']
# [6, 7] 	 5 9
# Answer: the bonyads My answer: ['as', 'the', 'bonyads', 'have', 'often']
# [44, 45, 46] 	 1 8
# Answer: to the south My answer: ['is', 'bordered', 'to', 'the', 'northwest', 'by', 'Armenia', ',']
# [26, 27, 28, 29] 	 5 9
# Answer: the sassanid era My answer: ['Iran', ',', 'like', 'those', 'excavated']
# [5, 6] 	 5 9
# Answer: 75 % My answer: ['75', '%', 'was', 'based', 'on']
# [6, 7, 8] 	 5 9
# Answer: the iraqi army My answer: [',', 'the', 'Iraqi', 'army', 'invaded']
# [3] 	 5 9
# Answer: 1973 My answer: ['in', 'oil', 'prices', ',', 'the']
# [5, 6] 	 5 9
# Answer: a third My answer: ['a', 'third', 'of', 'black', 'Harvard']
# [9, 10] 	 5 9
# Answer: class rank My answer: ['replaced', 'racial', 'quotas', 'with', 'class']
# [1] 	 5 9
# Answer: 2006 My answer: ['%', 'of', 'Michigan', 'voters', 'decided']
# [24, 25, 26] 	 5 9
# Answer: whites and males My answer: ['and', 'women', 'have', 'faced', 'discrimination']
# [26] 	 5 9
# Answer: two My answer: ['mandated', 'the', 'end', 'of', 'hiring']
# [21, 22, 23] 	 5 9
# Answer: enforcing equal opportunity My answer: ['against', 'affirmative', 'action', ',', 'wanted']
# [25, 26] 	 5 9
# Answer: 12 % My answer: ['educated', 'major', 'ethnic', 'group', 'and']
# [5, 6, 7] 	 5 9
# Answer: integrate public facilities My answer: ['integrate', 'public', 'facilities', ',', 'but']
# [6] 	 5 9
# Answer: reservations My answer: ['onto', 'reservations', 'which', 'were', 'far']
# [21, 22] 	 1 8
# Answer: legacy admissions My answer: [',', 'ethnicity', ',', 'native', 'language', ',', 'social', 'class']
# [13, 14] 	 5 9
# Answer: class inequality My answer: ["'s", 'effectiveness', 'is', 'based', 'on']
# [3] 	 6 8
# Answer: 17 My answer: ['two', 'Hispanics', 'the']
# [4, 5] 	 5 9
# Answer: 60 % My answer: ['%', 'of', 'Michigan', 'voters', 'decided']
# -------------------------------------------------------------------
# KeyboardInterrupt                 Traceback (most recent call last)
# <ipython-input-106-02a779b53e0e> in <module>()
#       1 my_answers = []
#       2 for i,embed_query in enumerate(embed_train_qs):
# ----> 3     start_idx, end_idx = get_start_end(training_input[i:i+1])
#       4     start_idx = np.argmax(start_idx)
#       5     end_idx = np.argmax(end_idx)
#
# <ipython-input-96-abee95b65203> in get_start_end(question)
#       1 def get_start_end(question):
#       2     # Encode the input as state vectors.
# ----> 3     states_value = encoder_model.predict(question)
#       4
#       5     # Generate empty target sequence of length 1.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1833         f = self.predict_function
#    1834         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1835                                   verbose=verbose, steps=steps)
#    1836
#    1837     def train_on_batch(self, x, y,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1329                     ins_batch[i] = ins_batch[i].toarray()
#    1330
# -> 1331                 batch_outs = f(ins_batch)
#    1332                 if not isinstance(batch_outs, list):
#    1333                     batch_outs = [batch_outs]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import csv
with open('result.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["id","answer"])
    for i,embed_query in enumerate(embed_test_qs):
        start_idx, end_idx = get_start_end(testing_input[i:i+1])
        start_idx = np.argmax(start_idx)
        end_idx = np.argmax(end_idx)
        my_answer = tokenized_test_context[i][start_idx:end_idx+1]
        writer.writerow([str(i), " ".join(my_answer)])
